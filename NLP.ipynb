# %%
import numpy as np
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from sklearn.datasets import load_files
import pandas as pd
import re
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from gensim.models import Word2Vec
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
from gensim.models import KeyedVectors
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn import preprocessing
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences 
from keras.models import Sequential
from keras.layers import Dense, Embedding, LSTM, SimpleRNN
from keras.layers import Dense, Dropout, Activation
from keras.layers import Conv1D, MaxPooling1D
from keras.utils.np_utils import to_categorical
from keras.models import Model
from keras.engine import Input

# %% [markdown]
# # NLTK experiments

# %%
text = 'NLP is a subfield of computer science and artificial intelligence. It is concerned with interactions between computers and human (natural) languages. It is used to apply machine learning algorithms to text and speech.'

# %%
print(text)
# Out:
# NLP is a subfield of computer science and artificial intelligence. It is concerned with interactions between computers and human (natural) languages. It is used to apply machine learning algorithms to text and speech.

# %%
#Sentence tokenization. Splitting the paragraph into sentences
sentences = sent_tokenize(text)
print(sentences)
# Out:
# ['NLP is a subfield of computer science and artificial intelligence.', 'It is concerned with interactions between computers and human (natural) languages.', 'It is used to apply machine learning algorithms to text and speech.']

# %%
#Word tokenization. Splitting the sentences into words
words = word_tokenize(text)
print(words)
# Out:
# ['NLP', 'is', 'a', 'subfield', 'of', 'computer', 'science', 'and', 'artificial', 'intelligence', '.', 'It', 'is', 'concerned', 'with', 'interactions', 'between', 'computers', 'and', 'human', '(', 'natural', ')', 'languages', '.', 'It', 'is', 'used', 'to', 'apply', 'machine', 'learning', 'algorithms', 'to', 'text', 'and', 'speech', '.']

# %%
#Sentence wise word tokenization 
tokenized_words = []

for i in range(len(sentences)):
    tokenized_words.append(word_tokenize(sentences[i]))

print(tokenized_words)
# Out:
# [['NLP', 'is', 'a', 'subfield', 'of', 'computer', 'science', 'and', 'artificial', 'intelligence', '.'], ['It', 'is', 'concerned', 'with', 'interactions', 'between', 'computers', 'and', 'human', '(', 'natural', ')', 'languages', '.'], ['It', 'is', 'used', 'to', 'apply', 'machine', 'learning', 'algorithms', 'to', 'text', 'and', 'speech', '.']]

# %%
#Stemming
stemmer = PorterStemmer()
stemmed_sent = []

for i in range(len(sentences)):
    words = word_tokenize(sentences[i])
    words = [stemmer.stem(word) for word in words]
    stemmed_sent.append(words) 

print(stemmed_sent)
# Out:
# [['nlp', 'is', 'a', 'subfield', 'of', 'comput', 'scienc', 'and', 'artifici', 'intellig', '.'], ['It', 'is', 'concern', 'with', 'interact', 'between', 'comput', 'and', 'human', '(', 'natur', ')', 'languag', '.'], ['It', 'is', 'use', 'to', 'appli', 'machin', 'learn', 'algorithm', 'to', 'text', 'and', 'speech', '.']]

# %%
#Lemmatization
lemmatizer = WordNetLemmatizer()
lemma_sent = []

for i in range(len(sentences)):
    words = word_tokenize(sentences[i])
    words = [lemmatizer.lemmatize(word) for word in words]
    lemma_sent.append(words)
    
print(lemma_sent)
# Out:
# [['NLP', 'is', 'a', 'subfield', 'of', 'computer', 'science', 'and', 'artificial', 'intelligence', '.'], ['It', 'is', 'concerned', 'with', 'interaction', 'between', 'computer', 'and', 'human', '(', 'natural', ')', 'language', '.'], ['It', 'is', 'used', 'to', 'apply', 'machine', 'learning', 'algorithm', 'to', 'text', 'and', 'speech', '.']]

# %%
#Print stop words in English
stops = stopwords.words("english")
print(stops)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'her', 'hers', 'herself', 'it', 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', 'should', 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', 'couldn', 'didn', 'doesn', 'hadn', 'hasn', 'haven', 'isn', 'ma', 'mightn', 'mustn', 'needn', 'shan', 'shouldn', 'wasn', 'weren', 'won', 'wouldn']

# %%
#Removing stop words
stop_words_removed = []

for i in range(len(sentences)):
    words = word_tokenize(sentences[i])
    words = [word for word in words if word not in stopwords.words('english')]
    stop_words_removed.append(words)
    
print(stop_words_removed)
# Out:
# [['NLP', 'subfield', 'computer', 'science', 'artificial', 'intelligence', '.'], ['It', 'concerned', 'interactions', 'computers', 'human', '(', 'natural', ')', 'languages', '.'], ['It', 'used', 'apply', 'machine', 'learning', 'algorithms', 'text', 'speech', '.']]

# %% [markdown]
# # Text classification
# ## Sentiment analysis

# %%
#Reading the data
data = pd.read_csv('sa_data.csv')

# %%
data.head()
# Out:
#                                                 text sentiment
# 0  RT @NancyLeeGrahn: How did everyone feel about...   Neutral
# 1  RT @ScottWalker: Didn't catch the full #GOPdeb...  Positive
# 2  RT @TJMShow: No mention of Tamir Rice and the ...   Neutral
# 3  RT @RobGeorge: That Carly Fiorina is trending ...  Positive
# 4  RT @DanScavino: #GOPDebate w/ @realDonaldTrump...  Positive

# %%
#Preprocessing - removing unwanted characters, tokenization, stop-word removal
def clean_data(tweet):
    x = re.sub("[^a-zA-Z0-9]", " ",tweet) 
    x = x.lower().split()                             
    stops = set(stopwords.words("english"))                  
    words = [w for w in x if not w in stops] 
    return( " ".join(words))

# %%
data['text'] = data['text'].apply(lambda x: clean_data(x))
print(data['text'])
# Out:
# 0        nancyleegrahn everyone feel climate change que...
# 1        scottwalker catch full gopdebate last night sc...
# 2        tjmshow mention tamir rice gopdebate held clev...
# 3        robgeorge carly fiorina trending hours debate ...
# 4        danscavino gopdebate w realdonaldtrump deliver...
# 5        gregabbott tx tedcruz first day rescind every ...
# 6        warriorwoman91 liked happy heard going moderat...
# 7        going msnbc live thomasaroberts around 2 pm et...
# 8        deer headlights lizzwinstead ben carson may br...
# 9        nancyosborne180 last night debate proved gopde...
# 10       jgreendc realdonaldtrump fairness billclinton ...
# 11       waynedupreeshow woke tweet gopdebate best line...
# 12       reading family comments great gopdebate http c...
# 13       arcticfox2016 allenwestrepub dear jebbush gopd...
# 14       pattonoswalt loved scott walker mark harmon ro...
# 15       hey chrischristie exploiting tragedy 9 11 poli...
# 16       carolcnn donaldtrump fire comments women peter...
# 17       johncardillo guess speaking time gopdebate fox...
# 18       reason comment funny case ignorant gop tcot re...
# 19       pamelageller huckabee paying transgender surge...
# 20       chucknellis cruz class amp truth gets vote gop...
# 21       mchamric teatraitors gopdebate still clown sho...
# 22       erinmallorylong hate planned parenthood women ...
# 23       thekevinryder gopdebate vine dabulldawg88 http...
# 24       mrpooni fox news trying convince us young blac...
# 25       gopdebate rankings worst performance rubio kas...
# 26       thebaxterbean scott walker abortion ban allows...
# 27       feministabulous competition moved far gay righ...
# 28       mch7576 teatraitors gopdebate still clown show...
# 29       hillaryclinton watch gopdebate bet feel like d...
#                                ...
# 13841    ethanobama trump admit gives money return busi...
# 13842    trump world look contribution list clinton fou...
# 13843           jessicavalenti need coif reform gopdebates
# 13844    wow rubio ear head ratio messed walker point g...
# 13845    the818 let play fast distance trump gopdebates...
# 13846    watching gop debates gopdebates https co nogwf...
# 13847         mjtbaum god making appearance gopdebate good
# 13848    puestoloco newday cancel primaries fox party s...
# 13849    kaylasmith4791 really enjoyed everything marco...
# 13850    rwsurfergirl candidates attack realdonaldtrump...
# 13851    gopdebate nutshell via vote true blue 2016 htt...
# 13852    erinmallorylong hate planned parenthood women ...
# 13853    brendankkirby johnkasich wrapped mailman vote ...
# 13854    monaeltahawy tell one good thing gopdebates ca...
# 13855    pro life nonsense gopdebate amusing notion jiz...
# 13856              gop respects life black ones gopdebates
# 13857                   watch fox news assholes gopdebates
# 13858    marcorubio came gate like true leader look for...
# 13859    best line gopdebate immigration without assimi...
# 13860    people say prolife usually anti social program...
# 13861    rwsurfergirl realdonaldtrump pledge suppogop e...
# 13862    rwsurfergirl trump got right nobody would talk...
# 13863    trans soldiers die huckabee foot bill make ful...
# 13864    rwsurfergirl anyone else want punch chris wall...
# 13865    rwsurfergirl fox cherry picking candidates jeb...
# 13866    cappy yarbrough love see men never faced pregn...
# 13867    georgehenryw thought huckabee exceeded expecta...
# 13868    lrihendry tedcruz president always tell truth ...
# 13869    jrehling gopdebate donald trump says time poli...
# 13870    lrihendry tedcruz headed presidential debates ...
# Name: text, Length: 13871, dtype: object

# %%
for i in range(len(data)):
    data['text'][i] = data['text'][i].replace('rt ','')

print(data['text'])
# Out:
# 0        nancyleegrahn everyone feel climate change que...
# 1        scottwalker catch full gopdebate last night sc...
# 2        tjmshow mention tamir rice gopdebate held clev...
# 3        robgeorge carly fiorina trending hours debate ...
# 4        danscavino gopdebate w realdonaldtrump deliver...
# 5        gregabbott tx tedcruz first day rescind every ...
# 6        warriorwoman91 liked happy heard going moderat...
# 7        going msnbc live thomasaroberts around 2 pm et...
# 8        deer headlights lizzwinstead ben carson may br...
# 9        nancyosborne180 last night debate proved gopde...
# 10       jgreendc realdonaldtrump fairness billclinton ...
# 11       waynedupreeshow woke tweet gopdebate best line...
# 12       reading family comments great gopdebate http c...
# 13       arcticfox2016 allenwestrepub dear jebbush gopd...
# 14       pattonoswalt loved scott walker mark harmon ro...
# 15       hey chrischristie exploiting tragedy 9 11 poli...
# 16       carolcnn donaldtrump fire comments women peter...
# 17       johncardillo guess speaking time gopdebate fox...
# 18       reason comment funny case ignorant gop tcot re...
# 19       pamelageller huckabee paying transgender surge...
# 20       chucknellis cruz class amp truth gets vote gop...
# 21       mchamric teatraitors gopdebate still clown sho...
# 22       erinmallorylong hate planned parenthood women ...
# 23       thekevinryder gopdebate vine dabulldawg88 http...
# 24       mrpooni fox news trying convince us young blac...
# 25       gopdebate rankings worst performance rubio kas...
# 26       thebaxterbean scott walker abortion ban allows...
# 27       feministabulous competition moved far gay righ...
# 28       mch7576 teatraitors gopdebate still clown show...
# 29       hillaryclinton watch gopdebate bet feel like d...
#                                ...
# 13841    ethanobama trump admit gives money return busi...
# 13842    trump world look contribution list clinton fou...
# 13843           jessicavalenti need coif reform gopdebates
# 13844    wow rubio ear head ratio messed walker point g...
# 13845    the818 let play fast distance trump gopdebates...
# 13846    watching gop debates gopdebates https co nogwf...
# 13847         mjtbaum god making appearance gopdebate good
# 13848    puestoloco newday cancel primaries fox party s...
# 13849    kaylasmith4791 really enjoyed everything marco...
# 13850    rwsurfergirl candidates attack realdonaldtrump...
# 13851    gopdebate nutshell via vote true blue 2016 htt...
# 13852    erinmallorylong hate planned parenthood women ...
# 13853    brendankkirby johnkasich wrapped mailman vote ...
# 13854    monaeltahawy tell one good thing gopdebates ca...
# 13855    pro life nonsense gopdebate amusing notion jiz...
# 13856              gop respects life black ones gopdebates
# 13857                   watch fox news assholes gopdebates
# 13858    marcorubio came gate like true leader look for...
# 13859    best line gopdebate immigration without assimi...
# 13860    people say prolife usually anti social program...
# 13861    rwsurfergirl realdonaldtrump pledge suppogop e...
# 13862    rwsurfergirl trump got right nobody would talk...
# 13863    trans soldiers die huckabee foot bill make ful...
# 13864    rwsurfergirl anyone else want punch chris wall...
# 13865    rwsurfergirl fox cherry picking candidates jeb...
# 13866    cappy yarbrough love see men never faced pregn...
# 13867    georgehenryw thought huckabee exceeded expecta...
# 13868    lrihendry tedcruz president always tell truth ...
# 13869    jrehling gopdebate donald trump says time poli...
# 13870    lrihendry tedcruz headed presidential debates ...
# Name: text, Length: 13871, dtype: object

# %%
#Converting the dataframe into list
reviews = data['text'].tolist()
sentiment = data['sentiment'].tolist()

# %%
corpus = []
for i in range(len(reviews)):
    corpus.append(word_tokenize(reviews[i]))

# %%
corpus
# Out:
# [['nancyleegrahn',
#   'everyone',
#   'feel',
#   'climate',
#   'change',
#   'question',
#   'last',
#   'night',
#   'exactly',
#   'gopdebate'],
#  ['scottwalker',
#   'catch',
#   'full',
#   'gopdebate',
#   'last',
#   'night',
#   'scott',
#   'best',
#   'lines',
#   '90',
#   'seconds',
#   'walker16',
#   'http',
#   'co',
#   'zsff'],
#  ['tjmshow',
#   'mention',
#   'tamir',
#   'rice',
#   'gopdebate',
#   'held',
#   'cleveland',
#   'wow'],
#  ['robgeorge',
#   'carly',
#   'fiorina',
#   'trending',
#   'hours',
#   'debate',
#   'men',
#   'completed',
#   'gopdebate',
#   'says'],
#  ['danscavino',
#   'gopdebate',
#   'w',
#   'realdonaldtrump',
#   'delivered',
#   'highest',
#   'ratings',
#   'history',
#   'presidential',
#   'debates',
#   'trump2016',
#   'http',
#   'co'],
#  ['gregabbott',
#   'tx',
#   'tedcruz',
#   'first',
#   'day',
#   'rescind',
#   'every',
#   'illegal',
#   'executive',
#   'action',
#   'taken',
#   'barack',
#   'obama',
#   'gopdebate',
#   'foxnews'],
#  ['warriorwoman91',
#   'liked',
#   'happy',
#   'heard',
#   'going',
#   'moderator',
#   'anymore',
#   'gopdebate',
#   'megynkelly',
#   'https'],
#  ['going',
#   'msnbc',
#   'live',
#   'thomasaroberts',
#   'around',
#   '2',
#   'pm',
#   'et',
#   'gopdebate'],
#  ['deer',
#   'headlights',
#   'lizzwinstead',
#   'ben',
#   'carson',
#   'may',
#   'brain',
#   'surgeon',
#   'performed',
#   'lobotomy',
#   'gopdebate'],
#  ['nancyosborne180',
#   'last',
#   'night',
#   'debate',
#   'proved',
#   'gopdebate',
#   'batsask',
#   'badassteachersa',
#   'tbats',
#   'https',
#   'co',
#   'g2ggjy1bjd'],
#  ['jgreendc',
#   'realdonaldtrump',
#   'fairness',
#   'billclinton',
#   'owns',
#   'phrase',
#   'gopdebate'],
#  ['waynedupreeshow',
#   'woke',
#   'tweet',
#   'gopdebate',
#   'best',
#   'line',
#   'night',
#   'via',
#   'govmikehuckabee',
#   'http',
#   'co',
#   '6ov5hxhicv'],
#  ['reading',
#   'family',
#   'comments',
#   'great',
#   'gopdebate',
#   'http',
#   'co',
#   'giagjpygxz'],
#  ['arcticfox2016',
#   'allenwestrepub',
#   'dear',
#   'jebbush',
#   'gopdebate',
#   'notamistake',
#   'http',
#   'co',
#   'ttfg7kycd9'],
#  ['pattonoswalt',
#   'loved',
#   'scott',
#   'walker',
#   'mark',
#   'harmon',
#   'romantic',
#   'rival',
#   'summer',
#   'school',
#   'look',
#   'gopdebate'],
#  ['hey',
#   'chrischristie',
#   'exploiting',
#   'tragedy',
#   '9',
#   '11',
#   'political',
#   'gain',
#   'rudygiulianigop',
#   'thing',
#   'gopdebate'],
#  ['carolcnn',
#   'donaldtrump',
#   'fire',
#   'comments',
#   'women',
#   'peterbeinasl',
#   'schaeffer',
#   'iwf',
#   'myrkiger',
#   'weigh',
#   'gopdebate',
#   'http'],
#  ['johncardillo',
#   'guess',
#   'speaking',
#   'time',
#   'gopdebate',
#   'foxnews',
#   'moderators',
#   '31',
#   '7',
#   'time',
#   'http',
#   'co',
#   '2wsut0c0lx'],
#  ['reason',
#   'comment',
#   'funny',
#   'case',
#   'ignorant',
#   'gop',
#   'tcot',
#   'reason',
#   'government',
#   'working',
#   'people',
#   'gopdebate'],
#  ['pamelageller',
#   'huckabee',
#   'paying',
#   'transgender',
#   'surgery',
#   'soldiers',
#   'sailors',
#   'airmen',
#   'make',
#   'country',
#   'safer',
#   'ha',
#   'gopdebate'],
#  ['chucknellis', 'cruz', 'class', 'amp', 'truth', 'gets', 'vote', 'gopdebate'],
#  ['mchamric',
#   'teatraitors',
#   'gopdebate',
#   'still',
#   'clown',
#   'show',
#   'glad',
#   'head',
#   'clown',
#   'trump',
#   'helping',
#   'destroy',
#   'gop',
#   'http',
#   'co',
#   'nwgx8g8jwr'],
#  ['erinmallorylong',
#   'hate',
#   'planned',
#   'parenthood',
#   'women',
#   'hate',
#   'planned',
#   'parenthood',
#   'women',
#   'gopdebate'],
#  ['thekevinryder',
#   'gopdebate',
#   'vine',
#   'dabulldawg88',
#   'https',
#   'co',
#   'xkxvdradce'],
#  ['mrpooni',
#   'fox',
#   'news',
#   'trying',
#   'convince',
#   'us',
#   'young',
#   'black',
#   'americans',
#   'worried',
#   'isis',
#   'police',
#   'terrorism',
#   'gopdebate',
#   'http',
#   'co'],
#  ['gopdebate',
#   'rankings',
#   'worst',
#   'performance',
#   'rubio',
#   'kasich',
#   'christie',
#   'bush',
#   'trump',
#   'cruz',
#   'walker',
#   'paul',
#   'huckabee',
#   'carson'],
#  ['thebaxterbean',
#   'scott',
#   'walker',
#   'abortion',
#   'ban',
#   'allows',
#   'rapist',
#   'father',
#   'sue',
#   'emotional',
#   'distress',
#   'http',
#   'co',
#   'rhmvgumuir',
#   'gopdebate',
#   'badger'],
#  ['feministabulous',
#   'competition',
#   'moved',
#   'far',
#   'gay',
#   'rights',
#   'women',
#   'rights',
#   'worse',
#   'ever',
#   'g'],
#  ['mch7576',
#   'teatraitors',
#   'gopdebate',
#   'still',
#   'clown',
#   'show',
#   'glad',
#   'head',
#   'clown',
#   'trump',
#   'helping',
#   'destroy',
#   'gop',
#   'http',
#   'co',
#   'pry2qpcwfu'],
#  ['hillaryclinton',
#   'watch',
#   'gopdebate',
#   'bet',
#   'feel',
#   'like',
#   'donating',
#   'democrat',
#   'right',
#   'http',
#   'co',
#   'pglqcqqgop',
#   'http',
#   'co',
#   'qp1e'],
#  ['fbhw',
#   'going',
#   'need',
#   'borrow',
#   'train',
#   'horn',
#   'next',
#   'gopdebate',
#   'little',
#   'bell',
#   'wimpy',
#   'hornmeansyouredone'],
#  ['lisavikingstad',
#   'ted',
#   'cruz',
#   'gopdebate',
#   'like',
#   'ted',
#   'cruz',
#   'bed',
#   'keep',
#   'confusingly',
#   'sad',
#   'look',
#   'face',
#   'refuse'],
#  ['first',
#   'gopdebate',
#   'social',
#   'media',
#   'reaction',
#   'http',
#   'co',
#   'x6kuvskltf'],
#  ['socialmedia',
#   'first',
#   'gopdebate',
#   'social',
#   'media',
#   'reaction',
#   'http',
#   'co',
#   'ogoyfnyikj'],
#  ['winesdaypodcast',
#   'update',
#   'foxnews',
#   'tech',
#   'failures',
#   'gopdebate',
#   'http',
#   'co',
#   'fgglf2j5hu',
#   'http',
#   'co',
#   'zw35dkuozi'],
#  ['amymek',
#   'torched',
#   'passed',
#   'gt',
#   'candycrowley',
#   'longer',
#   'famous',
#   'political',
#   'assassin',
#   'congratulations',
#   'megynkelly',
#   'u',
#   'wi'],
#  ['stockwizards3',
#   'trump',
#   'carson',
#   'ticket',
#   'would',
#   'win',
#   'landslide',
#   'realdonaldtrump',
#   'seanhannity',
#   'anncoulter',
#   'republican',
#   'potus',
#   'trump2016'],
#  ['kvxrdashian',
#   'jeb',
#   'bush',
#   'obama',
#   'fault',
#   'brother',
#   'obama',
#   'clean',
#   'mess',
#   'brother',
#   'made',
#   'gopdebate',
#   'http'],
#  ['ali',
#   'fox',
#   'news',
#   'gopdebate',
#   'primary',
#   'voters',
#   'none',
#   'wiser',
#   'policy',
#   'plans',
#   'folks',
#   'putting',
#   'forth',
#   'journalism'],
#  ['itsashlyperez',
#   'listening',
#   'fetty',
#   'wap',
#   'packing',
#   'true',
#   'american',
#   'gopdebate',
#   'doesthishashtagexpire'],
#  ['mgell',
#   'trump',
#   'cross',
#   'shrug',
#   'emoji',
#   'president',
#   'business',
#   'lego',
#   'movie',
#   'gopdebate'],
#  ['jamellemybelle',
#   'meanwhile',
#   'white',
#   'house',
#   'gopdebate',
#   'http',
#   'co',
#   'nouuut5hkq'],
#  ['rowdygentleman',
#   'planning',
#   'gopdebate',
#   'drinking',
#   'game',
#   'right',
#   'rowdy',
#   'gentleman'],
#  ['brownblaze', 'please', 'kkkorgop', 'gopdebate', 'http', 'co', 'yaqyac3uv3'],
#  ['trump',
#   'thinks',
#   'criticism',
#   'misogynistic',
#   'remarks',
#   'political',
#   'correctness',
#   'problem',
#   'nope',
#   'pervasive',
#   'sexism',
#   'problem',
#   'gopdebate'],
#  ['lekarmasucre',
#   'gopdebate',
#   'handled',
#   'blacklivesmatter',
#   'http',
#   'co',
#   '8zgdy6lpct'],
#  ['palmaceiahome1',
#   'goal',
#   'foxnews',
#   'last',
#   'night',
#   'take',
#   'trump',
#   'pave',
#   'way',
#   'rino',
#   'like',
#   'bush',
#   'kasich',
#   'gopdebate'],
#  ['philstockworld',
#   'live',
#   'chat',
#   'room',
#   'gopdebate',
#   'trump',
#   'futures',
#   'spy',
#   'nonfarmpayrolls',
#   'jobs',
#   'netflix',
#   'http',
#   'co',
#   '0k06sf81rq',
#   'http'],
#  ['danscavino',
#   'gopdebate',
#   'w',
#   'realdonaldtrump',
#   'delivered',
#   'highest',
#   'ratings',
#   'history',
#   'presidential',
#   'debates',
#   'trump2016',
#   'fox',
#   'say',
#   'thanks'],
#  ['gov',
#   'tweeted',
#   'govmikehuckabee',
#   'gopdebate',
#   'moment',
#   'saying',
#   'purpose',
#   'military',
#   'kill',
#   'people',
#   'break',
#   'things',
#   'trans',
#   'servicemembers'],
#  ['ariannahuff', 'best', 'worst', 'gopdebate', 'http', 'co', 'yki30j7hho'],
#  ['megynkelly',
#   'chrisstirewalt',
#   'big',
#   'moments',
#   'randpaul',
#   'vs',
#   'chrischristie',
#   'realdonaldtrump',
#   'reaction',
#   'women',
#   'question',
#   'kellyfil'],
#  ['stylemom',
#   'question',
#   'hell',
#   'women',
#   'amp',
#   'body',
#   'parts',
#   'even',
#   'debate',
#   'foh',
#   'stop',
#   '1965',
#   'wtf',
#   'gopdebate'],
#  ['rushlimbaugh',
#   'americans',
#   'getting',
#   'beheaded',
#   'overseas',
#   'megynkelly',
#   'worried',
#   'whether',
#   'realdonaldtrump',
#   'calls',
#   'rosie',
#   'donnell',
#   'fat',
#   'gopdebate'],
#  ['chucknellis',
#   'defend',
#   'foxnews',
#   'far',
#   'fair',
#   'balanced',
#   'last',
#   'night',
#   'name',
#   'calling',
#   'juvenile',
#   'gopdebate'],
#  ['theskysgoneout',
#   'non',
#   'christians',
#   'gopdebate',
#   'god',
#   'questions',
#   'underline',
#   'little',
#   'anyone',
#   'really',
#   'cares',
#   'religious',
#   'minorities',
#   'chri'],
#  ['bipartisanism',
#   'gopdebate',
#   'response',
#   'blacklivesmatter',
#   'pathetic',
#   'http',
#   'co',
#   'ismxbrrm0h'],
#  ['factcheckdotorg',
#   'jebbush',
#   'said',
#   'cut',
#   'fl',
#   'taxes',
#   '19b',
#   'includes',
#   'cuts',
#   'estate',
#   'taxes',
#   'mandated',
#   'federal',
#   'law',
#   'gopdebate',
#   'ht'],
#  ['mydaughtersarmy',
#   'dear',
#   'gop',
#   'want',
#   'stop',
#   'abortions',
#   'gopdebate',
#   'http',
#   'co',
#   'rbl1t4ipx6'],
#  ['karrattipaul',
#   'join',
#   'isis',
#   'sign',
#   'death',
#   'warrant',
#   'signed',
#   'tedcruz',
#   'next',
#   'president',
#   'us',
#   'gopdebate',
#   'wakeupamerica',
#   'cruzcrew',
#   'htt'],
#  ['p0tus', 'gopdebate', 'closing', 'statements', 'http', 'co', 's15nlillso'],
#  ['amymek',
#   'status',
#   'single',
#   'broke',
#   'foxnews',
#   'last',
#   'night',
#   'goodbye',
#   'megynkelly',
#   'bretbaier',
#   'amp',
#   'chris',
#   'wallace',
#   'gopdebate',
#   'http'],
#  ['frankluntz',
#   'gopdebate',
#   '14',
#   'focus',
#   'groupers',
#   'said',
#   'favorable',
#   'view',
#   'trump',
#   '3',
#   'saw',
#   'positively',
#   'http'],
#  ['holly',
#   'renee',
#   'made',
#   'first',
#   'donation',
#   'carlyfiorina',
#   'impressed',
#   'gopdebate',
#   'performance',
#   'fiorina',
#   'http',
#   'co',
#   'jlfhfvz7st'],
#  ['thejimhughes',
#   'want',
#   'stop',
#   'sending',
#   'foreign',
#   'aid',
#   'places',
#   'burn',
#   'flag',
#   'staberkeley',
#   'gopdebate'],
#  ['frankthorpnbc',
#   'rand',
#   'paul',
#   'eye',
#   'roll',
#   'chris',
#   'christie',
#   'gopdebate',
#   'https',
#   'co',
#   'hf318qsowd'],
#  ['johnkasich',
#   'scrap',
#   'president',
#   'iran',
#   'deal',
#   'iran',
#   'get',
#   'nuke',
#   'kasich4us',
#   'gopdebate',
#   'http',
#   'co',
#   '9trzxonlzf'],
#  ['trying',
#   'decide',
#   'early',
#   'come',
#   'back',
#   'twitter',
#   'fulltime',
#   'gon',
#   'na',
#   'wait',
#   'closer',
#   'election',
#   'gopdebate',
#   'may',
#   'hooked'],
#  ['mspackyetti',
#   'donald',
#   'trump',
#   'campaign',
#   'reveals',
#   '1',
#   'important',
#   'thing',
#   'twitter',
#   'trolls',
#   'real',
#   'people',
#   'vote',
#   'scare',
#   'eve'],
#  ['bipartisanism',
#   'saying',
#   'worry',
#   'trump',
#   'never',
#   'elected',
#   'need',
#   'remember',
#   'elected',
#   'george',
#   'bush',
#   'twice',
#   'gopdebate',
#   'http'],
#  ['fox',
#   'news',
#   'gopdebate',
#   'agenda',
#   'promote',
#   'carly',
#   'never',
#   'mention',
#   'fired',
#   'hp',
#   'fiorina',
#   'amp',
#   'run',
#   'trump',
#   'race',
#   'http',
#   'co',
#   '9k1eujdfo7'],
#  ['hlllary',
#   'oh',
#   'one',
#   'thing',
#   'anyone',
#   'hear',
#   'anything',
#   'affordable',
#   'child',
#   'care',
#   'working',
#   'families',
#   'last',
#   'night',
#   'gopdebate'],
#  ['naughtybeyotch',
#   'allenwestrepub',
#   'dear',
#   'jebbush',
#   'gopdebate',
#   'notamistake',
#   'http',
#   'co',
#   'wqnsupspkc'],
#  ['marthamaccallum',
#   'billhemmer',
#   'gopdebate',
#   'bill',
#   'martha',
#   'team',
#   'first',
#   'debate',
#   '2nd',
#   'debate',
#   'ambush'],
#  ['country',
#   'going',
#   'hell',
#   'megyn',
#   'kelly',
#   'foxnews',
#   'attacking',
#   'trump',
#   'war',
#   'women',
#   'gopdebate'],
#  ['franklin',
#   'graham',
#   '1st',
#   'gopdebate',
#   'encouraging',
#   'see',
#   'several',
#   'candidates',
#   'express',
#   'faith',
#   'god',
#   'son',
#   'jesus',
#   'christ',
#   'http',
#   'c'],
#  ['snarkydemo',
#   'donaldtrump',
#   'said',
#   'politically',
#   'correct',
#   'course',
#   'trumpspeak',
#   'let',
#   'face',
#   'huge',
#   'asshole'],
#  ['bipartisanism',
#   'message',
#   'gopdebate',
#   'candidates',
#   'http',
#   'co',
#   'wfk5cmvgin'],
#  ['davidcicilline',
#   'worst',
#   'episode',
#   'apprentice',
#   'ever',
#   'seen',
#   'gopdebate'],
#  ['govmikehuckabee',
#   'luntz',
#   'lines',
#   'go',
#   'almost',
#   'reach',
#   '100',
#   'almost',
#   'never',
#   'happens',
#   'dial',
#   'research',
#   'gopdebate',
#   'htt'],
#  ['lolhayley',
#   'purpose',
#   'military',
#   'kill',
#   'people',
#   'break',
#   'things',
#   'something',
#   'actual',
#   'man',
#   'running',
#   'president',
#   'said'],
#  ['wondering',
#   'could',
#   'get',
#   'republican',
#   'party',
#   'pay',
#   'liver',
#   'transplant',
#   'playing',
#   'mtaibbi',
#   'gopdebate',
#   'drinking',
#   'game',
#   'last',
#   'night'],
#  ['brandondhowell',
#   'great',
#   'way',
#   'stafriday',
#   'carlyfiorina',
#   'carlyfiorina',
#   'gopdebate',
#   'http',
#   'co',
#   '1ai9cuz8by'],
#  ['tedcruz',
#   'elected',
#   'first',
#   'day',
#   'president',
#   'rescind',
#   'every',
#   'illegal',
#   'unconstitutional',
#   'executive',
#   'order',
#   'enacted',
#   'pres',
#   'oba'],
#  ['ronnie2k',
#   'donald',
#   'trump',
#   'gopdebate',
#   'like',
#   'https',
#   'co',
#   'jcuirk1i1u'],
#  ['bruneski',
#   'upstairs',
#   'putting',
#   'kids',
#   'bed',
#   'many',
#   'questions',
#   'climate',
#   'change',
#   'miss',
#   'gopdebate',
#   'gopclowncar'],
#  ['todd',
#   'akin',
#   'planned',
#   'parenthood',
#   'sting',
#   'backfired',
#   'republicans',
#   'gopdebate',
#   'standwithpp',
#   'http',
#   'co',
#   'ekxpfkthqn'],
#  ['learjetter',
#   'hey',
#   'foxnews',
#   'let',
#   'republicans',
#   'digest',
#   'gopdebate',
#   'allowing',
#   'crazy',
#   'dwstweets',
#   'trash',
#   'gop',
#   'ladysandersfarm',
#   'http'],
#  ['thebaxterbean',
#   'watch',
#   'donald',
#   'trump',
#   'receive',
#   'enormous',
#   'applause',
#   'horribly',
#   'misogynistic',
#   'gopdebate',
#   'answer',
#   'http',
#   'co',
#   'r4e8tpotd5',
#   'http'],
#  ['favorite',
#   'twitter',
#   'responses',
#   'gopdebate',
#   'last',
#   'night',
#   'http',
#   'co',
#   '2iqcdrcdlm',
#   'http',
#   'co',
#   '7tdma3vlm8'],
#  ['even',
#   'though',
#   'super',
#   'conservative',
#   'reporter',
#   'actually',
#   'like',
#   'megyn',
#   'kelly',
#   'interview',
#   'style',
#   'amp',
#   'great',
#   'gopdebate'],
#  ['kingsthings',
#   'gopdebate',
#   'debate',
#   'series',
#   '1',
#   'minute',
#   'opportunities',
#   'avoid',
#   'answering',
#   'question',
#   'one',
#   'candidate'],
#  ['melissagracey',
#   'credit',
#   'joke',
#   'goes',
#   'someone',
#   'else',
#   'funny',
#   'gopdebate',
#   'http',
#   'co',
#   'icredssplr'],
#  ['reince',
#   'simply',
#   'incredible',
#   'http',
#   'co',
#   'apxm8ao8jf',
#   'last',
#   'night',
#   'gopdebate',
#   'doubled',
#   'previous',
#   'record',
#   'watched',
#   'primary',
#   'debate'],
#  ['katethomas',
#   'literally',
#   'true',
#   'watched',
#   'gopdebate',
#   'amp',
#   'got',
#   'lousy',
#   'hangover',
#   'http',
#   'co',
#   'cxch7x'],
#  ['fl',
#   'dreamer',
#   'haha',
#   'little',
#   'saas',
#   'voxdotcom',
#   'morning',
#   'towards',
#   'realdonaldtrump',
#   'factchecked',
#   'gopdebate',
#   'http',
#   'co',
#   'daectmllaj'],
#  ['texascruzn',
#   'allenwestrepub',
#   'dear',
#   'jebbush',
#   'gopdebate',
#   'notamistake',
#   'http',
#   'co',
#   '1z3vufjzlw'],
#  ['zellieimani',
#   'people',
#   'saw',
#   'person',
#   'vs',
#   'saw',
#   'tv',
#   'gopdebate',
#   'http',
#   'co',
#   'qlgsxrh5hw'],
#  ['thebaxterbean',
#   'marco',
#   'rubio',
#   'told',
#   'face',
#   'candidate',
#   'yesterday',
#   'anti',
#   'gay',
#   'bigotry',
#   'http',
#   'co',
#   'a4eiuettlf',
#   'gopdebate',
#   'ht'],
#  ['cariisie',
#   'none',
#   'made',
#   'trump',
#   'look',
#   'place',
#   'foolish',
#   'yet',
#   'think',
#   'done',
#   'crying',
#   'think',
#   'agai'],
#  ['akbarjenkins',
#   'maybe',
#   'gop',
#   'got',
#   'piven',
#   'amp',
#   'cloward',
#   'confused',
#   'pinkard',
#   'amp',
#   'bowden',
#   'thinks',
#   'steal',
#   'cars',
#   'kevinbaker',
#   'kevinmkr'],
#  ['great',
#   'time',
#   'watching',
#   'gopdebate',
#   'last',
#   'night',
#   'http',
#   'co',
#   'qcmxmu8mlp'],
#  ['jrehling',
#   'gopdebate',
#   'donald',
#   'trump',
#   'says',
#   'time',
#   'political',
#   'correctness',
#   'calling',
#   'women',
#   'fat',
#   'pigs',
#   'save'],
#  ['theonlyadult',
#   'potus',
#   'one',
#   'people',
#   'tv',
#   'might',
#   'next',
#   'one',
#   'rip',
#   'everything',
#   'gopdebate',
#   'http',
#   'co'],
#  ['think',
#   'realdonaldtrump',
#   'caught',
#   'surprise',
#   'first',
#   'question',
#   'never',
#   'able',
#   'recover',
#   'equilibrium',
#   'gopdebate'],
#  ['kirahoffy',
#   'foxnews',
#   'web',
#   'stream',
#   'mobile',
#   'app',
#   'fail',
#   'gopdebate',
#   'surprised',
#   'http',
#   'co',
#   'tkpesooezt'],
#  ['johnkasich',
#   'john',
#   'kasich',
#   'helped',
#   'ohioans',
#   'create',
#   '350',
#   '000',
#   'new',
#   'jobs',
#   'america',
#   'gopdebate',
#   'http',
#   'co',
#   'kbzfbjyp2c'],
#  ['please',
#   'help',
#   'maryknoll',
#   'sisters',
#   'replace',
#   'windows',
#   'convent',
#   'https',
#   'co',
#   'fdgxg3vv13',
#   'catholic',
#   'gofundme',
#   'trcot',
#   'gopdebate'],
#  ['carlyfiorina',
#   'gopdebate',
#   'largest',
#   'audience',
#   'yet',
#   'chip',
#   '3',
#   'help',
#   'us',
#   'keep',
#   'https',
#   'co',
#   'nzync1jrxs',
#   'http'],
#  ['trump',
#   'said',
#   'jebbush',
#   'true',
#   'gentleman',
#   'amp',
#   'started',
#   'violently',
#   '69ing',
#   'gopdebate'],
#  ['cameronesposito',
#   'ugh',
#   'guys',
#   'ever',
#   'shut',
#   'much',
#   'respect',
#   'women',
#   'gopdebate'],
#  ['snarkydemo',
#   'gopdebate',
#   'teach',
#   'us',
#   'future',
#   'president',
#   'trump',
#   'america',
#   'probably',
#   'safe',
#   'except',
#   'attacked'],
#  ['congoboy',
#   'going',
#   'long',
#   'tiring',
#   'election',
#   'season',
#   'shockingly',
#   'ill',
#   'informed',
#   'candidates',
#   'gopdebate',
#   'http',
#   'co',
#   'vtk1k0txi'],
#  ['amymek',
#   'god',
#   'blessed',
#   'republican',
#   'party',
#   'many',
#   'great',
#   'candidates',
#   'thedemocrats',
#   'even',
#   'find',
#   'one',
#   'marcorubio',
#   'gopdebate'],
#  ['johnkasich',
#   'miracle',
#   'happen',
#   'grow',
#   'opportunity',
#   'grow',
#   'jobs',
#   'gopdebate',
#   'http',
#   'co',
#   'lnqhdgtudk'],
#  ['mattyiceaz', 'scott', 'walker', 'even', 'carry', 'state', 'gopdebate'],
#  ['xlnb',
#   'black',
#   'people',
#   'need',
#   'anymore',
#   'indication',
#   'republicans',
#   'hate',
#   'us',
#   'peep',
#   'gopdebate',
#   'http',
#   'co',
#   'bh0chsy5eh'],
#  ['smethanie',
#   'sure',
#   'god',
#   'told',
#   'run',
#   'tooth',
#   'fairy',
#   'agreed',
#   'teletubbies',
#   'voted',
#   'yes',
#   'gopdebate'],
#  ['palmaceiahome1',
#   'trump',
#   'told',
#   'megyn',
#   'kelly',
#   'go',
#   'hell',
#   'foxnews',
#   'gopdebate'],
#  ['palmaceiahome1',
#   'caller',
#   'rush',
#   'limbaugh',
#   'show',
#   'lost',
#   'respect',
#   'fox',
#   'news',
#   'foxnews',
#   'gopdebate'],
#  ['realdonaldtrump',
#   'stinger',
#   'inc',
#   'realdonaldtrump',
#   'megynkelly',
#   'behaviour',
#   'gopdebate',
#   'astonishingly',
#   'biased'],
#  ['republicans',
#   'debate',
#   'economics',
#   'rubio',
#   'wins',
#   'bush',
#   'falters',
#   'huckabee',
#   'exaggerates',
#   'http',
#   'co',
#   'molloaqhwq',
#   'gopdebate',
#   'knowmorenotless',
#   'gpnaplang'],
#  ['jamesviser',
#   'huh',
#   'half',
#   'clinton',
#   'charity',
#   'went',
#   'clintons',
#   'http',
#   'co',
#   'bvwrosgwal',
#   'copolitics',
#   'hillary2016',
#   'stophillary',
#   'uniteb'],
#  ['kraig4u',
#   'gopdebate',
#   'order',
#   'take',
#   'trump',
#   'wonder',
#   'fox',
#   'news',
#   'one',
#   'took',
#   'order',
#   'seriously',
#   'heidil',
#   'rn'],
#  ['diegouk',
#   'democrats',
#   'watching',
#   'gopdebate',
#   'last',
#   'night',
#   'http',
#   'co',
#   '7v4wjok3vm',
#   'p2',
#   'ctl',
#   'topprog',
#   'tcot',
#   'tlot'],
#  ['amymek',
#   'owe',
#   'realdonaldtrump',
#   'huge',
#   'thank',
#   '4',
#   'exposing',
#   'world',
#   'megynkelly',
#   'chris',
#   'wallace',
#   'amp',
#   'frankluntz',
#   'true',
#   'rhinos'],
#  ['thebaxterbean',
#   'scott',
#   'walker',
#   'lies',
#   'says',
#   'wi',
#   'budget',
#   '535m',
#   'surplus',
#   'actually',
#   '1',
#   '76b',
#   'deficit',
#   'http',
#   'co',
#   'vvmxzkxlkr',
#   'gopdebate',
#   'http'],
#  ['right',
#   'last',
#   'heard',
#   'sensanders',
#   'women',
#   'could',
#   'give',
#   'birth',
#   'child',
#   'changed',
#   'gopdebate',
#   'https',
#   'co',
#   '5hkcefp1hf'],
#  ['pattonoswalt',
#   'received',
#   'word',
#   'god',
#   'soup',
#   'sandwich',
#   'crazy',
#   'gopdebate'],
#  ['frankconniff',
#   'fox',
#   'news',
#   'gopdebate',
#   'interviewer',
#   'candidates',
#   'take',
#   'gop',
#   'talking',
#   'points',
#   'feeding'],
#  ['lesliemac',
#   'murder',
#   'black',
#   'ppl',
#   'fine',
#   'unborn',
#   'black',
#   'babies',
#   'goplogic',
#   'gopdebate'],
#  ['hillaryclinton',
#   'missing',
#   'jon',
#   'stewaalready',
#   'gopdebate',
#   'jonvoyage',
#   'h'],
#  ['charlottelaws', 'chris', 'christie', 'really', 'standing', 'gopdebate'],
#  ['libertyjibbet',
#   'hey',
#   'realdonaldtrump',
#   'know',
#   'whine',
#   'unfair',
#   'questions',
#   'carlyfiorina',
#   'grow',
#   'set',
#   'ya',
#   'gopde'],
#  ['pro',
#   'life',
#   'watched',
#   '2',
#   'hour',
#   'abortion',
#   'last',
#   'night',
#   'gopdebate',
#   'forkedtongue',
#   'iseeorangepeople'],
#  ['danscavino',
#   'megynkelly',
#   'failed',
#   'american',
#   'people',
#   'tonight',
#   'tried',
#   'make',
#   'history',
#   'destroying',
#   'realdonaldtrump',
#   'kellyfai'],
#  ['edstetzer',
#   'btw',
#   'mix',
#   'politics',
#   'religion',
#   'get',
#   'politics',
#   'gopdebate'],
#  ['teammarco',
#   'marco',
#   'nailed',
#   'abortion',
#   'must',
#   'protect',
#   'life',
#   'gopdebate',
#   'http',
#   'co',
#   'nn6s7do22j'],
#  ['megynkelly',
#   'bretbaier',
#   'foxnews',
#   'wtf',
#   'chris',
#   'wallace',
#   'attacking',
#   'trump2016',
#   'bankruptcy',
#   'giving',
#   'rubio',
#   'softball',
#   'gopdebate'],
#  ['obviously',
#   'get',
#   'memo',
#   'seersuckerthursday',
#   'gopdebate',
#   'http',
#   'co',
#   'lzagrrtzfl'],
#  ['vh1',
#   'honestly',
#   'donald',
#   'trump',
#   'types',
#   'petty',
#   'last',
#   'night',
#   'gopdebate',
#   'gt',
#   'http',
#   'co',
#   'qxdoemfuqo',
#   'http',
#   'co',
#   'mcr6lrjh2h'],
#  ['tuxcedocat',
#   'republican',
#   'dopefuls',
#   'say',
#   'take',
#   'us',
#   'back',
#   '2009',
#   'day',
#   'one',
#   'never',
#   'see',
#   'one',
#   'day',
#   'white',
#   'house',
#   'gopdebate'],
#  ['trump',
#   'gloating',
#   'abt',
#   'buying',
#   'gop',
#   'dem',
#   'pols',
#   'amp',
#   'bidding',
#   '2000s',
#   'billionaire',
#   'caricature',
#   'myacash',
#   'gopdebate',
#   'https',
#   'co',
#   '5spmu3csic'],
#  ['peddoc63',
#   'go',
#   'carly',
#   'go',
#   'carly',
#   'go',
#   'carly',
#   'carlyfiorina',
#   'carly2016',
#   'gopdebate',
#   'flyoverculture',
#   'leahr77',
#   'steph93065',
#   'maydnusa',
#   'http',
#   'co'],
#  ['daenerys', 'listening', 'gopdebate', 'like', 'http', 'co', '3jrcuqdafu'],
#  ['scorpionspriest',
#   'best',
#   'moment',
#   'gopdebate',
#   'last',
#   'night',
#   'rand',
#   'telling',
#   'christie',
#   'go',
#   'get',
#   'another',
#   'hug',
#   'obama'],
#  ['johnfugelsang',
#   'missed',
#   'either',
#   'gopdebate',
#   'need',
#   'know',
#   'struggling',
#   'americans',
#   'unlimited',
#   'war'],
#  ['pfikac',
#   'jebbush',
#   'verge',
#   'greatest',
#   'time',
#   'alive',
#   'world',
#   'washington',
#   'holding',
#   'us',
#   'back',
#   'mysa',
#   'txlege'],
#  ['drmartyfox',
#   'trump',
#   'wins',
#   'drudge',
#   'debate',
#   'poll',
#   'landslide',
#   'tedcruz',
#   '2',
#   'gopdebate',
#   'pjnet',
#   'http',
#   'co',
#   'yuh6j7qqha',
#   'http'],
#  ['siteroi',
#   'governorperry',
#   'fights',
#   'back',
#   'abt',
#   'immigration',
#   'q',
#   'says',
#   'border',
#   'porous',
#   'must',
#   'fixed',
#   'first'],
#  ['summary', 'gopdebate', 'status', 'quo', 'shit', 'show'],
#  ['thepatriot143',
#   'debbie',
#   'blocks',
#   'tweeter',
#   'questioned',
#   'dem',
#   'debate',
#   'schedule',
#   'http',
#   'co',
#   'gxna0toqaq',
#   'gopdebate',
#   'dwstweets',
#   'http',
#   'co',
#   'kxikf'],
#  ['sallykohn',
#   'hey',
#   'look',
#   '10',
#   'men',
#   'standing',
#   'stage',
#   'arguing',
#   'get',
#   'control',
#   'women',
#   'bodies',
#   'choices',
#   'gopdebate'],
#  ['thebaxterbean',
#   'rubio',
#   'budget',
#   'raises',
#   'middleclass',
#   'taxes',
#   'adds',
#   '4',
#   '5t',
#   'deficit',
#   'cuts',
#   'investmenttax',
#   '0',
#   'http',
#   'co',
#   '9s9nuvsaf7',
#   'gopdebate',
#   'ht'],
#  ['chrisjzullo',
#   'last',
#   'night',
#   'gopdebate',
#   'saw',
#   'bunch',
#   'rich',
#   'old',
#   'despots',
#   'zero',
#   'solutions',
#   'nations',
#   'problems',
#   'un'],
#  ['nancyosborne180',
#   'gopdebate',
#   'batsask',
#   'badassteachersa',
#   'tbats',
#   'debate',
#   'learned',
#   'nothing',
#   'new',
#   'http',
#   'co',
#   'vmtnri7xev',
#   'http',
#   'co',
#   '6mt'],
#  ['rfhkerry', 'think', 'people', 'qualified', 'unfollow', 'gopdebate'],
#  ['bipartisanism',
#   'ben',
#   'carson',
#   'spoke',
#   'science',
#   'gopdebate',
#   'neiltyson',
#   'like',
#   'http',
#   'co',
#   'byooh7i3n6'],
#  ['real',
#   'illegal',
#   'alien',
#   'gopdebate',
#   'farrakhan',
#   'immigration',
#   'mexican',
#   'bor',
#   'https',
#   'co',
#   'lklffn2lfy',
#   'via',
#   'youtube'],
#  ['gopdebate',
#   'talking',
#   'heads',
#   'put',
#   'debate',
#   'talking',
#   'heads',
#   'telling',
#   'us',
#   'debates',
#   'went',
#   'maybe',
#   'wasted',
#   'time',
#   'watching'],
#  ['steel5757',
#   'donaldtrump',
#   'plaza',
#   'casino',
#   'teddybear',
#   'plush',
#   'tuxedo',
#   'http',
#   'co',
#   'qhttx0pldg',
#   'coolstuff',
#   'gopdebate',
#   'http',
#   'co',
#   'qjunzjy'],
#  ['trump',
#   'right',
#   'megynkelly',
#   'really',
#   'needs',
#   'study',
#   'matthew',
#   '7',
#   'verses',
#   '3',
#   '5',
#   'gopdebate',
#   'https',
#   'co',
#   'ygnprhiehv'],
#  ['ac360',
#   'donaldtrump',
#   'memorable',
#   'gopdebate',
#   'moments',
#   'right',
#   'ac360',
#   'http',
#   'co',
#   'kdnhgj2ry3',
#   'http',
#   'co',
#   'hz9gwe'],
#  ['gopdebate', 'one', 'picture', 'http', 'co', 'wmmucjuqju'],
#  ['maureenjohnson',
#   'think',
#   'women',
#   'sleep',
#   'curse',
#   'shed',
#   'open',
#   'field',
#   'property'],
#  ['think',
#   'god',
#   'pretty',
#   'fair',
#   'guy',
#   'ben',
#   'carson',
#   'neurosurgeon',
#   'belief',
#   'modern',
#   'day',
#   'taxation',
#   'based',
#   'ancient',
#   'book',
#   'gopdebate'],
#  ['nancyleegrahn',
#   'cheers',
#   'gopdebate',
#   'audience',
#   'aftertrump',
#   'defiantly',
#   'named',
#   'rosie',
#   'woman',
#   'called',
#   'fat',
#   'pig',
#   'voices'],
#  ['blacklives',
#   'matter',
#   'apparently',
#   'republican',
#   'candidates',
#   'president',
#   'http',
#   'co',
#   '8rfevfwsxx',
#   'foxnews',
#   'uniteblue',
#   'gopdebate'],
#  ['overall',
#   'main',
#   'thing',
#   'learned',
#   'gopdebate',
#   'straight',
#   'white',
#   'men',
#   'matter'],
#  ['usfree4life',
#   'thought',
#   'seanhannity',
#   'best',
#   'post',
#   'gopdebate',
#   'interviews',
#   'night',
#   'gave',
#   'chance',
#   '2straighten',
#   'position'],
#  ['johnkasich',
#   'hey',
#   'realdonaldtrump',
#   'still',
#   'looking',
#   'chip',
#   'check',
#   'http',
#   'co',
#   'dy8knz122t',
#   'gopdebate'],
#  ['megynkelly',
#   'bretbaier',
#   'chriswallace',
#   'america',
#   'criticizing',
#   'ur',
#   'performances',
#   'gopdebate',
#   'b',
#   'c',
#   'u',
#   'really',
#   'bad',
#   'job',
#   'moderators'],
#  ['govmikehuckabee',
#   'luntz',
#   'lines',
#   'go',
#   'almost',
#   'reach',
#   '100',
#   'almost',
#   'never',
#   'happens',
#   'dial',
#   'research',
#   'gopdebate',
#   'rigged'],
#  ['oftenimprudent',
#   'wish',
#   'could',
#   'teach',
#   'teenage',
#   'girls',
#   'love',
#   'much',
#   'donald',
#   'trump',
#   'loves',
#   'gopdebate'],
#  ['amymek',
#   'conservatives',
#   'people',
#   'without',
#   'network',
#   'gopdebate',
#   'foxnews'],
#  ['bhowl',
#   'come',
#   'talk',
#   'climate',
#   'change',
#   'anyone',
#   'even',
#   'seen',
#   'california',
#   'right',
#   'gopdebate',
#   'debatewithbernie'],
#  ['travisconsidine',
#   'governorperry',
#   'gopdebate',
#   'performance',
#   'review',
#   'reel',
#   'https',
#   'co',
#   'o5qurozbku',
#   'perry2016'],
#  ['chrisjzullo',
#   'last',
#   'night',
#   'could',
#   'raised',
#   'hands',
#   'spoiled',
#   'billionaire',
#   'oligarch',
#   'racist',
#   'religi'],
#  ['gopdebate',
#   '2016',
#   'teamdrbencarson',
#   'realbencarson',
#   'wow',
#   'brilliant',
#   'cool',
#   'calm',
#   'amp',
#   'collected',
#   'empowering'],
#  ['soopermexican',
#   'ted',
#   'cruz',
#   'appreciate',
#   'emphatically',
#   'sarcastic',
#   'air',
#   'quotes',
#   'megan',
#   'kelly',
#   'gopdebate'],
#  ['benjamminwalker',
#   'circumstances',
#   '10',
#   'men',
#   'dictate',
#   'abortion',
#   'rights',
#   'women',
#   '21st',
#   'century',
#   'better'],
#  ['danscavino',
#   'gopdebate',
#   'winner',
#   'drudge',
#   '50',
#   '187k',
#   'realdonaldtrump',
#   'time',
#   '46',
#   '25k',
#   'realdonaldtrump',
#   'foxsd',
#   '49',
#   'realdonaldtrump',
#   'http'],
#  ['joeprich',
#   'megynkelly',
#   '2012',
#   'chided',
#   'candycrowley',
#   'going',
#   'objective',
#   'moderator',
#   'active',
#   'participant',
#   'gopdebate',
#   'http'],
#  ['gopdebate',
#   'foxnews',
#   'realdonaldtrump',
#   'in1996',
#   'called',
#   'billclinton',
#   'two',
#   'timing',
#   'slut',
#   'stand',
#   'statement'],
#  ['renomarky',
#   'never',
#   'watch',
#   'kellyfile',
#   '1',
#   'gopdebate',
#   'questions',
#   '2',
#   'pandering',
#   'dwstweets',
#   '3',
#   'making',
#   'ratings',
#   'http'],
#  ['imho',
#   'gopdebate',
#   'winners',
#   'marcorubio',
#   'kasich',
#   'donaldtrump',
#   'losers',
#   'scottwalker',
#   'randpaul',
#   'bencarson',
#   'others',
#   'completely',
#   'forgettable'],
#  ['johnkasich',
#   'smaller',
#   'govt',
#   'ohio',
#   'government',
#   'payroll',
#   'smaller',
#   '3',
#   'decades',
#   'http',
#   'co',
#   'igfif4j1tt',
#   'gopdebate',
#   'http',
#   'co'],
#  ['zellieimani',
#   'twitter',
#   'users',
#   'takeover',
#   'gopdebate',
#   'hashtag',
#   'drag',
#   'gop',
#   'candidates',
#   'https',
#   'co',
#   'lmznompfmw',
#   'kkkorgop',
#   'http',
#   'co',
#   'ewez899a0c'],
#  ['jebbush',
#   'challenging',
#   'teacher',
#   'unions',
#   'beating',
#   'way',
#   'go',
#   'jeb',
#   'http',
#   'co',
#   '5imgwdrl4g',
#   'gopdebate'],
#  ['billyeichner',
#   'thank',
#   'watching',
#   'gopdebate',
#   'tonight',
#   'julieklausner',
#   'blast',
#   'writing'],
#  ['theblaze',
#   'real',
#   'war',
#   'women',
#   'realdonaldtrump',
#   'megynkelly',
#   'rushlimbaugh',
#   'gopdebate',
#   'anncoulter'],
#  ['governorperry',
#   'governorperry',
#   'fire',
#   'debate',
#   'performance',
#   'https',
#   'co',
#   'armjn6vwpg',
#   'gopdebate',
#   'perry2016',
#   'tcot'],
#  ['blowticious',
#   'pro',
#   'life',
#   'republicans',
#   'like',
#   'gopdebate',
#   'http',
#   'co',
#   'bioxoplejn'],
#  ['governorperry',
#   'icymi',
#   'governorperry',
#   'border',
#   'security',
#   'illegal',
#   'immigration',
#   'gopdebate',
#   'perry2016',
#   'tcot',
#   'https',
#   'co',
#   '1s25d2d0nk'],
#  ['allthingsflynn',
#   'trump',
#   'vs',
#   'fox',
#   'news',
#   'conflict',
#   'quite',
#   'conundrum',
#   'like',
#   'personification',
#   'greed',
#   'vs',
#   'hate',
#   'root'],
#  ['carlyfiorina', 'know', 'extraordinary', 'nation', 'gopdebate'],
#  ['laxnoreos',
#   'meanwhile',
#   'white',
#   'house',
#   'gopdebate',
#   'http',
#   'co',
#   'mfs7ixfovc'],
#  ['rubio',
#   'still',
#   'preference',
#   'see',
#   'point',
#   'critics',
#   'opportunism',
#   'inconsistency',
#   'gopdebate'],
#  ['realdonaldtrump',
#   'ever',
#   'tell',
#   'megynkelly',
#   'go',
#   'wait',
#   'car',
#   'bad',
#   'attitude',
#   'suggests',
#   'waronwomen',
#   'gopdebate'],
#  ['thetexasphoenix',
#   'fire',
#   'governorperry',
#   'fire',
#   'debate',
#   'performance',
#   'https',
#   'co',
#   '0a1w02w7sz',
#   'gopdebate',
#   'perry2016'],
#  ['playing', 'dad', 'settling', 'gopdebate', 'http', 'co', 'w6w3e5nboa'],
#  ['realdonaldtrump',
#   'frankluntz',
#   'getting',
#   'lot',
#   'megynkelly',
#   'hatemail',
#   'tonight',
#   'gopdebate',
#   'totally',
#   'overrated',
#   'angry'],
#  ['literally',
#   'true',
#   'watched',
#   'gopdebate',
#   'amp',
#   'got',
#   'lousy',
#   'hangover',
#   'http',
#   'co',
#   'cxch7xxq1v',
#   'robinmarty'],
#  ['jonvoyage', 'half', 'long', 'gopdebate', 'twice', 'intelligible'],
#  ['lisabloom',
#   'single',
#   'question',
#   'last',
#   'night',
#   'gopdebate',
#   'urgent',
#   'issue',
#   'time',
#   'climate',
#   'change'],
#  ['gopdebate',
#   'foxnews',
#   'amp',
#   'gotcha',
#   'questions',
#   'seemed',
#   'designed',
#   'elicit',
#   'typical',
#   'political',
#   'spin',
#   'responses',
#   'tlot'],
#  ['gopdebate',
#   'promises',
#   'made',
#   'startups',
#   'tech',
#   'conference',
#   'seem',
#   'quite',
#   'reasonable'],
#  ['roy',
#   'rogers',
#   'knuckldraginsam',
#   'gop',
#   'realdonaldtrump',
#   'yobynnad1127',
#   'amen',
#   'trump2016',
#   'wakeupamerica',
#   'gopdebate',
#   'tcot',
#   'stoprush',
#   'http'],
#  ['carlyfiorina',
#   'highest',
#   'calling',
#   'leadership',
#   'challenge',
#   'status',
#   'quo',
#   'amp',
#   'unlock',
#   'potential',
#   'others',
#   'gopdebate',
#   'carly2016'],
#  ['zzcrane',
#   'watching',
#   'donald',
#   'trump',
#   'bandwagon',
#   'pass',
#   'tlot',
#   'tcot',
#   'gopdebate',
#   'http',
#   'co',
#   'wvqlsxgmcl'],
#  ['deray',
#   'gopdebate',
#   'began',
#   'moderators',
#   'say',
#   '8',
#   'million',
#   'ppl',
#   'discussing',
#   'racial',
#   'issues',
#   'happened',
#   'thos'],
#  ['feministabulous',
#   'nothing',
#   'like',
#   'listening',
#   'ten',
#   'dudes',
#   'never',
#   'need',
#   'abortion',
#   'talk',
#   'whether',
#   'right'],
#  ['senwhitehouse',
#   'fox',
#   'silenced',
#   'koch',
#   'billions',
#   'single',
#   'question',
#   'last',
#   'night',
#   'gopdebate',
#   'climatechange',
#   'deniers',
#   'mond'],
#  ['tyriquex',
#   'republicans',
#   'rich',
#   'care',
#   'poverty',
#   'america',
#   'amp',
#   'definitely',
#   'care',
#   'bout',
#   'poverty',
#   'bla'],
#  ['office',
#   'chat',
#   'gopdebate',
#   'amp',
#   'outed',
#   'flaming',
#   'liberal',
#   'politics',
#   'geek',
#   'probably',
#   'surprising'],
#  ['catching',
#   'gopdebate',
#   'lindseygrahamsc',
#   'childish',
#   'amp',
#   'cheap',
#   'move',
#   'call',
#   'billclinton',
#   'amp',
#   'hillaryclinton',
#   '17',
#   'year',
#   'old',
#   'story'],
#  ['tomhall',
#   'thing',
#   'could',
#   'made',
#   'last',
#   'night',
#   'gopdebate',
#   'amusing',
#   'would',
#   'cowbells',
#   'morecowbells',
#   'http',
#   'co'],
#  ['kesgardner', 'ted', 'cruz', 'attack', 'republicans', 'gopdebate'],
#  ['governorperry',
#   'icymi',
#   'hell',
#   'irandeal',
#   'gopdebate',
#   'perry2016',
#   'tcot',
#   'https',
#   'co',
#   'kqhjdjcgws'],
#  ['frankconniff', 'hard', 'say', 'gopdebate', 'bernie', 'hillary'],
#  ['larhunter',
#   'donald',
#   'trump',
#   'wins',
#   'election',
#   'know',
#   'biff',
#   'stole',
#   'almanac',
#   'timeline',
#   'gopdebate'],
#  ['carlyfiorina',
#   'chip',
#   '3',
#   'keep',
#   'momentum',
#   'going',
#   'gopdebate',
#   'carly2016',
#   'https',
#   'co',
#   'w3mtcmr7ze'],
#  ['cenkuygur',
#   'chris',
#   'christie',
#   'said',
#   'work',
#   'two',
#   'years',
#   'retiring',
#   'get',
#   'tens',
#   'thousands',
#   'less',
#   'paid'],
#  ['johnkasich',
#   'john',
#   'kasich',
#   'ready',
#   'lead',
#   'join',
#   'team',
#   'claire',
#   'http',
#   'co',
#   'dy8knz122t',
#   'gopdebate',
#   'https',
#   'co',
#   'knwmideqty'],
#  ['edwrather',
#   'biggest',
#   'losers',
#   'debate',
#   'fox',
#   'moderators',
#   'attacked',
#   'instead',
#   'moderating',
#   'gopdebate'],
#  ['whitneyneal',
#   'trump',
#   'yet',
#   'give',
#   'single',
#   'evidence',
#   'based',
#   'answer',
#   'direct',
#   'question',
#   'policy',
#   'frighten',
#   'gopdeb'],
#  ['way',
#   'studio',
#   'appear',
#   'cnn',
#   'discuss',
#   'last',
#   'night',
#   'gopdebate',
#   'tune'],
#  ['blkfeminst',
#   'honestly',
#   'think',
#   'sometimes',
#   'guys',
#   'forgot',
#   'came',
#   'wombs',
#   'kkkorgop',
#   'gopdebate',
#   'https',
#   'co',
#   'fo3a6dxflf'],
#  ['grneyedmandy',
#   'women',
#   'shame',
#   'women',
#   'abortions',
#   'deserve',
#   'shamed',
#   'soul',
#   'self',
#   'respect',
#   'plannedparen'],
#  ['amandajogomez',
#   'watches',
#   'gopdebate',
#   'looks',
#   'directly',
#   'camera',
#   'like',
#   'office'],
#  ['icaruspundit',
#   'donald',
#   'trump',
#   'closing',
#   'statement',
#   'every',
#   'dinner',
#   'conversation',
#   'villages',
#   'ever',
#   'gopdebate'],
#  ['thexclass',
#   'rich',
#   'wage',
#   'war',
#   'poor',
#   'die',
#   'jean',
#   'paul',
#   'sartre',
#   'gop',
#   'foreign',
#   'policy',
#   'gopdebate'],
#  ['gopdebate',
#   'saw',
#   'candidates',
#   'completely',
#   'miss',
#   'mark',
#   'race',
#   'amp',
#   'blacklivesmatter',
#   'http',
#   'co',
#   'k9nhdpue32',
#   'http',
#   'co',
#   'hlcqpxjzru'],
#  ['seabassthephish',
#   'gop',
#   'proud',
#   'defeating',
#   'teachers',
#   'union',
#   'even',
#   'though',
#   'wanted',
#   'higher',
#   'wages',
#   'gopdebate'],
#  ['writeintrump',
#   'obama',
#   'better',
#   'leave',
#   'prayer',
#   'rug',
#   'behind',
#   'oval',
#   'office',
#   'get',
#   'elected',
#   'throw',
#   'gopdebate'],
#  ['chucknellis', 'foxnews', 'got', 'right', 'gopdebate'],
#  ['mrskimcam',
#   'trump',
#   'said',
#   'u',
#   'stupid',
#   'let',
#   'vote',
#   'president',
#   'wtf',
#   'people',
#   'gopdebate'],
#  ['excited',
#   'johnkasich',
#   'gopdebate',
#   'kasich4us',
#   'republicandebate',
#   'kasich2016',
#   'waiting',
#   '20',
#   'years'],
#  ['chadpergram',
#   'rep',
#   'engel',
#   '2nd',
#   'major',
#   'jewish',
#   'democrat',
#   'announce',
#   'opposition',
#   'iran',
#   'deal',
#   'gopdebate',
#   'following',
#   'schumer',
#   'opposition'],
#  ['hey',
#   'look',
#   'feelings',
#   'donald',
#   'trump',
#   'summed',
#   'one',
#   'gif',
#   'gopdebate',
#   'http',
#   'co',
#   'zjwugwj9hz'],
#  ['tommychong', 'dudes', 'legalization', 'marijuana', 'gopdebate'],
#  ['cberesniova',
#   'learned',
#   'gopdebate',
#   'guy',
#   'dad',
#   'mailman',
#   'jesus',
#   'christ',
#   'everyone',
#   'running',
#   'mate',
#   'gop',
#   'run'],
#  ['thebaxterbean',
#   'marco',
#   'rubio',
#   'briefly',
#   'backed',
#   'immigration',
#   'reform',
#   'privately',
#   'berated',
#   'dreamers',
#   'http',
#   'co',
#   'we77qdt3kt',
#   'gopdebate',
#   'http'],
#  ['damienfahey',
#   'french',
#   'kissed',
#   'jesus',
#   'christ',
#   'every',
#   'candidate',
#   'gopdebate'],
#  ['gopdebate',
#   'closingstatements',
#   'govmikehuckabee',
#   'honest',
#   'u',
#   'defs',
#   'talking',
#   'realdonaldtrump',
#   'coz',
#   'stealing',
#   'ur',
#   'schtick'],
#  ['cnn',
#   'msnbc',
#   'new',
#   'york',
#   'times',
#   'praise',
#   'fox',
#   'moderators',
#   'know',
#   'moderators',
#   'fucked',
#   'gopdebate'],
#  ['kesgardner', 'trump', 'lunatic', 'gopdebate'],
#  ['cruz', 'class', 'amp', 'truth', 'gets', 'vote', 'gopdebate'],
#  ['kesgardner',
#   'assclown',
#   'reason',
#   'anyone',
#   'even',
#   'talking',
#   'illegal',
#   'immigration',
#   'keep',
#   'digging',
#   'donald',
#   'gopdebate'],
#  ['berniesanders',
#   'tom',
#   'hanks',
#   'finally',
#   'somebody',
#   'makes',
#   'sense',
#   'gopdebate',
#   'debatewithbernie'],
#  ['southernhomo', 'olivia', 'pope', 'would', 'vote', 'guys', 'gopdebate'],
#  ['gop',
#   'candidates',
#   'want',
#   'reduce',
#   'taxes',
#   'huckabee',
#   'wants',
#   'legalize',
#   'prostitution',
#   'drugs',
#   'tax',
#   'gopdebate'],
#  ['kesgardner',
#   'hi',
#   'fox',
#   'panel',
#   'ask',
#   'donald',
#   'every',
#   'single',
#   'question',
#   'hand',
#   'shovel',
#   'keep',
#   'digging'],
#  ['josephkapsch',
#   'hillaryclinton',
#   'barackobama',
#   'joebiden',
#   'gopdebate',
#   'https',
#   'co',
#   'yi4qns3hzh'],
#  ['gopdebate',
#   'trump',
#   'breaking',
#   'records',
#   'polished',
#   'politician',
#   'makes',
#   'love',
#   'even',
#   'https',
#   'co',
#   'tgowchxf3x'],
#  ['berniesanders', 'oh', 'movie', 'trailer', 'gopdebate', 'debatewithbernie'],
#  ['tacticaldissent',
#   'sally',
#   'kohn',
#   'amp',
#   'debbie',
#   'wasserman',
#   'schultz',
#   'praising',
#   'megyn',
#   'kelly',
#   'tonight',
#   'tell',
#   'everything',
#   'need'],
#  ['trump',
#   'accessory',
#   'women',
#   'wearing',
#   'shoes',
#   'gopdebate',
#   'http',
#   'co',
#   'xz4zc1lt8n'],
#  ['funniest',
#   'line',
#   'coming',
#   'fr',
#   'republican',
#   'people',
#   'frustrated',
#   'fed',
#   'think',
#   'government',
#   'working',
#   'gopdebate'],
#  ['donald', 'trump', 'absolute', 'nut', 'entertaining', 'lol', 'gopdebate'],
#  ['thehill',
#   'top',
#   'gop',
#   'pundits',
#   'pick',
#   'gopdebate',
#   'winners',
#   'http',
#   'co',
#   'qpvju6p7sz',
#   'http',
#   'co',
#   'jcdu5qzjnj',
#   'winners',
#   'fox',
#   'news',
#   'losers',
#   'usa'],
#  ['dykstradame',
#   'candidates',
#   'went',
#   'hillaryclinton',
#   '32',
#   'times',
#   'gopdebate',
#   'remained',
#   'silent',
#   'issues',
#   'affect',
#   'us',
#   'http'],
#  ['danscavino',
#   'megynkelly',
#   'trying',
#   '2show',
#   'realdonaldtrump',
#   'w',
#   'foxnews',
#   'trying',
#   '2take',
#   'trying',
#   '2destroy',
#   'happening',
#   'kelly'],
#  ['gov',
#   'tweeted',
#   'gopdebate',
#   'moment',
#   'realbencarson',
#   'saying',
#   'publicize',
#   'world',
#   'answer',
#   'waterboarding'],
#  ['give',
#   'e',
#   'big',
#   'ego',
#   'gopdebate',
#   'earned',
#   'excellence',
#   'rhymes',
#   'rump'],
#  ['passion', 'gopdebate', 'religiousupamovie'],
#  ['nro',
#   'marcorubio',
#   'got',
#   'best',
#   'reviews',
#   'deserved',
#   'read',
#   'nreditorial',
#   'recap',
#   'gopdebate',
#   'gt',
#   'http',
#   'co',
#   'stzw'],
#  ['ohnoshetwitnt',
#   'wait',
#   'see',
#   'lannister',
#   'kill',
#   'next',
#   'episode',
#   'gopdebate'],
#  ['kesgardner',
#   'brutal',
#   'question',
#   'assclown',
#   'megan',
#   'kelly',
#   'lesson',
#   'careful',
#   'tweet',
#   'twitter',
#   'gopdebate'],
#  ['tusk81', 'democrats', 'watching', 'gopdebate', 'http', 'co', 'szicslm7km'],
#  ['trump',
#   'changed',
#   'mind',
#   'supporting',
#   'partial',
#   'birth',
#   'abortion',
#   'friend',
#   'changed',
#   'mind',
#   'aborting',
#   'amp',
#   'great',
#   'kid',
#   'gopdebate'],
#  ['best', 'closing', 'statement', 'realbencarson', 'gopdebate'],
#  ['chrischristie',
#   'stop',
#   'worrying',
#   'loved',
#   'amp',
#   'staworrying',
#   'respected',
#   'tellingitlikeitis',
#   'gopdebate',
#   'https'],
#  ['lesleyabravanel',
#   'trump',
#   'sycophants',
#   'want',
#   'know',
#   'megynkelly',
#   'hidden',
#   'agenda',
#   'last',
#   'night',
#   'answer',
#   'simple',
#   'called',
#   'vagin'],
#  ['real',
#   'gopdebate',
#   'winner',
#   'republican',
#   'voters',
#   'fox',
#   'nation',
#   'http',
#   'co',
#   '98g42iaz5o'],
#  ['donald',
#   'trump',
#   'really',
#   'nasty',
#   'piece',
#   'work',
#   'hope',
#   'disappears',
#   'quickly',
#   'gopdebate'],
#  ['amaraconda',
#   'fetuses',
#   'unborn',
#   'babies',
#   'clusters',
#   'cells',
#   'stop',
#   'shaming',
#   'people',
#   'want',
#   'abortions',
#   'gopdebate'],
#  ['mattkbh',
#   'far',
#   'away',
#   'best',
#   'tweets',
#   'last',
#   'night',
#   'debatewithbernie',
#   'gopdebate',
#   'http',
#   'co',
#   'gzdltyumnn'],
#  ['know',
#   'chrischristie',
#   'reminds',
#   'actor',
#   'andy',
#   'devine',
#   'gopdebate',
#   'http',
#   'co',
#   'xyy8fxpjcd'],
#  ['pattonoswalt',
#   'despite',
#   'huckabee',
#   'says',
#   'always',
#   'make',
#   'sure',
#   'prostitute',
#   'pimp',
#   'pay',
#   'fica',
#   'pension',
#   'gopdebate'],
#  ['bipartisanism',
#   'hillary',
#   'clinton',
#   'watching',
#   'gopdebate',
#   'like',
#   'http',
#   'co',
#   'vokolq52xp'],
#  ['foxnews',
#   'great',
#   'challenging',
#   'candidates',
#   'gopdebate',
#   'candidates',
#   'handle',
#   'tough',
#   'question',
#   'could',
#   'never',
#   'b',
#   'potus'],
#  ['k',
#   'mcq',
#   'say',
#   'opposite',
#   'megan',
#   'kelly',
#   'acted',
#   'like',
#   'sjw',
#   'tumblr',
#   'whining',
#   'feminism',
#   'sad',
#   'gopdebate',
#   'https',
#   'c'],
#  ['conssista',
#   'rightly',
#   'frank',
#   'rightly',
#   'gopdebate',
#   'https',
#   'co',
#   '32cfasi17d'],
#  ['number',
#   'times',
#   'ronald',
#   'reagan',
#   'mentioned',
#   'gopdebate',
#   'damn',
#   'high'],
#  ['pattonoswalt',
#   'trump',
#   'p',
#   'c',
#   'culture',
#   'suddenly',
#   '100',
#   'even',
#   'kidding',
#   'howling',
#   'shit',
#   'cave',
#   'human',
#   'gop'],
#  ['carljacksonshow',
#   'bencarson',
#   'great',
#   'close',
#   'operates',
#   'brains',
#   'worry',
#   'skin',
#   'color',
#   'gopdebate'],
#  ['davante',
#   'r',
#   'women',
#   'would',
#   'offended',
#   'trumps',
#   'misogyny',
#   'certainly',
#   'vote',
#   'republican',
#   'find',
#   'new',
#   'fake',
#   'issue',
#   'faux',
#   'news'],
#  ['auntcol54', 'keep', 'religion', 'politics', 'gopdebate'],
#  ['dianneg',
#   'bought',
#   'amp',
#   'sold',
#   'randpaul',
#   'reiterating',
#   'points',
#   'realdonaldtrump',
#   'gopdebate'],
#  ['wilw',
#   'boy',
#   'bet',
#   'mood',
#   'clown',
#   'car',
#   'going',
#   'tense',
#   'jerks',
#   'leave',
#   'gopdebate'],
#  ['campeauelliot',
#   'dr',
#   'ben',
#   'carson',
#   'great',
#   'job',
#   'tonight',
#   'loved',
#   'closing',
#   'statement',
#   'realbencarson',
#   'gopdebate'],
#  ['redheadandright',
#   'meet',
#   'new',
#   'darling',
#   'left',
#   'megyn',
#   'gotcha',
#   'kelly',
#   'gopdebate',
#   'foxnews',
#   'donaldtrump',
#   'megynkelly'],
#  ['foxnewspolitics',
#   'behind',
#   'fox',
#   'debate',
#   'anchors',
#   'hashed',
#   'questions',
#   'gopdebate',
#   'failed'],
#  ['anyone',
#   'get',
#   'trashed',
#   'playing',
#   'rollingstone',
#   'gopdebate',
#   'drinking',
#   'game',
#   'drinkinggame'],
#  ['donaldtrump',
#   'donates',
#   'u',
#   'call',
#   'favor',
#   'years',
#   'later',
#   'sounds',
#   'like',
#   'thegodfather',
#   'potus',
#   'thats',
#   'legal',
#   'gopdebate',
#   'gopclowncar'],
#  ['jediane9',
#   'ugh',
#   'think',
#   'actually',
#   'people',
#   'sitting',
#   'couch',
#   'last',
#   'night',
#   'saying',
#   'yes',
#   'yes',
#   'reasonable',
#   'gopdebate'],
#  ['barracudamama',
#   'allenwestrepub',
#   'dear',
#   'jebbush',
#   'gopdebate',
#   'notamistake',
#   'http',
#   'co',
#   'e1smu0hn5j'],
#  ['kesgardner',
#   'politics',
#   'even',
#   'partially',
#   'rational',
#   'trump',
#   'campaign',
#   'gop',
#   'nomination',
#   'ended',
#   'gopdebate'],
#  ['andrewhclark',
#   'gaypatriot',
#   'takeaway',
#   'last',
#   'night',
#   'america',
#   'deserve',
#   'ben',
#   'carson',
#   'http',
#   'co',
#   'kjgfyypcte',
#   'gopdebate'],
#  ['chrisjzullo',
#   'scott',
#   'walker',
#   'chooses',
#   'killing',
#   'mother',
#   'rather',
#   'aborting',
#   'unborn',
#   'embryo',
#   'reason',
#   'countries',
#   'give',
#   'us',
#   'funny'],
#  ['uniteblue',
#   'abortion',
#   'talking',
#   'point',
#   'gopdebate',
#   'since',
#   'ppsellsbabyparts'],
#  ['k',
#   'mcq',
#   'closing',
#   'statements',
#   'reminisce',
#   'america',
#   'longer',
#   'exists',
#   'ted',
#   'kennedy',
#   '1965',
#   'immigration',
#   'nationality',
#   'act',
#   'g'],
#  ['lkwdcitizen',
#   'make',
#   'chris',
#   'christie',
#   'stopped',
#   'cleveland',
#   'ice',
#   'cream',
#   'shop',
#   'gopdebate',
#   'http',
#   'co',
#   'v8wvyfexx9'],
#  ['maureenjohnson',
#   'ted',
#   'cruz',
#   'going',
#   'personally',
#   'take',
#   'away',
#   'telescope',
#   'try',
#   'witch',
#   'gopdebate'],
#  ['realdonaldtrump',
#   'killed',
#   'last',
#   'night',
#   'gopdebate',
#   'glad',
#   'cares',
#   'america',
#   'makeamericagreatagain'],
#  ['youngblkrepub',
#   'gopdebate',
#   'exciting',
#   'anything',
#   'else',
#   'tv',
#   'past',
#   '10',
#   'years'],
#  ['abbijacobson', 'shiiiittt', 'tough', 'say', 'making', 'horny', 'gopdebate'],
#  ['megynkelly',
#   'asked',
#   'realdonaldtrump',
#   'poor',
#   'questions',
#   'help',
#   'bush',
#   'polls',
#   'hannity',
#   'gopdebate',
#   'https',
#   'co',
#   'p389iile2n'],
#  ['bullriders1',
#   'olivianuzzi',
#   'daveweigel',
#   'gopdebate',
#   'better',
#   'thought',
#   'though',
#   'candidates',
#   'finessed',
#   'issues',
#   'sound',
#   'bytes'],
#  ['thebaxterbean',
#   'yes',
#   'marco',
#   'rubio',
#   'actually',
#   'said',
#   'iraq',
#   'invasion',
#   'mistake',
#   'http',
#   'co',
#   'xrowkhymm1',
#   'gopdebate',
#   'http',
#   'co',
#   'vjmjdm'],
#  ['thebaxterbean',
#   'marco',
#   'rubio',
#   'voted',
#   'unemployment',
#   'benefits',
#   'even',
#   'though',
#   'florida',
#   'needs',
#   'http',
#   'co',
#   '2i6uolsctj',
#   'gopdebate',
#   'ht'],
#  ['jebbush',
#   'thoughtful',
#   'gopdebate',
#   'rethink911',
#   'http',
#   'co',
#   'k37hnbe2jy'],
#  ['thejimhughes',
#   'lot',
#   'jobs',
#   'available',
#   'bush',
#   'serves',
#   '2',
#   'terms',
#   'conservatives',
#   'committed',
#   'suicide',
#   'go'],
#  ['huh',
#   'watching',
#   'foxnews',
#   'debate',
#   '1',
#   'far',
#   'moderators',
#   'participants',
#   'better',
#   'gopdebate'],
#  ['3chicspolitico',
#   'donald',
#   'trump',
#   'insulted',
#   'megynkelly',
#   'women',
#   'one',
#   'man',
#   'stage',
#   'confronted',
#   'none',
#   'worthy'],
#  ['jjauthor',
#   'learjetter',
#   'waiting',
#   'megynkelly',
#   'ask',
#   'realdonaldtrump',
#   'stop',
#   'beating',
#   'wife',
#   'gopdebate',
#   'http'],
#  ['andreatantaros',
#   'last',
#   'night',
#   'watching',
#   'outnumberedfnc',
#   'got',
#   'ericbolling',
#   'good',
#   'stuff',
#   'gopdebate'],
#  ['renomarky',
#   'earth',
#   'megynkelly',
#   'aint',
#   'gopdebate',
#   'foxdebate',
#   'megynkelly',
#   'megynkellydebatequestions',
#   'http',
#   'co',
#   'yxhy'],
#  ['kesgardner',
#   'rand',
#   'paul',
#   'lands',
#   'first',
#   'haymaker',
#   'night',
#   'gopdebate'],
#  ['tarasetmayer',
#   'coming',
#   'wilkowmajority',
#   '1220pm',
#   'live',
#   'siriusxm',
#   'patriot125',
#   'post',
#   'gopdebate'],
#  ['republicans',
#   'like',
#   'rosie',
#   'donnell',
#   'icymi',
#   'frankluntz',
#   'gopdebate',
#   'debrief',
#   'cbsthismorning',
#   'http',
#   'co',
#   'nqiuiccolb'],
#  ['fff',
#   'highlights',
#   'week',
#   'include',
#   'nationalunderwearday',
#   'gopdebate',
#   'jonvoyage',
#   'officially',
#   'worst',
#   'week',
#   'ever',
#   'tgif'],
#  ['greenspaceguy',
#   'thedailyshow',
#   'jon',
#   'stewafeel',
#   'comfortable',
#   'w',
#   'retirement',
#   'gopdebate',
#   'solved',
#   'problems',
#   'personal',
#   'amp',
#   'scientific',
#   'htt'],
#  ['kesgardner',
#   'course',
#   'assclown',
#   'pledge',
#   'run',
#   'third',
#   'party',
#   'candidate',
#   'gopdebate'],
#  ['paul',
#   'krugman',
#   'sums',
#   'happended',
#   'last',
#   'night',
#   'one',
#   'two',
#   'major',
#   'parties',
#   'gone',
#   'deep',
#   'end',
#   'http',
#   'co',
#   'gkubem7ge7',
#   'gopdebate'],
#  ['eqphoto',
#   'remember',
#   'matter',
#   'wins',
#   'gopdebate',
#   'everyone',
#   'watched',
#   'loses',
#   'alcoholpoisoning'],
#  ['anthonymarlowe',
#   'trump',
#   'video',
#   'cost',
#   '4',
#   'times',
#   '700m',
#   'would',
#   'managed',
#   'realdonaldtrump',
#   'gopdebate',
#   'h'],
#  ['megynkelly', 'disgraced', 'last', 'night', 'gopdebate'],
#  ['proginosko',
#   'prediction',
#   'final',
#   'gopdebate',
#   'donald',
#   'trump',
#   'tear',
#   'missionimpossible',
#   'mask',
#   'reveal',
#   'smirking',
#   'jon',
#   'stewart'],
#  ['fallon',
#   'jon',
#   'stewaplease',
#   'come',
#   'back',
#   'alone',
#   'https',
#   'co',
# ...
#   'http',
#   'co',
#   'i4t3c2gmzo',
#   'via',
#   'sfgate'],
#  ['want',
#   'point',
#   'one',
#   'time',
#   'real',
#   'question',
#   'real',
#   'presidential',
#   'debate',
#   'god',
#   'say',
#   'gopdebate'],
#  ['thebaxterbean',
#   'marco',
#   'rubio',
#   'constitutional',
#   'right',
#   'choose',
#   'egregiously',
#   'flawed',
#   'decision',
#   'http',
#   'co',
#   'u63wrh7mxn',
#   'gopdebate',
#   'http'],
#  ['scott',
#   'walker',
#   'wisconsin',
#   'seeing',
#   'fastest',
#   'shrinking',
#   'middle',
#   'class',
#   'america',
#   'http',
#   'co',
#   'zopokedb8l',
#   'gopdebate',
#   'votersfirst',
#   'trump2016'],
#  ['supporters',
#   'seem',
#   'care',
#   'corrupt',
#   'politicians',
#   'calls',
#   'stupid',
#   'gopdebate',
#   'https',
#   'co',
#   '8jnmnzszbk'],
#  ['gopdebate',
#   'carly',
#   'fiorina',
#   'called',
#   'hillary',
#   'liar',
#   '3x',
#   'hardball',
#   'chris',
#   '5',
#   'minutes',
#   'later',
#   'says',
#   'never',
#   'liar'],
#  ['know',
#   'audience',
#   'erupted',
#   'last',
#   'night',
#   'realdonaldtrump',
#   'rosie',
#   'line',
#   'ques',
#   'could',
#   'want',
#   'guy',
#   'prez',
#   'gopdebate'],
#  ['winners',
#   'gopdebate',
#   'sen',
#   'marcorubio',
#   'amp',
#   'former',
#   'hp',
#   'ceo',
#   'carlyfiorina',
#   'far',
#   'best',
#   'republican',
#   'presidential',
#   'candidates',
#   'http',
#   'co',
#   'v9qdpmpkk4'],
#  ['nancyleegrahn',
#   'gopdebate',
#   'giant',
#   'commercial',
#   'hillaryclinton',
#   'president',
#   'thank',
#   'god'],
#  ['daveanthony',
#   'chewbacca',
#   'roaring',
#   'every',
#   'would',
#   'fit',
#   'right',
#   'gopdebate'],
#  ['gopdebate',
#   'field',
#   'seems',
#   'terrified',
#   'mentioning',
#   'obama',
#   'negative',
#   'light'],
#  ['political',
#   'correctness',
#   'vile',
#   'term',
#   'people',
#   'invoke',
#   'slur',
#   'cowards',
#   'gopdebate',
#   'http',
#   'co',
#   'n8pu1zovbh'],
#  ['established',
#   'gopdebate',
#   'afraid',
#   'someone',
#   'willing',
#   'tell',
#   'truth',
#   'would',
#   'shake',
#   'dc',
#   'https',
#   'co',
#   'mia5t8yswp'],
#  ['writeintrump',
#   'knew',
#   'war',
#   'iraq',
#   'bad',
#   'idea',
#   'like',
#   'knew',
#   'letting',
#   'blind',
#   'guy',
#   'cut',
#   'rand',
#   'paul',
#   'hair',
#   'bad',
#   'idea',
#   'gop'],
#  ['yay', 'social', 'issues', 'next', 'gopdebate'],
#  ['artiswarusa',
#   'democrats',
#   'say',
#   'hail',
#   'hitlery',
#   'socialist',
#   'deathbydemocrat',
#   'election2016',
#   'stophillary',
#   'gopdebate',
#   'nazi',
#   'liberallogic',
#   'http'],
#  ['elevat0rlady',
#   'hopped',
#   'fb',
#   'saw',
#   'friends',
#   'recap',
#   'gopdebate',
#   'wins',
#   'http',
#   'co',
#   'tpszbvid8o'],
#  ['mammals',
#   'suck',
#   'shocked',
#   'hour',
#   'gopdebate',
#   'amp',
#   'qs',
#   'police',
#   'brutality',
#   'amp',
#   'blacklivesmatter'],
#  ['maybe',
#   'tweeting',
#   'game',
#   'know',
#   'let',
#   'spelling',
#   'contest',
#   'profanity',
#   'u',
#   'win',
#   'gopdebate',
#   'https',
#   'co',
#   '9taliqmezh'],
#  ['jeffsimmons2050',
#   'gopdebate',
#   'takeaway',
#   'presence',
#   'matters',
#   'see',
#   'presence',
#   'blend',
#   'believability',
#   'articulation',
#   'integrity',
#   'w',
#   'edg'],
#  ['carly',
#   'fiorina',
#   'runs',
#   'circles',
#   'around',
#   'chris',
#   'matthews',
#   'hillary',
#   'record',
#   'youtube',
#   'https',
#   'co',
#   'b9p8wg3ixz',
#   'gopdebate'],
#  ['jrehling',
#   'gopdebate',
#   'donald',
#   'trump',
#   'bruce',
#   'wayne',
#   'would',
#   'turned',
#   'parents',
#   'lived'],
#  ['jphoganorg',
#   'gopdebate',
#   'feelthebern',
#   'step',
#   'fallen',
#   'hillary2016',
#   'justice',
#   'fbi',
#   'fec',
#   'dissect',
#   '22nd',
#   'amendment',
#   'http'],
#  ['ali',
#   'compiled',
#   'chabased',
#   'polling',
#   'rank',
#   'versus',
#   'time',
#   'allotted',
#   'speak',
#   'gopdebate',
#   'walker',
#   'paul',
#   'robbed',
#   'http',
#   'co'],
#  ['gop',
#   'debate',
#   'campaign',
#   'preview',
#   'rearview',
#   'bradbannon',
#   'linkedin',
#   'https',
#   'co',
#   'n0mko8qqie',
#   'uniteblue',
#   'p2',
#   'potus',
#   'gopdebate',
#   'rsg15'],
#  ['richardhine',
#   'joe',
#   'biden',
#   'watching',
#   'gopdebate',
#   'http',
#   'co',
#   '6y2axgitms'],
#  ['american',
#   'women',
#   'take',
#   'note',
#   'realdonaldtrump',
#   'justified',
#   'piggish',
#   'attacks',
#   'women',
#   'gopdebate',
#   '1',
#   'man',
#   'stage',
#   'called'],
#  ['feministabulous',
#   'hate',
#   'abortion',
#   'defund',
#   'planned',
#   'parenthood',
#   'surefire',
#   'way',
#   'increase',
#   'abortion'],
#  ['leahrboss',
#   'carlyfiorina',
#   'spanked',
#   'boys',
#   'tonight',
#   'even',
#   'radar',
#   'gopdebate'],
#  ['indranibala',
#   'chris',
#   'christie',
#   'currently',
#   'using',
#   'case',
#   'bolster',
#   'campaign',
#   'presidency',
#   'gopdebate',
#   'https',
#   'co',
#   'ygmuldg8n2'],
#  ['jeb', 'looks', 'like', 'beavis', 'smiles', 'gopdebate'],
#  ['needs',
#   'comedy',
#   'shows',
#   'gopdebate',
#   'meanwhile',
#   'macdebate',
#   'kinda',
#   'snore',
#   'sorry',
#   'canada',
#   'https',
#   'co',
#   'qiqvue3fsr'],
#  ['thebaxterbean',
#   'reminder',
#   'family',
#   'important',
#   'republican',
#   '2016',
#   'candidates',
#   'gay',
#   'families',
#   'http',
#   'co',
#   'cs0usassqs',
#   'gopdebate',
#   'ht'],
#  ['debates',
#   'like',
#   'founding',
#   'fathers',
#   'less',
#   'like',
#   'game',
#   'shows',
#   'http',
#   'co',
#   '01kulhlxsk',
#   'gopdebate'],
#  ['berniesanders',
#   'scottwalker',
#   'man',
#   'say',
#   'one',
#   'intelligent',
#   'thing',
#   'mean',
#   'none',
#   'berniesanders',
#   'gopdebate',
#   'feelthebern'],
#  ['serious', 'gopdebate', 'hangover', 'today'],
#  ['cfjwagner',
#   '4',
#   'scariest',
#   'bugs',
#   'mean',
#   'gop',
#   'candidates',
#   'rimshot',
#   'http',
#   'co',
#   'okc1tfczww',
#   'gopdebate',
#   'blog',
#   'writerslife',
#   'http'],
#  ['marnus3',
#   'perfect',
#   'remedy',
#   'gopdebate',
#   'hangover',
#   'ff',
#   'pharris830',
#   'mharvey816',
#   'comebackdecade',
#   'glentheplumber',
#   'rfschatten'],
#  ['realdonaldtrump', 'got', 'trumped', 'megynkelly', 'gopdebate'],
#  ['mydaughtersarmy',
#   'debate',
#   'hard',
#   'ted',
#   'cruz',
#   'gopdebate',
#   'http',
#   'co',
#   '9hmr7num6n'],
#  ['keemstarx', 'black', 'guy', 'smafuck', 'gopdebate', 'trump', 'make', 'vp'],
#  ['thought', 'megynkelly', 'awesome', 'job', 'gopdebate', 'personally'],
#  ['megynkelly',
#   'u',
#   'disappointed',
#   'last',
#   'night',
#   'gopdebate',
#   'u',
#   'asked',
#   'realdonaldtrump',
#   'q',
#   'pertinent',
#   '2',
#   'duties',
#   'president'],
#  ['gahtbomb',
#   'mike',
#   'huckabee',
#   'purpose',
#   'military',
#   'kill',
#   'people',
#   'break',
#   'things',
#   'gopdebate'],
#  ['ag',
#   'texas',
#   'hillary',
#   'clinton',
#   'response',
#   'gopdebate',
#   'guys',
#   'ok',
#   'secure',
#   'thousands',
#   'votes',
#   'illegals'],
#  ['writeintrump',
#   'every',
#   'time',
#   'bell',
#   'rings',
#   'rand',
#   'paul',
#   'little',
#   'poodle',
#   'ears',
#   'keep',
#   'perking',
#   'gopdebate'],
#  ['whinenot',
#   'rush',
#   'one',
#   '9',
#   'candidates',
#   'stage',
#   'joined',
#   'megan',
#   'kelly',
#   'going',
#   'donald',
#   'trump',
#   'gopdebate'],
#  ['writeintrump',
#   'rand',
#   'paul',
#   'haircut',
#   'really',
#   'distracting',
#   'almost',
#   'yelled',
#   'rand',
#   'get',
#   'leash',
#   'time',
#   'walk',
#   'gopdebate'],
#  ['tired',
#   'shills',
#   'media',
#   'hillary',
#   'henceforth',
#   'known',
#   'shillary',
#   'gopdebate'],
#  ['almightygod',
#   'ben',
#   'carson',
#   'god',
#   'pretty',
#   'fair',
#   'guy',
#   'guess',
#   'never',
#   'read',
#   'bible',
#   'job',
#   'pharaoh',
#   'shebears',
#   'gopdebate'],
#  ['writeintrump',
#   'cheap',
#   'tactic',
#   'rand',
#   'paul',
#   'getting',
#   'haircut',
#   'poodle',
#   'distract',
#   'gopdebate'],
#  ['theblaze',
#   'mattwalshblog',
#   'republicans',
#   'gopdebate',
#   'maybe',
#   'think',
#   'electing',
#   'someone',
#   'http',
#   'co',
#   'brx74ildwm'],
#  ['john',
#   'kasich',
#   'seems',
#   'like',
#   'decent',
#   'guy',
#   'pity',
#   'republican',
#   'gopdebate'],
#  ['gopdebate',
#   'bingo',
#   'atavist',
#   'https',
#   'co',
#   'hkew4f0kb2',
#   'http',
#   'co',
#   'pwaoz6kvop'],
#  ['rmconservative',
#   'cruz',
#   'line',
#   'campaignconservative',
#   'cuts',
#   '2',
#   'core',
#   'issue',
#   'gop',
#   'amp',
#   'also',
#   'shortcomings',
#   'gopdebate',
#   'htt'],
#  ['pulmyears',
#   'official',
#   'photo',
#   'big',
#   'foxnews',
#   'gopdebate',
#   'last',
#   'night',
#   'http',
#   'co',
#   '9yqgzvc2qv'],
#  ['last',
#   'night',
#   'gopdebate',
#   'proved',
#   'everything',
#   'already',
#   'knew',
#   'white',
#   'patriarchal',
#   'elitist',
#   'homophobic',
#   'party',
#   'gop'],
#  ['trump',
#   'integrity',
#   'character',
#   'principles',
#   'proud',
#   'mattwalshblog',
#   'agreed',
#   'gopdebate',
#   'trump'],
#  ['linnyitssn',
#   'also',
#   'funny',
#   'constitution',
#   'loving',
#   'republicans',
#   'structurally',
#   'violate',
#   'constitution',
#   'bringing',
#   'religion',
#   'politics',
#   'g'],
#  ['oaaselect',
#   'radical',
#   'capitalism',
#   'individual',
#   'rights',
#   'looking',
#   'heroic',
#   'candidate',
#   'gopdebate'],
#  ['blowtorch',
#   'irs',
#   'like',
#   'sound',
#   'criminalabusesnowpoised2policeourhealthcare',
#   'go',
#   'rick',
#   'gopdebate',
#   'https',
#   'co',
#   'zflcfhee3j'],
#  ['megynkelly', 'favorite', 'tonight', 'gopdebate', 'foxnews'],
#  ['gopdebate',
#   'fix',
#   'get',
#   'go',
#   'first',
#   'question',
#   'pledging',
#   'suppoaddressed',
#   'directly',
#   '2',
#   'realdonaldtrump'],
#  ['first',
#   'gopdebate',
#   'social',
#   'media',
#   'reaction',
#   'http',
#   'co',
#   'uh06ezxxfg',
#   'socialmedia',
#   'smo'],
#  ['realbencarson',
#   'excellent',
#   'job',
#   'last',
#   'night',
#   'gopdebate',
#   'class',
#   'act',
#   'around',
#   'proud',
#   'republican',
#   'candidate',
#   'bencarson'],
#  ['korystamper',
#   'lookups',
#   'misogynist',
#   'spiking',
#   'merriamwebster',
#   'http',
#   'co',
#   'k7rbb12rlc',
#   'trump',
#   'women',
#   'gopdebate',
#   'http',
#   'co',
#   'yxsj'],
#  ['god',
#   'speaking',
#   'looney',
#   'tunes',
#   'real',
#   'questions',
#   'gopdebate',
#   'https',
#   'co',
#   'fbo00cn461'],
#  ['marcorubio',
#   'skye820',
#   'going',
#   'make',
#   'american',
#   'century',
#   'got',
#   'empower',
#   'small',
#   'businesses',
#   'thanks',
#   'question'],
#  ['pattonoswalt',
#   'god',
#   'named',
#   'bruce',
#   'springsteen',
#   'go',
#   'listen',
#   'jungleland',
#   'get',
#   'fucking',
#   'clue',
#   'christie',
#   'gopdebate'],
#  ['saw',
#   'megynkelly',
#   'reach',
#   'scratch',
#   'balls',
#   'picked',
#   '10th',
#   'fight',
#   'realdonaldtrump',
#   'gopdebate',
#   'tcot'],
#  ['thepatriot143',
#   'winner',
#   'overall',
#   'today',
#   'gopdebate',
#   'carlyfiorina',
#   'really',
#   'stood',
#   'among',
#   'gop',
#   'candidates'],
#  ['republicans',
#   'hate',
#   'gun',
#   'free',
#   'zones',
#   'held',
#   'gopdebate',
#   'gun',
#   'free',
#   'zone',
#   'https',
#   'co',
#   '0rlayowqw1'],
#  ['peddoc63',
#   'embassy',
#   'attacked',
#   'woman',
#   'would',
#   'trust',
#   'carlyfiorina',
#   'fav',
#   'hillaryclinton',
#   'gopdebate',
#   'http'],
#  ['lizadonnelly',
#   'political',
#   'nonsense',
#   'last',
#   'night',
#   'gopdebate',
#   'see',
#   'http',
#   'co',
#   'mocgzthbdz',
#   'site',
#   'https',
#   'co',
#   'xyahgrr5vh'],
#  ['teatraitors',
#   'gopdebate',
#   'still',
#   'clown',
#   'show',
#   'glad',
#   'head',
#   'clown',
#   'trump',
#   'helping',
#   'destroy',
#   'gop',
#   'http',
#   'co',
#   'pry2qpcwfu'],
#  ['must',
#   'admit',
#   'realdonaldtrump',
#   'throws',
#   'shade',
#   'like',
#   'rhoa',
#   'lol',
#   'gopdebate',
#   'https',
#   'co',
#   'c9luq1dww3'],
#  ['looking',
#   'forward',
#   'listening',
#   'drshow',
#   'news',
#   'roundup',
#   'morning',
#   'look',
#   'away',
#   'gopdebate',
#   'http',
#   'co',
#   'o8rtitvgdt'],
#  ['molonlabe1776us',
#   'last',
#   'night',
#   'looked',
#   'megynkelly',
#   'bretbaier',
#   'gopdebate',
#   'tcot',
#   'realdonaldtrump',
#   'http',
#   'co',
#   'k2tk'],
#  ['know', 'laugh', 'cry', 'last', 'nights', 'gopdebate'],
#  ['pillary56',
#   'difference',
#   'politically',
#   'correct',
#   'massive',
#   'jerk',
#   'mr',
#   'trump',
#   'gopdebate'],
#  ['thoughts',
#   'perry',
#   'fiorina',
#   'must',
#   'replace',
#   'paul',
#   'kasich',
#   'top',
#   'ten',
#   'jindal',
#   'needs',
#   'step',
#   'replace',
#   'christie',
#   'gopdebate'],
#  ['marcorubio', 'nominee', 'party', 'future', 'gopdebate'],
#  ['sentedcruz',
#   'best',
#   'answer',
#   'night',
#   'response',
#   'immigration',
#   'stupidity',
#   'sides',
#   'want',
#   'gopdebate'],
#  ['thebloggess',
#   'rather',
#   'watching',
#   'gopdebate',
#   'watching',
#   'maureenjohnson',
#   'live',
#   'tweet',
#   'made',
#   'right',
#   'decision',
#   'https'],
#  ['interesting',
#   'gopdebate',
#   'analysis',
#   'marcorubio',
#   'clearly',
#   'excelled',
#   'conservative',
#   'leader',
#   'need',
#   'go',
#   'teammarco',
#   'tcot',
#   'https',
#   'co',
#   'pve8wuodke'],
#  ['krauthammer',
#   'sorry',
#   'downfall',
#   'trump',
#   'last',
#   'nights',
#   'debate',
#   'greatly',
#   'exaggerated',
#   'gopdebate'],
#  ['moderator',
#   'scottwalker',
#   'rip',
#   'iran',
#   'deal',
#   'day',
#   '1',
#   'walker',
#   'remember',
#   'tying',
#   'yellow',
#   'ribbons',
#   'trees',
#   'gopdebate'],
#  ['ccalbos',
#   'tell',
#   'us',
#   'god',
#   'speaks',
#   'happening',
#   'real',
#   'life',
#   'gopdebate'],
#  ['gusramsey', 'snl', 'big', 'enough', 'cast', 'spoof', 'gopdebate'],
#  ['bbcworld',
#   'bbcjonsopel',
#   'midst',
#   'gopdebate',
#   'came',
#   'big',
#   'blow',
#   'barackobama',
#   'announcement',
#   'leading',
#   'jewish',
#   'democrat',
#   'sen',
#   'schumer'],
#  ['ccalbos',
#   'huckabee',
#   'military',
#   'kill',
#   'people',
#   'break',
#   'things',
#   'behalf',
#   'military',
#   'families',
#   'f',
#   'gopdebate'],
#  ['perezhilton',
#   'watching',
#   'gopdebate',
#   'hillaryclinton',
#   'taking',
#   'selfies',
#   'kimkardashian',
#   'http',
#   'co',
#   'hytsdemr64',
#   'http'],
#  ['realbencarson',
#   'pre',
#   'gopdebate',
#   'ritual',
#   'bc2dc16',
#   'https',
#   'co',
#   'agbmc4nbm5'],
#  ['realdonaldtrump',
#   'arrogance',
#   'gopdebate',
#   'used',
#   'laws',
#   'country',
#   'advantage',
#   'notthatguy',
#   'http',
#   'co',
#   'rjtjr9ioac'],
#  ['18',
#   'hours',
#   'later',
#   'looking',
#   'back',
#   'biggest',
#   'gaffe',
#   'gopdebate',
#   'repeatedly',
#   'tagging',
#   'victor',
#   'cruz',
#   'teamvic',
#   'instead',
#   'ted',
#   'cruz',
#   'tedcruz'],
#  ['real',
#   'scary',
#   'liberals',
#   'allowed',
#   '2',
#   'walk',
#   'around',
#   'committing',
#   'horrific',
#   'crimes',
#   'humanity',
#   'gopdebate',
#   'plannedbutcherhood'],
#  ['like',
#   'thank',
#   '9',
#   'candidates',
#   'gopdebate',
#   'took',
#   'trump',
#   'task',
#   'trying',
#   'fatshame',
#   'rosie'],
#  ['got', 'ta', 'love', 'megynkelly', 'gopdebate'],
#  ['numbersmuncher',
#   'donald',
#   'trump',
#   'guy',
#   'flips',
#   'risk',
#   'board',
#   'realizes',
#   'overtake',
#   'asia',
#   'gopdebate'],
#  ['brendohare',
#   'great',
#   'battle',
#   'last',
#   'night',
#   'premier',
#   'teenage',
#   'athletes',
#   'gopdebate',
#   'http',
#   'co',
#   'plgp4aai2y'],
#  ['foxnews',
#   'replace',
#   'megynkelly',
#   'marthamaccallum',
#   'future',
#   'debates',
#   'maccallum',
#   'much',
#   'better',
#   'job',
#   'early',
#   'debate',
#   'gopdebate'],
#  ['donald',
#   'trump',
#   'democratic',
#   'spy',
#   'http',
#   'co',
#   '8n9mvtkn4u',
#   'realdonaldtrump',
#   'sensanders',
#   'trump',
#   'donaldtrump',
#   'hillary2016',
#   'gopdebate'],
#  ['jjosephwilliams',
#   '16',
#   'united',
#   'states',
#   'homes',
#   'tv',
#   'sets',
#   'tuned',
#   'gopdebate',
#   'wow',
#   'http',
#   'co',
#   'trs8vmwjyg'],
#  ['gopdebate',
#   'old',
#   'white',
#   'rich',
#   'conservative',
#   'dudes',
#   'parade',
#   'childhood',
#   'nightmare',
#   'mine'],
#  ['ljcambria',
#   'realdonaldtrump',
#   'forget',
#   'vote',
#   'especislly',
#   'go',
#   'independent',
#   'lulz',
#   'huckster',
#   'rnc',
#   'gop',
#   'gopdebate'],
#  ['recap',
#   'gopdebate',
#   'tenmen',
#   'want',
#   'make',
#   'choices',
#   'women',
#   'goptbt',
#   'http',
#   'co',
#   'v1desifyee'],
#  ['writeintrump',
#   'made',
#   'hillary',
#   'clinton',
#   'go',
#   'wedding',
#   'also',
#   'made',
#   'best',
#   'man',
#   'gopdebate'],
#  ['rand',
#   'paul',
#   'could',
#   'drop',
#   'top',
#   '10',
#   'w',
#   'dreadful',
#   'petulent',
#   'debate',
#   'fiorina',
#   'moves',
#   'gopdebate',
#   'tcot'],
#  ['nerdist',
#   'got',
#   'ta',
#   'say',
#   'refreshing',
#   'hear',
#   'presidential',
#   'debate',
#   'everyone',
#   'correctly',
#   'pronouncing',
#   'nuclear',
#   'gopdebate'],
#  ['gogoaleee',
#   'ig',
#   'deleted',
#   'dd',
#   'account',
#   'participated',
#   'kkkorgop',
#   'hashtag',
#   'gopdebate',
#   'http',
#   'co',
#   'jnyrnopngx',
#   'via',
#   'dream'],
#  ['crazyclarine',
#   'lol',
#   'the3o5flyguy',
#   'watching',
#   'gopdebate',
#   'like',
#   'http',
#   'co',
#   'zowjcu2baz'],
#  ['sjadetx', 'thoughts', 'gopdebate', 'http', 'co', 'bt7glnyuon'],
#  ['freedomtexasmom',
#   'love',
#   'megynkelly',
#   'died',
#   'tonight',
#   'gopdebate',
#   'foxnews',
#   'trumpcruz2016',
#   'makeamericagreatagain'],
#  ...]

# %% [markdown]
# ### Feature extraction using word2vec

# %%
#Creating word embedding for the words. Embedding dimension = 100
model = Word2Vec(corpus, size=100, window=5, min_count=1)

# %%
#Voabulary list
model.wv.vocab
# Out:
# {'hear': <gensim.models.keyedvectors.Vocab at 0x7f31959757f0>,
#  'immigration': <gensim.models.keyedvectors.Vocab at 0x7f3195975c88>,
#  '14th': <gensim.models.keyedvectors.Vocab at 0x7f3195975550>,
#  'tcpalm': <gensim.models.keyedvectors.Vocab at 0x7f31950a3be0>,
#  'newlow': <gensim.models.keyedvectors.Vocab at 0x7f3195975ba8>,
#  'dinner': <gensim.models.keyedvectors.Vocab at 0x7f319523e780>,
#  'socialmedia': <gensim.models.keyedvectors.Vocab at 0x7f319523e978>,
#  'teeth': <gensim.models.keyedvectors.Vocab at 0x7f319523e240>,
#  'heels': <gensim.models.keyedvectors.Vocab at 0x7f319523e9b0>,
#  'annemarieweers': <gensim.models.keyedvectors.Vocab at 0x7f319523eb38>,
#  'newsnation': <gensim.models.keyedvectors.Vocab at 0x7f3195241080>,
#  'please': <gensim.models.keyedvectors.Vocab at 0x7f3195241208>,
#  'elianabenador': <gensim.models.keyedvectors.Vocab at 0x7f319524af28>,
#  'messenger': <gensim.models.keyedvectors.Vocab at 0x7f31952412e8>,
#  'sfrnc': <gensim.models.keyedvectors.Vocab at 0x7f3195241320>,
#  'republicanprimary': <gensim.models.keyedvectors.Vocab at 0x7f3195241358>,
#  'wage': <gensim.models.keyedvectors.Vocab at 0x7f31952413c8>,
#  'sickness': <gensim.models.keyedvectors.Vocab at 0x7f31952414e0>,
#  'leaks': <gensim.models.keyedvectors.Vocab at 0x7f31950d6198>,
#  'lowinfotweeter': <gensim.models.keyedvectors.Vocab at 0x7f3195241588>,
#  'existence': <gensim.models.keyedvectors.Vocab at 0x7f3195241630>,
#  'jgreendc': <gensim.models.keyedvectors.Vocab at 0x7f31952416d8>,
#  'lost': <gensim.models.keyedvectors.Vocab at 0x7f319512c8d0>,
#  'displays': <gensim.models.keyedvectors.Vocab at 0x7f31952417b8>,
#  '1ybwuamd4o': <gensim.models.keyedvectors.Vocab at 0x7f31952417f0>,
#  'world': <gensim.models.keyedvectors.Vocab at 0x7f3195241898>,
#  'vb5bdjr1k9': <gensim.models.keyedvectors.Vocab at 0x7f31952418d0>,
#  'climatedesk': <gensim.models.keyedvectors.Vocab at 0x7f3195241908>,
#  'every1': <gensim.models.keyedvectors.Vocab at 0x7f3195100e80>,
#  'dkpol': <gensim.models.keyedvectors.Vocab at 0x7f3195241940>,
#  'morrissey': <gensim.models.keyedvectors.Vocab at 0x7f31952419b0>,
#  'govtstheproblem': <gensim.models.keyedvectors.Vocab at 0x7f31952419e8>,
#  'frankbruni': <gensim.models.keyedvectors.Vocab at 0x7f3195241c18>,
#  'foundation': <gensim.models.keyedvectors.Vocab at 0x7f3195241c88>,
#  'wackos': <gensim.models.keyedvectors.Vocab at 0x7f3195241d68>,
#  'proginosko': <gensim.models.keyedvectors.Vocab at 0x7f3195241e80>,
#  'illnesses': <gensim.models.keyedvectors.Vocab at 0x7f3195241eb8>,
#  'rwgy9dozx6': <gensim.models.keyedvectors.Vocab at 0x7f3195241f28>,
#  'foxn': <gensim.models.keyedvectors.Vocab at 0x7f3195241f60>,
#  'shes': <gensim.models.keyedvectors.Vocab at 0x7f31951f1a20>,
#  'auhlnza3ww': <gensim.models.keyedvectors.Vocab at 0x7f31952410b8>,
#  'treppps': <gensim.models.keyedvectors.Vocab at 0x7f3195241128>,
#  'potential': <gensim.models.keyedvectors.Vocab at 0x7f3195241278>,
#  'trusts': <gensim.models.keyedvectors.Vocab at 0x7f31952412b0>,
#  'pc': <gensim.models.keyedvectors.Vocab at 0x7f31950fd668>,
#  'thetexasphoenix': <gensim.models.keyedvectors.Vocab at 0x7f3195241390>,
#  'capitalize': <gensim.models.keyedvectors.Vocab at 0x7f3195241400>,
#  'envelope': <gensim.models.keyedvectors.Vocab at 0x7f3195241048>,
#  'hlntv': <gensim.models.keyedvectors.Vocab at 0x7f31952411d0>,
#  'wimpy': <gensim.models.keyedvectors.Vocab at 0x7f31952414a8>,
#  'ratingsbonanza': <gensim.models.keyedvectors.Vocab at 0x7f3195241518>,
#  'vohandas': <gensim.models.keyedvectors.Vocab at 0x7f3195241550>,
#  'nailed': <gensim.models.keyedvectors.Vocab at 0x7f31952415c0>,
#  'divide': <gensim.models.keyedvectors.Vocab at 0x7f319516d908>,
#  'cqnow': <gensim.models.keyedvectors.Vocab at 0x7f3195241710>,
#  'universe': <gensim.models.keyedvectors.Vocab at 0x7f3195241978>,
#  'gexpvd1vb0': <gensim.models.keyedvectors.Vocab at 0x7f31951f1ac8>,
#  'qpvju6p7sz': <gensim.models.keyedvectors.Vocab at 0x7f31950e7320>,
#  'uaib1m8ekc': <gensim.models.keyedvectors.Vocab at 0x7f31950f27f0>,
#  'ideology': <gensim.models.keyedvectors.Vocab at 0x7f3195241b70>,
#  'flyoverculture': <gensim.models.keyedvectors.Vocab at 0x7f3195241c50>,
#  'wvzuw29m7d': <gensim.models.keyedvectors.Vocab at 0x7f3195241cf8>,
#  'torpedo': <gensim.models.keyedvectors.Vocab at 0x7f3195241dd8>,
#  'protesting': <gensim.models.keyedvectors.Vocab at 0x7f3195241e10>,
#  'dobadarris': <gensim.models.keyedvectors.Vocab at 0x7f3195241e48>,
#  'sewer': <gensim.models.keyedvectors.Vocab at 0x7f3195241ef0>,
#  'concur': <gensim.models.keyedvectors.Vocab at 0x7f3195241f98>,
#  'yrhbygjemv': <gensim.models.keyedvectors.Vocab at 0x7f3195241780>,
#  'alison': <gensim.models.keyedvectors.Vocab at 0x7f3195241828>,
#  'chat': <gensim.models.keyedvectors.Vocab at 0x7f3195241a90>,
#  'nhgop': <gensim.models.keyedvectors.Vocab at 0x7f319523feb8>,
#  'quiz': <gensim.models.keyedvectors.Vocab at 0x7f319509fcc0>,
#  'succinctly': <gensim.models.keyedvectors.Vocab at 0x7f3195241da0>,
#  'retire': <gensim.models.keyedvectors.Vocab at 0x7f3195241b38>,
#  'bites': <gensim.models.keyedvectors.Vocab at 0x7f31952415f8>,
#  'feminism': <gensim.models.keyedvectors.Vocab at 0x7f31952350b8>,
#  'theabridgedzach': <gensim.models.keyedvectors.Vocab at 0x7f31952350f0>,
#  'shows': <gensim.models.keyedvectors.Vocab at 0x7f3195235160>,
#  'disrespect': <gensim.models.keyedvectors.Vocab at 0x7f3195235198>,
#  'sentedcruz': <gensim.models.keyedvectors.Vocab at 0x7f31952351d0>,
#  'gary': <gensim.models.keyedvectors.Vocab at 0x7f3195235240>,
#  'alpha': <gensim.models.keyedvectors.Vocab at 0x7f3195235278>,
#  'liberals': <gensim.models.keyedvectors.Vocab at 0x7f31952352e8>,
#  'biology': <gensim.models.keyedvectors.Vocab at 0x7f31952353c8>,
#  'gentle': <gensim.models.keyedvectors.Vocab at 0x7f3195174358>,
#  'mrchuckd': <gensim.models.keyedvectors.Vocab at 0x7f31952354a8>,
#  'dqr7ljewnu': <gensim.models.keyedvectors.Vocab at 0x7f3195235080>,
#  'impressive': <gensim.models.keyedvectors.Vocab at 0x7f3195235358>,
#  'hype': <gensim.models.keyedvectors.Vocab at 0x7f3195235438>,
#  'baddies': <gensim.models.keyedvectors.Vocab at 0x7f3195235518>,
#  'pits': <gensim.models.keyedvectors.Vocab at 0x7f31952355c0>,
#  'ytrz6qvhod': <gensim.models.keyedvectors.Vocab at 0x7f31952355f8>,
#  'rug': <gensim.models.keyedvectors.Vocab at 0x7f319512cc18>,
#  'pharaoh': <gensim.models.keyedvectors.Vocab at 0x7f3195247940>,
#  'jotted': <gensim.models.keyedvectors.Vocab at 0x7f31950a3d68>,
#  'thatswhatjvsaid': <gensim.models.keyedvectors.Vocab at 0x7f3195235828>,
#  'kerry': <gensim.models.keyedvectors.Vocab at 0x7f319519b7f0>,
#  'rollout': <gensim.models.keyedvectors.Vocab at 0x7f3195235898>,
#  'sponsoring': <gensim.models.keyedvectors.Vocab at 0x7f31952358d0>,
#  '03yplnfagb': <gensim.models.keyedvectors.Vocab at 0x7f3195235978>,
#  'yhfktwap9z': <gensim.models.keyedvectors.Vocab at 0x7f31952359b0>,
#  'gop201': <gensim.models.keyedvectors.Vocab at 0x7f31952359e8>,
#  'a4zov5ekot': <gensim.models.keyedvectors.Vocab at 0x7f3195235a20>,
#  'phb2pfyiww': <gensim.models.keyedvectors.Vocab at 0x7f31950fe668>,
#  'proposed': <gensim.models.keyedvectors.Vocab at 0x7f3195235a90>,
#  'debriefing': <gensim.models.keyedvectors.Vocab at 0x7f3195150400>,
#  'f9dfwmqt2o': <gensim.models.keyedvectors.Vocab at 0x7f3195235b00>,
#  'rubio2016': <gensim.models.keyedvectors.Vocab at 0x7f3195235b38>,
#  'veep': <gensim.models.keyedvectors.Vocab at 0x7f319510b438>,
#  'mfl1956': <gensim.models.keyedvectors.Vocab at 0x7f3195235c50>,
#  'pie8ujpda1': <gensim.models.keyedvectors.Vocab at 0x7f3195235d68>,
#  '1z3vufjzlw': <gensim.models.keyedvectors.Vocab at 0x7f3195235da0>,
#  'queenlatifah': <gensim.models.keyedvectors.Vocab at 0x7f319512ce80>,
#  'tuegrpp46m': <gensim.models.keyedvectors.Vocab at 0x7f3195235dd8>,
#  'unnewsworty': <gensim.models.keyedvectors.Vocab at 0x7f31950e4860>,
#  'imjustceej': <gensim.models.keyedvectors.Vocab at 0x7f3195235e80>,
#  'zealots': <gensim.models.keyedvectors.Vocab at 0x7f3195235f60>,
#  'rattle': <gensim.models.keyedvectors.Vocab at 0x7f3195235f98>,
#  'unflinching': <gensim.models.keyedvectors.Vocab at 0x7f3195235fd0>,
#  'socialist': <gensim.models.keyedvectors.Vocab at 0x7f3195235208>,
#  'uneducated': <gensim.models.keyedvectors.Vocab at 0x7f3195235400>,
#  'votersfirst': <gensim.models.keyedvectors.Vocab at 0x7f3195235588>,
#  'dxnjjuxele': <gensim.models.keyedvectors.Vocab at 0x7f3195235668>,
#  'yqw1hmwgx8': <gensim.models.keyedvectors.Vocab at 0x7f31952356d8>,
#  'soon': <gensim.models.keyedvectors.Vocab at 0x7f3195235a58>,
#  'un2cj2dotj': <gensim.models.keyedvectors.Vocab at 0x7f3195235c18>,
#  'gd6rvbhz4p': <gensim.models.keyedvectors.Vocab at 0x7f3195235c88>,
#  'bringingjobs': <gensim.models.keyedvectors.Vocab at 0x7f3195235d30>,
#  'idg375': <gensim.models.keyedvectors.Vocab at 0x7f3195235ef0>,
#  'chadpergram': <gensim.models.keyedvectors.Vocab at 0x7f3195235f28>,
#  'zqcaonpakj': <gensim.models.keyedvectors.Vocab at 0x7f31950f95c0>,
#  'pissing': <gensim.models.keyedvectors.Vocab at 0x7f3195235128>,
#  'sirius206': <gensim.models.keyedvectors.Vocab at 0x7f31952354e0>,
#  'greg': <gensim.models.keyedvectors.Vocab at 0x7f3195235710>,
#  'var': <gensim.models.keyedvectors.Vocab at 0x7f3195235940>,
#  'misinformed': <gensim.models.keyedvectors.Vocab at 0x7f3195235ac8>,
#  'jeb': <gensim.models.keyedvectors.Vocab at 0x7f3195235b70>,
#  'among': <gensim.models.keyedvectors.Vocab at 0x7f3195235ba8>,
#  'myfoxtampabay': <gensim.models.keyedvectors.Vocab at 0x7f3195235cc0>,
#  'blowjob': <gensim.models.keyedvectors.Vocab at 0x7f3195251198>,
#  'olde': <gensim.models.keyedvectors.Vocab at 0x7f3195235630>,
#  'paworld': <gensim.models.keyedvectors.Vocab at 0x7f3195235780>,
#  'hlllary': <gensim.models.keyedvectors.Vocab at 0x7f31952357b8>,
#  'teamusa': <gensim.models.keyedvectors.Vocab at 0x7f31951f7b38>,
#  'libs': <gensim.models.keyedvectors.Vocab at 0x7f31951f13c8>,
#  'assume': <gensim.models.keyedvectors.Vocab at 0x7f3195235e48>,
#  'wide': <gensim.models.keyedvectors.Vocab at 0x7f3195238080>,
#  'disappear': <gensim.models.keyedvectors.Vocab at 0x7f31952380f0>,
#  'adventures': <gensim.models.keyedvectors.Vocab at 0x7f3195238160>,
#  '2night': <gensim.models.keyedvectors.Vocab at 0x7f3195238240>,
#  'journalists': <gensim.models.keyedvectors.Vocab at 0x7f3195238278>,
#  'dale': <gensim.models.keyedvectors.Vocab at 0x7f31952382b0>,
#  'vision': <gensim.models.keyedvectors.Vocab at 0x7f3195238358>,
#  'mstuart1970': <gensim.models.keyedvectors.Vocab at 0x7f3195238390>,
#  'loathed': <gensim.models.keyedvectors.Vocab at 0x7f3195238400>,
#  'equipped': <gensim.models.keyedvectors.Vocab at 0x7f3195238470>,
#  'astounded': <gensim.models.keyedvectors.Vocab at 0x7f31950f5d68>,
#  'woke': <gensim.models.keyedvectors.Vocab at 0x7f31952385f8>,
#  'nooz': <gensim.models.keyedvectors.Vocab at 0x7f3195238668>,
#  'p4lntsuxkl': <gensim.models.keyedvectors.Vocab at 0x7f31952386a0>,
#  'hillaryforpresident': <gensim.models.keyedvectors.Vocab at 0x7f3195238748>,
#  'sosrcpfvsj': <gensim.models.keyedvectors.Vocab at 0x7f3195238780>,
#  'freakin': <gensim.models.keyedvectors.Vocab at 0x7f31952387f0>,
#  'sinking': <gensim.models.keyedvectors.Vocab at 0x7f3195238860>,
#  'editorial': <gensim.models.keyedvectors.Vocab at 0x7f319510e160>,
#  'zii1mx72gv': <gensim.models.keyedvectors.Vocab at 0x7f3195238898>,
#  'katienolan': <gensim.models.keyedvectors.Vocab at 0x7f3195238940>,
#  'docks': <gensim.models.keyedvectors.Vocab at 0x7f31952389b0>,
#  'damon': <gensim.models.keyedvectors.Vocab at 0x7f31952389e8>,
#  'bnlieb': <gensim.models.keyedvectors.Vocab at 0x7f3195238a20>,
#  'shortly': <gensim.models.keyedvectors.Vocab at 0x7f3195238a58>,
#  'numbersmuncher': <gensim.models.keyedvectors.Vocab at 0x7f31950ee0b8>,
#  'we77qdt3kt': <gensim.models.keyedvectors.Vocab at 0x7f3195238a90>,
#  'reflex': <gensim.models.keyedvectors.Vocab at 0x7f3195238ac8>,
#  'wonder': <gensim.models.keyedvectors.Vocab at 0x7f3195238b38>,
#  'joetalkshow': <gensim.models.keyedvectors.Vocab at 0x7f3195238b70>,
#  'amiramitch': <gensim.models.keyedvectors.Vocab at 0x7f3195238c18>,
#  'veered': <gensim.models.keyedvectors.Vocab at 0x7f3195238c88>,
#  'unionmaiden': <gensim.models.keyedvectors.Vocab at 0x7f3195174be0>,
#  '0lkex8jjv1': <gensim.models.keyedvectors.Vocab at 0x7f3195238da0>,
#  'ovgxifrluc': <gensim.models.keyedvectors.Vocab at 0x7f3195131438>,
#  'tagging': <gensim.models.keyedvectors.Vocab at 0x7f3195238e80>,
#  'fuapqthmzg': <gensim.models.keyedvectors.Vocab at 0x7f3195238ef0>,
#  'tacticaldissent': <gensim.models.keyedvectors.Vocab at 0x7f3195238f60>,
#  'dominates': <gensim.models.keyedvectors.Vocab at 0x7f31952380b8>,
#  'busy': <gensim.models.keyedvectors.Vocab at 0x7f3195238198>,
#  'jonstewagone': <gensim.models.keyedvectors.Vocab at 0x7f3195238208>,
#  'veto': <gensim.models.keyedvectors.Vocab at 0x7f3195238320>,
#  'illustrated': <gensim.models.keyedvectors.Vocab at 0x7f31950f25c0>,
#  'police': <gensim.models.keyedvectors.Vocab at 0x7f3195238518>,
#  'bgudpo0ikb': <gensim.models.keyedvectors.Vocab at 0x7f31950ab0b8>,
#  'ticked': <gensim.models.keyedvectors.Vocab at 0x7f31950dc0f0>,
#  'parkerc2112': <gensim.models.keyedvectors.Vocab at 0x7f3195253780>,
#  'history': <gensim.models.keyedvectors.Vocab at 0x7f3195238630>,
#  'obnoxious': <gensim.models.keyedvectors.Vocab at 0x7f31952386d8>,
#  'pongdlc': <gensim.models.keyedvectors.Vocab at 0x7f3195238710>,
#  'hammers': <gensim.models.keyedvectors.Vocab at 0x7f31951f1c18>,
#  'senschumer': <gensim.models.keyedvectors.Vocab at 0x7f31952388d0>,
#  'clearer': <gensim.models.keyedvectors.Vocab at 0x7f3195238b00>,
#  '24b': <gensim.models.keyedvectors.Vocab at 0x7f3195238be0>,
#  'placater': <gensim.models.keyedvectors.Vocab at 0x7f31951ddf98>,
#  'vine': <gensim.models.keyedvectors.Vocab at 0x7f3195238d68>,
#  'peterdaou': <gensim.models.keyedvectors.Vocab at 0x7f31950ab828>,
#  'trip': <gensim.models.keyedvectors.Vocab at 0x7f3195238f28>,
#  'destabilized': <gensim.models.keyedvectors.Vocab at 0x7f3195238f98>,
#  '7eyg5ib8uk': <gensim.models.keyedvectors.Vocab at 0x7f31950f0080>,
#  'buried': <gensim.models.keyedvectors.Vocab at 0x7f3195238128>,
#  'drn2bhohii': <gensim.models.keyedvectors.Vocab at 0x7f319509c908>,
#  'bassalid': <gensim.models.keyedvectors.Vocab at 0x7f31952383c8>,
#  'ighqi3lgh9': <gensim.models.keyedvectors.Vocab at 0x7f3195238550>,
#  'carlson': <gensim.models.keyedvectors.Vocab at 0x7f3195205ba8>,
#  'xtjmcwysho': <gensim.models.keyedvectors.Vocab at 0x7f31951f1da0>,
#  'attendance': <gensim.models.keyedvectors.Vocab at 0x7f3195238cc0>,
#  'modern': <gensim.models.keyedvectors.Vocab at 0x7f31952384a8>,
#  'sisbsjpubf': <gensim.models.keyedvectors.Vocab at 0x7f31952385c0>,
#  'mztcbkkgwu': <gensim.models.keyedvectors.Vocab at 0x7f3195238908>,
#  'queens': <gensim.models.keyedvectors.Vocab at 0x7f319513f5c0>,
#  '2h47tkg2lk': <gensim.models.keyedvectors.Vocab at 0x7f31951d6240>,
#  'wiright': <gensim.models.keyedvectors.Vocab at 0x7f3195238d30>,
#  'karlrove': <gensim.models.keyedvectors.Vocab at 0x7f3195249048>,
#  'bitchesthecat': <gensim.models.keyedvectors.Vocab at 0x7f3195249080>,
#  '5m': <gensim.models.keyedvectors.Vocab at 0x7f31952490b8>,
#  'joins': <gensim.models.keyedvectors.Vocab at 0x7f31952490f0>,
#  'copy': <gensim.models.keyedvectors.Vocab at 0x7f3195249160>,
#  'modernjam': <gensim.models.keyedvectors.Vocab at 0x7f31952491d0>,
#  'd6ptfwe7n0': <gensim.models.keyedvectors.Vocab at 0x7f3195249278>,
#  'fs': <gensim.models.keyedvectors.Vocab at 0x7f3195249438>,
#  'philstockworld': <gensim.models.keyedvectors.Vocab at 0x7f31952494a8>,
#  'beaches': <gensim.models.keyedvectors.Vocab at 0x7f31950a6278>,
#  'panderi': <gensim.models.keyedvectors.Vocab at 0x7f319513f6a0>,
#  'c': <gensim.models.keyedvectors.Vocab at 0x7f3195249588>,
#  'nj9p7v90nv': <gensim.models.keyedvectors.Vocab at 0x7f3195249630>,
#  'planted': <gensim.models.keyedvectors.Vocab at 0x7f3195100828>,
#  'libcrib': <gensim.models.keyedvectors.Vocab at 0x7f31952496d8>,
#  'touched': <gensim.models.keyedvectors.Vocab at 0x7f3195249710>,
#  'uptomyknees': <gensim.models.keyedvectors.Vocab at 0x7f3195249748>,
#  'remembered': <gensim.models.keyedvectors.Vocab at 0x7f3195249780>,
#  'o9s38elwo5': <gensim.models.keyedvectors.Vocab at 0x7f3195249828>,
#  'studentsforrubio': <gensim.models.keyedvectors.Vocab at 0x7f3195249898>,
#  'randpaul': <gensim.models.keyedvectors.Vocab at 0x7f31950f02e8>,
#  'mojowhoha': <gensim.models.keyedvectors.Vocab at 0x7f3195249940>,
#  '7rsjnzl1rw': <gensim.models.keyedvectors.Vocab at 0x7f31951ea438>,
#  'nanosecond': <gensim.models.keyedvectors.Vocab at 0x7f3195249a20>,
#  'sibe': <gensim.models.keyedvectors.Vocab at 0x7f31951d7550>,
#  'smith': <gensim.models.keyedvectors.Vocab at 0x7f3195249a90>,
#  'aca': <gensim.models.keyedvectors.Vocab at 0x7f3195241240>,
#  'biggest': <gensim.models.keyedvectors.Vocab at 0x7f3195249b70>,
#  'boggles': <gensim.models.keyedvectors.Vocab at 0x7f3195249ba8>,
#  'godsdontexist': <gensim.models.keyedvectors.Vocab at 0x7f3195249c18>,
#  'kihafycss7': <gensim.models.keyedvectors.Vocab at 0x7f31951d5080>,
#  'rj0rz1zmn2': <gensim.models.keyedvectors.Vocab at 0x7f3195249c88>,
#  'bwtmuj4qpe': <gensim.models.keyedvectors.Vocab at 0x7f3195249d68>,
#  'gpnaplang': <gensim.models.keyedvectors.Vocab at 0x7f3195249da0>,
#  'ubw1sfgkzh': <gensim.models.keyedvectors.Vocab at 0x7f3195249208>,
#  'oy': <gensim.models.keyedvectors.Vocab at 0x7f31952492e8>,
#  'newamericancentury': <gensim.models.keyedvectors.Vocab at 0x7f3195249358>,
#  'support4': <gensim.models.keyedvectors.Vocab at 0x7f3195249550>,
#  'joshtpm': <gensim.models.keyedvectors.Vocab at 0x7f31951a0b38>,
#  'dawg': <gensim.models.keyedvectors.Vocab at 0x7f31952497b8>,
#  'hover': <gensim.models.keyedvectors.Vocab at 0x7f31952497f0>,
#  'rxqpfymqre': <gensim.models.keyedvectors.Vocab at 0x7f3195249908>,
#  'straighttalk': <gensim.models.keyedvectors.Vocab at 0x7f31952499b0>,
#  'egomaniacal': <gensim.models.keyedvectors.Vocab at 0x7f3195249ac8>,
#  'rankings': <gensim.models.keyedvectors.Vocab at 0x7f3195103b00>,
#  'truthteamone': <gensim.models.keyedvectors.Vocab at 0x7f3195249cc0>,
#  'mellynjess': <gensim.models.keyedvectors.Vocab at 0x7f3195249cf8>,
#  'quiet': <gensim.models.keyedvectors.Vocab at 0x7f31952461d0>,
#  'jbview': <gensim.models.keyedvectors.Vocab at 0x7f31950feac8>,
#  'mega': <gensim.models.keyedvectors.Vocab at 0x7f3195249f60>,
#  'amandagutterman': <gensim.models.keyedvectors.Vocab at 0x7f3195249320>,
#  'throwing': <gensim.models.keyedvectors.Vocab at 0x7f3195249390>,
#  'savedel': <gensim.models.keyedvectors.Vocab at 0x7f3195249518>,
#  'stats': <gensim.models.keyedvectors.Vocab at 0x7f31951744a8>,
#  'uhq5vx44jw': <gensim.models.keyedvectors.Vocab at 0x7f31952499e8>,
#  'today': <gensim.models.keyedvectors.Vocab at 0x7f319513f860>,
#  'radiofreetom': <gensim.models.keyedvectors.Vocab at 0x7f3195249dd8>,
#  'cult': <gensim.models.keyedvectors.Vocab at 0x7f3195249f98>,
#  'billcosby': <gensim.models.keyedvectors.Vocab at 0x7f3195249fd0>,
#  'strong': <gensim.models.keyedvectors.Vocab at 0x7f3195249470>,
#  '4navxgg1pd': <gensim.models.keyedvectors.Vocab at 0x7f3195249668>,
#  'showed': <gensim.models.keyedvectors.Vocab at 0x7f3195249be0>,
#  'tammy': <gensim.models.keyedvectors.Vocab at 0x7f3195249e10>,
#  'respecting': <gensim.models.keyedvectors.Vocab at 0x7f3195249e80>,
#  'thehumangraham': <gensim.models.keyedvectors.Vocab at 0x7f3195139eb8>,
#  'shtick': <gensim.models.keyedvectors.Vocab at 0x7f3195249ef0>,
#  'kuevblsugk': <gensim.models.keyedvectors.Vocab at 0x7f3195239048>,
#  'markgillar': <gensim.models.keyedvectors.Vocab at 0x7f3195239080>,
#  'toptrevor': <gensim.models.keyedvectors.Vocab at 0x7f31952390f0>,
#  'payattnlibs': <gensim.models.keyedvectors.Vocab at 0x7f3195239128>,
#  'fk2pohfp7y': <gensim.models.keyedvectors.Vocab at 0x7f31951f1198>,
#  'republicanswine': <gensim.models.keyedvectors.Vocab at 0x7f3195167cc0>,
#  'reactions': <gensim.models.keyedvectors.Vocab at 0x7f3195239320>,
#  'exceptionalism': <gensim.models.keyedvectors.Vocab at 0x7f3195239390>,
#  'yikes': <gensim.models.keyedvectors.Vocab at 0x7f31952393c8>,
#  'hgqti01htg': <gensim.models.keyedvectors.Vocab at 0x7f3195174a20>,
#  'rp': <gensim.models.keyedvectors.Vocab at 0x7f3195239470>,
#  'grindingdude': <gensim.models.keyedvectors.Vocab at 0x7f3195239518>,
#  'livelytradition': <gensim.models.keyedvectors.Vocab at 0x7f3195239550>,
#  'cool': <gensim.models.keyedvectors.Vocab at 0x7f3195239588>,
#  'paulul': <gensim.models.keyedvectors.Vocab at 0x7f3195239630>,
#  'china': <gensim.models.keyedvectors.Vocab at 0x7f3195137b38>,
#  'plans': <gensim.models.keyedvectors.Vocab at 0x7f31950d6b70>,
#  'favs': <gensim.models.keyedvectors.Vocab at 0x7f3195239780>,
#  'stcyrlyme2': <gensim.models.keyedvectors.Vocab at 0x7f31952397f0>,
#  'nokellyfiles': <gensim.models.keyedvectors.Vocab at 0x7f3195239828>,
#  'aviation': <gensim.models.keyedvectors.Vocab at 0x7f31952398d0>,
#  'something': <gensim.models.keyedvectors.Vocab at 0x7f3195239908>,
#  'blacktwitter': <gensim.models.keyedvectors.Vocab at 0x7f3195239940>,
#  'gln4dwvcpn': <gensim.models.keyedvectors.Vocab at 0x7f3195239978>,
#  'cities': <gensim.models.keyedvectors.Vocab at 0x7f31952399b0>,
#  'morn': <gensim.models.keyedvectors.Vocab at 0x7f3195237e10>,
#  'irreverin': <gensim.models.keyedvectors.Vocab at 0x7f3195239ac8>,
#  'bwbotevnxe': <gensim.models.keyedvectors.Vocab at 0x7f3195239b00>,
#  'nomorelies': <gensim.models.keyedvectors.Vocab at 0x7f3195239b38>,
#  'gatssnz5ao': <gensim.models.keyedvectors.Vocab at 0x7f3195239b70>,
#  'sfgate': <gensim.models.keyedvectors.Vocab at 0x7f3195239be0>,
#  'planet': <gensim.models.keyedvectors.Vocab at 0x7f3195239cc0>,
#  'actor': <gensim.models.keyedvectors.Vocab at 0x7f3195239dd8>,
#  'valid': <gensim.models.keyedvectors.Vocab at 0x7f3195239e48>,
#  'pickin': <gensim.models.keyedvectors.Vocab at 0x7f3195239eb8>,
#  'urban': <gensim.models.keyedvectors.Vocab at 0x7f3195239f28>,
#  'thatiswhythegopwilllose': <gensim.models.keyedvectors.Vocab at 0x7f3195239fd0>,
#  'keening': <gensim.models.keyedvectors.Vocab at 0x7f3195239240>,
#  'msgoddessrises': <gensim.models.keyedvectors.Vocab at 0x7f3195239358>,
#  'ff': <gensim.models.keyedvectors.Vocab at 0x7f31952395c0>,
#  'apply': <gensim.models.keyedvectors.Vocab at 0x7f31952396a0>,
#  'dgav1xxbn0': <gensim.models.keyedvectors.Vocab at 0x7f3195239710>,
#  'theatrics': <gensim.models.keyedvectors.Vocab at 0x7f3195239860>,
#  '36sdqby52a': <gensim.models.keyedvectors.Vocab at 0x7f31952399e8>,
#  'anniv': <gensim.models.keyedvectors.Vocab at 0x7f3195239a58>,
#  'seculardotorg': <gensim.models.keyedvectors.Vocab at 0x7f31950f0828>,
#  'probability': <gensim.models.keyedvectors.Vocab at 0x7f3195239ba8>,
#  'repolast': <gensim.models.keyedvectors.Vocab at 0x7f3195239c18>,
#  'tqkalafl8j': <gensim.models.keyedvectors.Vocab at 0x7f3195239c88>,
#  'extend': <gensim.models.keyedvectors.Vocab at 0x7f3195239d68>,
#  'fu': <gensim.models.keyedvectors.Vocab at 0x7f3195239e10>,
#  'deals': <gensim.models.keyedvectors.Vocab at 0x7f3195239f60>,
#  'resembled': <gensim.models.keyedvectors.Vocab at 0x7f3195239f98>,
#  'shapes': <gensim.models.keyedvectors.Vocab at 0x7f3195239160>,
#  'sheesh': <gensim.models.keyedvectors.Vocab at 0x7f31952391d0>,
#  'oz6upibxrp': <gensim.models.keyedvectors.Vocab at 0x7f3195239668>,
#  'walter': <gensim.models.keyedvectors.Vocab at 0x7f3195239a90>,
#  'craftbeer': <gensim.models.keyedvectors.Vocab at 0x7f3195239c50>,
#  'correspondent': <gensim.models.keyedvectors.Vocab at 0x7f31950f09e8>,
#  'force': <gensim.models.keyedvectors.Vocab at 0x7f3195239ef0>,
#  '6m': <gensim.models.keyedvectors.Vocab at 0x7f31951745f8>,
#  'onelegsandpiper': <gensim.models.keyedvectors.Vocab at 0x7f3195239748>,
#  'b9p8wg3ixz': <gensim.models.keyedvectors.Vocab at 0x7f31952397b8>,
#  'locate': <gensim.models.keyedvectors.Vocab at 0x7f31950f0a58>,
#  'choicers': <gensim.models.keyedvectors.Vocab at 0x7f3195239898>,
#  'anzmdiorve': <gensim.models.keyedvectors.Vocab at 0x7f3195239e80>,
#  'bullshit': <gensim.models.keyedvectors.Vocab at 0x7f319509f8d0>,
#  'goal': <gensim.models.keyedvectors.Vocab at 0x7f319523f080>,
#  'rik': <gensim.models.keyedvectors.Vocab at 0x7f319523f0f0>,
#  'rpqiu6ulvo': <gensim.models.keyedvectors.Vocab at 0x7f319523f128>,
#  'filled': <gensim.models.keyedvectors.Vocab at 0x7f319523f160>,
#  'jamaldajani': <gensim.models.keyedvectors.Vocab at 0x7f319523f278>,
#  'ha': <gensim.models.keyedvectors.Vocab at 0x7f319523f320>,
#  'gopdebacle': <gensim.models.keyedvectors.Vocab at 0x7f319523f358>,
#  'llspafhla0': <gensim.models.keyedvectors.Vocab at 0x7f31951c2668>,
#  'pursedlips': <gensim.models.keyedvectors.Vocab at 0x7f319523f3c8>,
#  'reboot': <gensim.models.keyedvectors.Vocab at 0x7f319523f400>,
#  'woot': <gensim.models.keyedvectors.Vocab at 0x7f319524e630>,
#  'exaggerated': <gensim.models.keyedvectors.Vocab at 0x7f319523f4e0>,
#  'lennykravitz': <gensim.models.keyedvectors.Vocab at 0x7f319524eb70>,
#  'pales': <gensim.models.keyedvectors.Vocab at 0x7f319523f6d8>,
#  'wreak': <gensim.models.keyedvectors.Vocab at 0x7f319523f7f0>,
#  'mp': <gensim.models.keyedvectors.Vocab at 0x7f319523f828>,
#  'politicalnightmare': <gensim.models.keyedvectors.Vocab at 0x7f319523f940>,
#  'flickerman': <gensim.models.keyedvectors.Vocab at 0x7f319523fa20>,
#  'm59gdl3zgt': <gensim.models.keyedvectors.Vocab at 0x7f319523fa58>,
#  'wait': <gensim.models.keyedvectors.Vocab at 0x7f319523fac8>,
#  'realdonaldtrumps': <gensim.models.keyedvectors.Vocab at 0x7f31951e4908>,
#  'phones': <gensim.models.keyedvectors.Vocab at 0x7f319523fbe0>,
#  'hoping': <gensim.models.keyedvectors.Vocab at 0x7f319523f0b8>,
#  'admits': <gensim.models.keyedvectors.Vocab at 0x7f319523fc50>,
#  'tithe': <gensim.models.keyedvectors.Vocab at 0x7f319523fc88>,
#  'clearly': <gensim.models.keyedvectors.Vocab at 0x7f319523fcf8>,
#  'defensebaron': <gensim.models.keyedvectors.Vocab at 0x7f319523fe10>,
#  'avkcv5ahqi': <gensim.models.keyedvectors.Vocab at 0x7f31951dd7f0>,
#  'easily': <gensim.models.keyedvectors.Vocab at 0x7f31951d8198>,
#  'ybtt5vytlr': <gensim.models.keyedvectors.Vocab at 0x7f319523ff60>,
#  'rolling': <gensim.models.keyedvectors.Vocab at 0x7f319523ff98>,
#  'speakin': <gensim.models.keyedvectors.Vocab at 0x7f319523ffd0>,
#  'r4e8tpotd5': <gensim.models.keyedvectors.Vocab at 0x7f319523f208>,
#  'fyhzzn5qp3': <gensim.models.keyedvectors.Vocab at 0x7f319523f2b0>,
#  'prerequisite': <gensim.models.keyedvectors.Vocab at 0x7f319523f470>,
#  'macauley': <gensim.models.keyedvectors.Vocab at 0x7f319523f550>,
#  'th2016': <gensim.models.keyedvectors.Vocab at 0x7f319523f588>,
#  'howell': <gensim.models.keyedvectors.Vocab at 0x7f319523f630>,
#  'kushandalcohol': <gensim.models.keyedvectors.Vocab at 0x7f319523f668>,
#  'bmh8u80tyh': <gensim.models.keyedvectors.Vocab at 0x7f319523f6a0>,
#  'sol': <gensim.models.keyedvectors.Vocab at 0x7f319523f710>,
#  'eqfo1j5ezw': <gensim.models.keyedvectors.Vocab at 0x7f319523f860>,
#  'ysi1o5tj4q': <gensim.models.keyedvectors.Vocab at 0x7f319523f898>,
#  'notthatguy': <gensim.models.keyedvectors.Vocab at 0x7f319523f9e8>,
#  'wordplay4days': <gensim.models.keyedvectors.Vocab at 0x7f319523fb70>,
#  'ubw2aoimxh': <gensim.models.keyedvectors.Vocab at 0x7f319523ff28>,
#  'qofpmihaye': <gensim.models.keyedvectors.Vocab at 0x7f319523f198>,
#  'blks': <gensim.models.keyedvectors.Vocab at 0x7f319523f518>,
#  'box': <gensim.models.keyedvectors.Vocab at 0x7f31951e9320>,
#  'donlynturnbull': <gensim.models.keyedvectors.Vocab at 0x7f319523f780>,
#  'activists': <gensim.models.keyedvectors.Vocab at 0x7f319509c048>,
#  'qgwm5': <gensim.models.keyedvectors.Vocab at 0x7f319523f978>,
#  'straits': <gensim.models.keyedvectors.Vocab at 0x7f319523fd30>,
#  'phoenix': <gensim.models.keyedvectors.Vocab at 0x7f319523fdd8>,
#  'darthputinkgb': <gensim.models.keyedvectors.Vocab at 0x7f319523fb00>,
#  'practiced': <gensim.models.keyedvectors.Vocab at 0x7f319523f908>,
#  'uses': <gensim.models.keyedvectors.Vocab at 0x7f319523fc18>,
#  'egged': <gensim.models.keyedvectors.Vocab at 0x7f31951e9898>,
#  'joe': <gensim.models.keyedvectors.Vocab at 0x7f319523fd68>,
#  'damienfahey': <gensim.models.keyedvectors.Vocab at 0x7f319523f240>,
#  '1012000': <gensim.models.keyedvectors.Vocab at 0x7f319523f2e8>,
#  'oyzwnvvplv': <gensim.models.keyedvectors.Vocab at 0x7f319523f8d0>,
#  'specific': <gensim.models.keyedvectors.Vocab at 0x7f31952420f0>,
#  'tomb': <gensim.models.keyedvectors.Vocab at 0x7f3195242198>,
#  'tak31523': <gensim.models.keyedvectors.Vocab at 0x7f3195242278>,
#  'twitterland': <gensim.models.keyedvectors.Vocab at 0x7f31952422e8>,
#  'stories': <gensim.models.keyedvectors.Vocab at 0x7f3195242320>,
#  'trumptastic': <gensim.models.keyedvectors.Vocab at 0x7f3195242390>,
#  'cor': <gensim.models.keyedvectors.Vocab at 0x7f3195242470>,
#  'ncwnw9jttt': <gensim.models.keyedvectors.Vocab at 0x7f31952424a8>,
#  'survives': <gensim.models.keyedvectors.Vocab at 0x7f3195242550>,
#  'spark': <gensim.models.keyedvectors.Vocab at 0x7f31952425c0>,
#  'indicator': <gensim.models.keyedvectors.Vocab at 0x7f31951c2080>,
#  'incest': <gensim.models.keyedvectors.Vocab at 0x7f31952425f8>,
#  'hateful': <gensim.models.keyedvectors.Vocab at 0x7f3195242630>,
#  'rickungar': <gensim.models.keyedvectors.Vocab at 0x7f31950f01d0>,
#  'supported': <gensim.models.keyedvectors.Vocab at 0x7f3195242898>,
#  'dontlettrumpspeak': <gensim.models.keyedvectors.Vocab at 0x7f31950f9be0>,
#  'rushlimbaugh': <gensim.models.keyedvectors.Vocab at 0x7f3195242978>,
#  '87p5eew8w7': <gensim.models.keyedvectors.Vocab at 0x7f31950f02b0>,
#  'tp1ptwujfa': <gensim.models.keyedvectors.Vocab at 0x7f3195242a58>,
#  'percent': <gensim.models.keyedvectors.Vocab at 0x7f3195242ac8>,
#  'agrees': <gensim.models.keyedvectors.Vocab at 0x7f3195242b38>,
#  'acres': <gensim.models.keyedvectors.Vocab at 0x7f3195242ba8>,
#  'presented': <gensim.models.keyedvectors.Vocab at 0x7f3195242be0>,
#  'mentions': <gensim.models.keyedvectors.Vocab at 0x7f3195242c18>,
#  'regards': <gensim.models.keyedvectors.Vocab at 0x7f319510f978>,
#  'thingsthatshouldbebasiclogic': <gensim.models.keyedvectors.Vocab at 0x7f3195242c88>,
#  'qocnoixedn': <gensim.models.keyedvectors.Vocab at 0x7f3195242cf8>,
#  'primary': <gensim.models.keyedvectors.Vocab at 0x7f3195242d68>,
#  'fergu': <gensim.models.keyedvectors.Vocab at 0x7f3195167080>,
#  'zycg0ixwru': <gensim.models.keyedvectors.Vocab at 0x7f3195242e10>,
#  'alike': <gensim.models.keyedvectors.Vocab at 0x7f3195242eb8>,
#  '4ih7btyeaz': <gensim.models.keyedvectors.Vocab at 0x7f31950e7ac8>,
#  'suggested': <gensim.models.keyedvectors.Vocab at 0x7f3195242ef0>,
#  'seems': <gensim.models.keyedvectors.Vocab at 0x7f3195167128>,
#  'going': <gensim.models.keyedvectors.Vocab at 0x7f3195242780>,
#  'influenced': <gensim.models.keyedvectors.Vocab at 0x7f31952427f0>,
#  'soda': <gensim.models.keyedvectors.Vocab at 0x7f3195100cc0>,
#  'lyrics': <gensim.models.keyedvectors.Vocab at 0x7f3195242860>,
#  'handled': <gensim.models.keyedvectors.Vocab at 0x7f3195242940>,
#  'specialguest': <gensim.models.keyedvectors.Vocab at 0x7f31952429e8>,
#  'sealevelrise': <gensim.models.keyedvectors.Vocab at 0x7f3195242b00>,
#  'latism': <gensim.models.keyedvectors.Vocab at 0x7f3195242e48>,
#  'xjtnrv0udk': <gensim.models.keyedvectors.Vocab at 0x7f31951f7e80>,
#  'uipoaigi9a': <gensim.models.keyedvectors.Vocab at 0x7f3195242f98>,
#  'incumbency': <gensim.models.keyedvectors.Vocab at 0x7f3195242080>,
#  'ballcap': <gensim.models.keyedvectors.Vocab at 0x7f3195242160>,
#  '1catherinesiena': <gensim.models.keyedvectors.Vocab at 0x7f3195242208>,
#  'deceiving': <gensim.models.keyedvectors.Vocab at 0x7f31952422b0>,
#  'iammgraham': <gensim.models.keyedvectors.Vocab at 0x7f3195242358>,
#  'agree': <gensim.models.keyedvectors.Vocab at 0x7f31952423c8>,
#  'mozgovaya': <gensim.models.keyedvectors.Vocab at 0x7f3195242438>,
#  'billayers': <gensim.models.keyedvectors.Vocab at 0x7f3195242588>,
#  'kiss': <gensim.models.keyedvectors.Vocab at 0x7f3195242710>,
#  'cons': <gensim.models.keyedvectors.Vocab at 0x7f31952427b8>,
#  'close': <gensim.models.keyedvectors.Vocab at 0x7f3195137c50>,
#  'w1qvowu2cb': <gensim.models.keyedvectors.Vocab at 0x7f319519e7b8>,
#  'tie': <gensim.models.keyedvectors.Vocab at 0x7f3195242b70>,
#  'transgendered': <gensim.models.keyedvectors.Vocab at 0x7f3195242cc0>,
#  'xqjbinizte': <gensim.models.keyedvectors.Vocab at 0x7f3195242f60>,
#  'shadowbard': <gensim.models.keyedvectors.Vocab at 0x7f31952421d0>,
#  'affinity': <gensim.models.keyedvectors.Vocab at 0x7f31952426a0>,
#  'poker': <gensim.models.keyedvectors.Vocab at 0x7f31951672b0>,
#  'cheating': <gensim.models.keyedvectors.Vocab at 0x7f31952426d8>,
#  'chadtrim': <gensim.models.keyedvectors.Vocab at 0x7f3195242c50>,
#  'brains': <gensim.models.keyedvectors.Vocab at 0x7f3195242d30>,
#  'unique': <gensim.models.keyedvectors.Vocab at 0x7f3195247080>,
#  '9cdnol3tm7': <gensim.models.keyedvectors.Vocab at 0x7f3195247198>,
#  'mchamric': <gensim.models.keyedvectors.Vocab at 0x7f3195247278>,
#  'trumpmisogynist': <gensim.models.keyedvectors.Vocab at 0x7f31951a36d8>,
#  'sting': <gensim.models.keyedvectors.Vocab at 0x7f3195247358>,
#  'salty': <gensim.models.keyedvectors.Vocab at 0x7f31950dde48>,
#  'conservative': <gensim.models.keyedvectors.Vocab at 0x7f3195247390>,
#  'gunnin': <gensim.models.keyedvectors.Vocab at 0x7f31952474a8>,
#  'agreed': <gensim.models.keyedvectors.Vocab at 0x7f3195247518>,
#  'demuerte': <gensim.models.keyedvectors.Vocab at 0x7f3195247588>,
#  'ohxdllknvx': <gensim.models.keyedvectors.Vocab at 0x7f31952476d8>,
#  'wiser': <gensim.models.keyedvectors.Vocab at 0x7f31950f0d68>,
#  'thomasmybarra': <gensim.models.keyedvectors.Vocab at 0x7f31950dfe10>,
#  'possibly': <gensim.models.keyedvectors.Vocab at 0x7f3195247710>,
#  'cord': <gensim.models.keyedvectors.Vocab at 0x7f31950f0da0>,
#  'soul': <gensim.models.keyedvectors.Vocab at 0x7f3195247828>,
#  'kurtschlichter': <gensim.models.keyedvectors.Vocab at 0x7f3195247860>,
#  'lpodl5pt1t': <gensim.models.keyedvectors.Vocab at 0x7f3195247908>,
#  'excuses': <gensim.models.keyedvectors.Vocab at 0x7f31951ec6d8>,
#  'germanirishlass': <gensim.models.keyedvectors.Vocab at 0x7f31952479e8>,
#  'outsider': <gensim.models.keyedvectors.Vocab at 0x7f3195247ac8>,
#  'wildest': <gensim.models.keyedvectors.Vocab at 0x7f3195247b00>,
#  's9hsbtzrsc': <gensim.models.keyedvectors.Vocab at 0x7f3195247b70>,
#  'jmekk2adkh': <gensim.models.keyedvectors.Vocab at 0x7f31950ab4a8>,
#  'futiledemocracy': <gensim.models.keyedvectors.Vocab at 0x7f3195247ba8>,
#  'newest': <gensim.models.keyedvectors.Vocab at 0x7f3195247c18>,
#  'embarrassment': <gensim.models.keyedvectors.Vocab at 0x7f3195247c88>,
#  'vers': <gensim.models.keyedvectors.Vocab at 0x7f3195247cf8>,
#  'meaningful': <gensim.models.keyedvectors.Vocab at 0x7f3195247d68>,
#  'tallest': <gensim.models.keyedvectors.Vocab at 0x7f3195247e10>,
#  'f2b': <gensim.models.keyedvectors.Vocab at 0x7f3195247e80>,
#  'info': <gensim.models.keyedvectors.Vocab at 0x7f3195247f60>,
#  'q83qu3u422': <gensim.models.keyedvectors.Vocab at 0x7f3195247128>,
#  'sethblanchard': <gensim.models.keyedvectors.Vocab at 0x7f3195247240>,
#  'visual': <gensim.models.keyedvectors.Vocab at 0x7f3195247400>,
#  'unlikable': <gensim.models.keyedvectors.Vocab at 0x7f3195247438>,
#  'california': <gensim.models.keyedvectors.Vocab at 0x7f319510ec50>,
#  'xw1baii9lq': <gensim.models.keyedvectors.Vocab at 0x7f3195167470>,
#  'careless': <gensim.models.keyedvectors.Vocab at 0x7f31952474e0>,
#  'logic': <gensim.models.keyedvectors.Vocab at 0x7f31952475c0>,
#  'njea': <gensim.models.keyedvectors.Vocab at 0x7f3195247668>,
#  'commanded': <gensim.models.keyedvectors.Vocab at 0x7f3195247898>,
#  'stellar': <gensim.models.keyedvectors.Vocab at 0x7f3195183c50>,
#  'quarterback': <gensim.models.keyedvectors.Vocab at 0x7f31952479b0>,
#  'demagog': <gensim.models.keyedvectors.Vocab at 0x7f3195247a90>,
#  'fuuuuun': <gensim.models.keyedvectors.Vocab at 0x7f319513af98>,
#  'hemdash': <gensim.models.keyedvectors.Vocab at 0x7f3195247c50>,
#  'v0qxraxbq0': <gensim.models.keyedvectors.Vocab at 0x7f3195247dd8>,
#  'gfyti5ilvc': <gensim.models.keyedvectors.Vocab at 0x7f31951f4ba8>,
#  'madelyne': <gensim.models.keyedvectors.Vocab at 0x7f3195122518>,
#  'hockey': <gensim.models.keyedvectors.Vocab at 0x7f3195247fd0>,
#  'voucher': <gensim.models.keyedvectors.Vocab at 0x7f31952470b8>,
#  'qtzejscxas': <gensim.models.keyedvectors.Vocab at 0x7f3195247160>,
#  'bracketed': <gensim.models.keyedvectors.Vocab at 0x7f31950a3278>,
#  'exclusion': <gensim.models.keyedvectors.Vocab at 0x7f31952472b0>,
#  'gndrtlfsnt': <gensim.models.keyedvectors.Vocab at 0x7f31952472e8>,
#  'drbhotchkins': <gensim.models.keyedvectors.Vocab at 0x7f3195247780>,
#  'wheeee': <gensim.models.keyedvectors.Vocab at 0x7f31952357f0>,
#  'kellykade': <gensim.models.keyedvectors.Vocab at 0x7f3195247a20>,
#  'gluttonforpunishment': <gensim.models.keyedvectors.Vocab at 0x7f3195247a58>,
#  '2vryvxptgu': <gensim.models.keyedvectors.Vocab at 0x7f31950a0828>,
#  'demsabroad': <gensim.models.keyedvectors.Vocab at 0x7f3195247eb8>,
#  '2irxupixke': <gensim.models.keyedvectors.Vocab at 0x7f3195247f28>,
#  'steagall': <gensim.models.keyedvectors.Vocab at 0x7f3195247630>,
#  'grovernorquist': <gensim.models.keyedvectors.Vocab at 0x7f31952476a0>,
#  'percenters': <gensim.models.keyedvectors.Vocab at 0x7f3195247d30>,
#  'prison': <gensim.models.keyedvectors.Vocab at 0x7f3195247da0>,
#  'servicemembers': <gensim.models.keyedvectors.Vocab at 0x7f319523a080>,
#  'owe': <gensim.models.keyedvectors.Vocab at 0x7f319523a1d0>,
#  'haters': <gensim.models.keyedvectors.Vocab at 0x7f31950e16a0>,
#  'hours': <gensim.models.keyedvectors.Vocab at 0x7f319523a278>,
#  'olivia': <gensim.models.keyedvectors.Vocab at 0x7f319523a2b0>,
#  '5y3hh7pcml': <gensim.models.keyedvectors.Vocab at 0x7f319523a2e8>,
#  'mspackyetti': <gensim.models.keyedvectors.Vocab at 0x7f319523a390>,
#  'colorblindness': <gensim.models.keyedvectors.Vocab at 0x7f319523a470>,
#  'fans': <gensim.models.keyedvectors.Vocab at 0x7f3195111128>,
#  'klux': <gensim.models.keyedvectors.Vocab at 0x7f319523a4e0>,
#  'anyway': <gensim.models.keyedvectors.Vocab at 0x7f319523a550>,
#  'justjr': <gensim.models.keyedvectors.Vocab at 0x7f31951401d0>,
#  'cousupreme': <gensim.models.keyedvectors.Vocab at 0x7f3195251cc0>,
#  'feet': <gensim.models.keyedvectors.Vocab at 0x7f319523a668>,
#  'esqpolitics': <gensim.models.keyedvectors.Vocab at 0x7f319523a748>,
#  'jabs': <gensim.models.keyedvectors.Vocab at 0x7f319523a8d0>,
#  'gavin': <gensim.models.keyedvectors.Vocab at 0x7f319523a908>,
#  'benedictcumberbatch': <gensim.models.keyedvectors.Vocab at 0x7f319523a978>,
#  'spears': <gensim.models.keyedvectors.Vocab at 0x7f319523aa58>,
#  'jncatron': <gensim.models.keyedvectors.Vocab at 0x7f319523aac8>,
#  'jimmylasalvia': <gensim.models.keyedvectors.Vocab at 0x7f319523ab70>,
#  'awwwww': <gensim.models.keyedvectors.Vocab at 0x7f319523ac50>,
#  'articles': <gensim.models.keyedvectors.Vocab at 0x7f319523acf8>,
#  'mallets': <gensim.models.keyedvectors.Vocab at 0x7f319523ad30>,
#  'wienies': <gensim.models.keyedvectors.Vocab at 0x7f319523ada0>,
#  'itsradishtime': <gensim.models.keyedvectors.Vocab at 0x7f3195253470>,
#  '6zjwbxbpse': <gensim.models.keyedvectors.Vocab at 0x7f319509d748>,
#  'kr55ae6jur': <gensim.models.keyedvectors.Vocab at 0x7f319523ae10>,
#  'receiving': <gensim.models.keyedvectors.Vocab at 0x7f319523ae80>,
#  'justiceputnam': <gensim.models.keyedvectors.Vocab at 0x7f319523af60>,
#  'confidence': <gensim.models.keyedvectors.Vocab at 0x7f3195111390>,
#  'legs': <gensim.models.keyedvectors.Vocab at 0x7f31951370b8>,
#  'ruff': <gensim.models.keyedvectors.Vocab at 0x7f319523a240>,
#  'harmed': <gensim.models.keyedvectors.Vocab at 0x7f319523a358>,
#  '74': <gensim.models.keyedvectors.Vocab at 0x7f319515e1d0>,
#  'creditors': <gensim.models.keyedvectors.Vocab at 0x7f3195167710>,
#  'pyj4huhgje': <gensim.models.keyedvectors.Vocab at 0x7f319523a5f8>,
#  'repelled': <gensim.models.keyedvectors.Vocab at 0x7f319523a7f0>,
#  'kikkiplanet': <gensim.models.keyedvectors.Vocab at 0x7f319523a860>,
#  'rocks': <gensim.models.keyedvectors.Vocab at 0x7f319523a940>,
#  'invisible': <gensim.models.keyedvectors.Vocab at 0x7f3195204208>,
#  'ballers': <gensim.models.keyedvectors.Vocab at 0x7f319523ac18>,
#  'millenials': <gensim.models.keyedvectors.Vocab at 0x7f3195137128>,
#  'thou': <gensim.models.keyedvectors.Vocab at 0x7f3195167748>,
#  'laurenekelly': <gensim.models.keyedvectors.Vocab at 0x7f319523af28>,
#  'roses': <gensim.models.keyedvectors.Vocab at 0x7f319523a0f0>,
#  'johnsununu': <gensim.models.keyedvectors.Vocab at 0x7f319523a320>,
#  'uzpmkfosyq': <gensim.models.keyedvectors.Vocab at 0x7f3195157f28>,
#  'jgnn2f5qo2': <gensim.models.keyedvectors.Vocab at 0x7f319523aa20>,
#  'puppy': <gensim.models.keyedvectors.Vocab at 0x7f319523ab38>,
#  'doriabiddle': <gensim.models.keyedvectors.Vocab at 0x7f319523a0b8>,
#  'oil': <gensim.models.keyedvectors.Vocab at 0x7f319523a198>,
#  'solution': <gensim.models.keyedvectors.Vocab at 0x7f319523a588>,
#  'christ': <gensim.models.keyedvectors.Vocab at 0x7f319523a9e8>,
#  'vvia1nuyld': <gensim.models.keyedvectors.Vocab at 0x7f319523afd0>,
#  'trumpattheroxbury': <gensim.models.keyedvectors.Vocab at 0x7f319523a3c8>,
#  'aroww333': <gensim.models.keyedvectors.Vocab at 0x7f319523a400>,
#  'denying': <gensim.models.keyedvectors.Vocab at 0x7f319523a6a0>,
#  '2afight': <gensim.models.keyedvectors.Vocab at 0x7f319523a710>,
#  'moe67': <gensim.models.keyedvectors.Vocab at 0x7f319523abe0>,
#  'matt': <gensim.models.keyedvectors.Vocab at 0x7f319523af98>,
#  'michiganforben': <gensim.models.keyedvectors.Vocab at 0x7f319524a048>,
#  'karibowiehertel': <gensim.models.keyedvectors.Vocab at 0x7f319524a128>,
#  'safer': <gensim.models.keyedvectors.Vocab at 0x7f319524a240>,
#  'jobs': <gensim.models.keyedvectors.Vocab at 0x7f319524a2e8>,
#  'keithboykin': <gensim.models.keyedvectors.Vocab at 0x7f319524a3c8>,
#  'brotherhood': <gensim.models.keyedvectors.Vocab at 0x7f319524a438>,
#  'guardian': <gensim.models.keyedvectors.Vocab at 0x7f319524a518>,
#  'amandajogomez': <gensim.models.keyedvectors.Vocab at 0x7f319524a7b8>,
#  'qgguob2kf6': <gensim.models.keyedvectors.Vocab at 0x7f319524a7f0>,
#  'rbpoms07gc': <gensim.models.keyedvectors.Vocab at 0x7f319524a828>,
#  'iangarytweets': <gensim.models.keyedvectors.Vocab at 0x7f319524a860>,
#  'locally': <gensim.models.keyedvectors.Vocab at 0x7f319524a908>,
#  'franchise2205': <gensim.models.keyedvectors.Vocab at 0x7f319524a940>,
#  'vyjl9fkxx6': <gensim.models.keyedvectors.Vocab at 0x7f31951f4d30>,
#  'complaints': <gensim.models.keyedvectors.Vocab at 0x7f319524a9b0>,
#  'extension': <gensim.models.keyedvectors.Vocab at 0x7f319510ed68>,
#  'child': <gensim.models.keyedvectors.Vocab at 0x7f319524aa20>,
#  'dz': <gensim.models.keyedvectors.Vocab at 0x7f31950f8128>,
#  'leighpatrick': <gensim.models.keyedvectors.Vocab at 0x7f319524aac8>,
#  'm1i4edf9pq': <gensim.models.keyedvectors.Vocab at 0x7f31952529b0>,
#  'hottake': <gensim.models.keyedvectors.Vocab at 0x7f319524ab38>,
#  'housewives': <gensim.models.keyedvectors.Vocab at 0x7f319524aba8>,
#  'unlimited': <gensim.models.keyedvectors.Vocab at 0x7f319524ac18>,
#  'defies': <gensim.models.keyedvectors.Vocab at 0x7f319524ac50>,
#  'behide': <gensim.models.keyedvectors.Vocab at 0x7f319524ad30>,
#  'quantity': <gensim.models.keyedvectors.Vocab at 0x7f319524ada0>,
#  'merits': <gensim.models.keyedvectors.Vocab at 0x7f31951fdf98>,
#  'nine': <gensim.models.keyedvectors.Vocab at 0x7f319524af60>,
#  'sbg1': <gensim.models.keyedvectors.Vocab at 0x7f319524af98>,
#  'faith': <gensim.models.keyedvectors.Vocab at 0x7f319524a080>,
#  'qualification': <gensim.models.keyedvectors.Vocab at 0x7f319524a198>,
#  'ross': <gensim.models.keyedvectors.Vocab at 0x7f319524a278>,
#  'redeeming': <gensim.models.keyedvectors.Vocab at 0x7f319524a2b0>,
#  'carlspry': <gensim.models.keyedvectors.Vocab at 0x7f31951c7cc0>,
#  'patient': <gensim.models.keyedvectors.Vocab at 0x7f319524a320>,
#  'framing': <gensim.models.keyedvectors.Vocab at 0x7f319520f3c8>,
#  'trounce': <gensim.models.keyedvectors.Vocab at 0x7f319524a400>,
#  'pecan': <gensim.models.keyedvectors.Vocab at 0x7f319524fa90>,
#  'generations': <gensim.models.keyedvectors.Vocab at 0x7f31951af470>,
#  'drinking': <gensim.models.keyedvectors.Vocab at 0x7f319524a5f8>,
#  'personified': <gensim.models.keyedvectors.Vocab at 0x7f319524a898>,
#  'time': <gensim.models.keyedvectors.Vocab at 0x7f319524a9e8>,
#  'wisdom': <gensim.models.keyedvectors.Vocab at 0x7f319524aa58>,
#  'plvdwlmars': <gensim.models.keyedvectors.Vocab at 0x7f319524aa90>,
#  'appealing': <gensim.models.keyedvectors.Vocab at 0x7f319524ab70>,
#  'adobo': <gensim.models.keyedvectors.Vocab at 0x7f319524abe0>,
#  'violating': <gensim.models.keyedvectors.Vocab at 0x7f319524ac88>,
#  '501c3': <gensim.models.keyedvectors.Vocab at 0x7f319524ae48>,
#  'adaptable': <gensim.models.keyedvectors.Vocab at 0x7f319524aeb8>,
#  'domestically': <gensim.models.keyedvectors.Vocab at 0x7f319524aef0>,
#  'huckabee2016': <gensim.models.keyedvectors.Vocab at 0x7f319524afd0>,
#  'celeb': <gensim.models.keyedvectors.Vocab at 0x7f319524a0f0>,
#  'drunkjcrewuguys': <gensim.models.keyedvectors.Vocab at 0x7f319524a160>,
#  'foxfriendsfirst': <gensim.models.keyedvectors.Vocab at 0x7f319524a588>,
#  'eodchick': <gensim.models.keyedvectors.Vocab at 0x7f319524a8d0>,
#  'moved': <gensim.models.keyedvectors.Vocab at 0x7f319524add8>,
#  'naivete': <gensim.models.keyedvectors.Vocab at 0x7f319524a1d0>,
#  'danaperino': <gensim.models.keyedvectors.Vocab at 0x7f319524a208>,
#  'mikeallen': <gensim.models.keyedvectors.Vocab at 0x7f319524a5c0>,
#  'perspective': <gensim.models.keyedvectors.Vocab at 0x7f319524acf8>,
#  'borders': <gensim.models.keyedvectors.Vocab at 0x7f319524ae80>,
#  'rawstory': <gensim.models.keyedvectors.Vocab at 0x7f319524a390>,
#  'truestory': <gensim.models.keyedvectors.Vocab at 0x7f319524a0b8>,
#  'yuikaxrvtv': <gensim.models.keyedvectors.Vocab at 0x7f3195237080>,
#  'lining': <gensim.models.keyedvectors.Vocab at 0x7f3195237128>,
#  'nra': <gensim.models.keyedvectors.Vocab at 0x7f319513dc88>,
#  'thatchrisgore': <gensim.models.keyedvectors.Vocab at 0x7f3195237198>,
#  'kimye': <gensim.models.keyedvectors.Vocab at 0x7f3195237240>,
#  'roadto2016': <gensim.models.keyedvectors.Vocab at 0x7f31951a0400>,
#  'traitor': <gensim.models.keyedvectors.Vocab at 0x7f3195237320>,
#  'kevantrich': <gensim.models.keyedvectors.Vocab at 0x7f31952374a8>,
#  'informed': <gensim.models.keyedvectors.Vocab at 0x7f31952374e0>,
#  '5f8mdy0rbx': <gensim.models.keyedvectors.Vocab at 0x7f31952375c0>,
#  'bengeesaman': <gensim.models.keyedvectors.Vocab at 0x7f31952375f8>,
#  'correctness': <gensim.models.keyedvectors.Vocab at 0x7f31952376a0>,
#  'sdblanke': <gensim.models.keyedvectors.Vocab at 0x7f3195237748>,
#  'cameron': <gensim.models.keyedvectors.Vocab at 0x7f3195238c50>,
#  'boaz': <gensim.models.keyedvectors.Vocab at 0x7f319518f7f0>,
#  'unbiased': <gensim.models.keyedvectors.Vocab at 0x7f31950f8518>,
#  'ken2ts': <gensim.models.keyedvectors.Vocab at 0x7f3195237908>,
#  'diva': <gensim.models.keyedvectors.Vocab at 0x7f3195237978>,
#  'amy': <gensim.models.keyedvectors.Vocab at 0x7f319509b160>,
#  '4p1vqtiwxf': <gensim.models.keyedvectors.Vocab at 0x7f3195237a58>,
#  'yr9m2mf9fh': <gensim.models.keyedvectors.Vocab at 0x7f31951f4f98>,
#  'quarantine': <gensim.models.keyedvectors.Vocab at 0x7f3195237be0>,
#  'stewathedailyshow': <gensim.models.keyedvectors.Vocab at 0x7f31951377f0>,
#  'hulashes': <gensim.models.keyedvectors.Vocab at 0x7f3195237dd8>,
#  'frozen': <gensim.models.keyedvectors.Vocab at 0x7f3195237e48>,
#  'cause': <gensim.models.keyedvectors.Vocab at 0x7f3195237ef0>,
#  'feed': <gensim.models.keyedvectors.Vocab at 0x7f3195237f60>,
#  'sprightlymagic': <gensim.models.keyedvectors.Vocab at 0x7f3195237f98>,
#  'scrub': <gensim.models.keyedvectors.Vocab at 0x7f31952370b8>,
#  'johneberkowitz': <gensim.models.keyedvectors.Vocab at 0x7f31952370f0>,
#  'peaceful': <gensim.models.keyedvectors.Vocab at 0x7f31952371d0>,
#  'bearrett50cal': <gensim.models.keyedvectors.Vocab at 0x7f31951c2828>,
#  'hint': <gensim.models.keyedvectors.Vocab at 0x7f31950a6550>,
#  '0psskxzuyj': <gensim.models.keyedvectors.Vocab at 0x7f3195237390>,
#  'tee': <gensim.models.keyedvectors.Vocab at 0x7f3195237470>,
#  'thattexasboy26': <gensim.models.keyedvectors.Vocab at 0x7f319513d9b0>,
#  'blacksab67': <gensim.models.keyedvectors.Vocab at 0x7f3195102358>,
#  'mcuban': <gensim.models.keyedvectors.Vocab at 0x7f3195244a20>,
#  'randomthoughts': <gensim.models.keyedvectors.Vocab at 0x7f3195237860>,
#  'compete': <gensim.models.keyedvectors.Vocab at 0x7f3195237940>,
#  'x9rqvsil': <gensim.models.keyedvectors.Vocab at 0x7f3195200a20>,
#  'insightful': <gensim.models.keyedvectors.Vocab at 0x7f3195113ba8>,
#  'uywu9jqcex': <gensim.models.keyedvectors.Vocab at 0x7f3195237b70>,
# ...
#  'communist': <gensim.models.keyedvectors.Vocab at 0x7f319523deb8>,
#  'jebspeak': <gensim.models.keyedvectors.Vocab at 0x7f319523def0>,
#  'europeans': <gensim.models.keyedvectors.Vocab at 0x7f319523df60>,
#  'segregated': <gensim.models.keyedvectors.Vocab at 0x7f319523d080>,
#  'microsoft': <gensim.models.keyedvectors.Vocab at 0x7f31950d7780>,
#  'fauxnews': <gensim.models.keyedvectors.Vocab at 0x7f3195137e10>,
#  'gathering': <gensim.models.keyedvectors.Vocab at 0x7f319523d240>,
#  'duffelblog': <gensim.models.keyedvectors.Vocab at 0x7f3195112470>,
#  'craved': <gensim.models.keyedvectors.Vocab at 0x7f3195199518>,
#  'essence': <gensim.models.keyedvectors.Vocab at 0x7f319523d438>,
#  'called': <gensim.models.keyedvectors.Vocab at 0x7f319523d470>,
#  'martyr': <gensim.models.keyedvectors.Vocab at 0x7f319523d518>,
#  'satirists': <gensim.models.keyedvectors.Vocab at 0x7f319523d588>,
#  'bickering': <gensim.models.keyedvectors.Vocab at 0x7f319512f630>,
#  'bbowers1906': <gensim.models.keyedvectors.Vocab at 0x7f319523d5f8>,
#  'med': <gensim.models.keyedvectors.Vocab at 0x7f319523d630>,
#  'helping': <gensim.models.keyedvectors.Vocab at 0x7f319523d6d8>,
#  'gunsen': <gensim.models.keyedvectors.Vocab at 0x7f3195137080>,
#  'mothers': <gensim.models.keyedvectors.Vocab at 0x7f3195098d68>,
#  'paulprovenza': <gensim.models.keyedvectors.Vocab at 0x7f319523da90>,
#  'ambertozer': <gensim.models.keyedvectors.Vocab at 0x7f319523db70>,
#  'great': <gensim.models.keyedvectors.Vocab at 0x7f319523dc18>,
#  'awkward': <gensim.models.keyedvectors.Vocab at 0x7f31951ec7b8>,
#  'fwghqvz9dg': <gensim.models.keyedvectors.Vocab at 0x7f319523dd68>,
#  'tsunami': <gensim.models.keyedvectors.Vocab at 0x7f319523ddd8>,
#  'tuning': <gensim.models.keyedvectors.Vocab at 0x7f31950dc7b8>,
#  'oobw167xiq': <gensim.models.keyedvectors.Vocab at 0x7f3195104a90>,
#  'dressed': <gensim.models.keyedvectors.Vocab at 0x7f319523df98>,
#  'attitude': <gensim.models.keyedvectors.Vocab at 0x7f319523d160>,
#  'movies': <gensim.models.keyedvectors.Vocab at 0x7f319523d2e8>,
#  'phl': <gensim.models.keyedvectors.Vocab at 0x7f3195184198>,
#  'vaginal': <gensim.models.keyedvectors.Vocab at 0x7f319523d780>,
#  'talent': <gensim.models.keyedvectors.Vocab at 0x7f319523d940>,
#  'lrihendry': <gensim.models.keyedvectors.Vocab at 0x7f319523dd30>,
#  'moms': <gensim.models.keyedvectors.Vocab at 0x7f319523d198>,
#  'fe54h9ckay': <gensim.models.keyedvectors.Vocab at 0x7f319523d860>,
#  't1ldoql94l': <gensim.models.keyedvectors.Vocab at 0x7f319523de80>,
#  'warmongering': <gensim.models.keyedvectors.Vocab at 0x7f319523d710>,
#  'htwqozlegb': <gensim.models.keyedvectors.Vocab at 0x7f319523dbe0>,
#  'prepping': <gensim.models.keyedvectors.Vocab at 0x7f3195251048>,
#  'sexuality': <gensim.models.keyedvectors.Vocab at 0x7f3195251080>,
#  '229b': <gensim.models.keyedvectors.Vocab at 0x7f31951376d8>,
#  'despite': <gensim.models.keyedvectors.Vocab at 0x7f31951474a8>,
#  'flashrepoink': <gensim.models.keyedvectors.Vocab at 0x7f31952511d0>,
#  'shitshow': <gensim.models.keyedvectors.Vocab at 0x7f31951a5358>,
#  'safe': <gensim.models.keyedvectors.Vocab at 0x7f3195251278>,
#  'woodruffbets': <gensim.models.keyedvectors.Vocab at 0x7f31952512b0>,
#  'bvwrosgwal': <gensim.models.keyedvectors.Vocab at 0x7f3195251358>,
#  'undoubtedly': <gensim.models.keyedvectors.Vocab at 0x7f31952513c8>,
#  'abo': <gensim.models.keyedvectors.Vocab at 0x7f3195251438>,
#  'watterson': <gensim.models.keyedvectors.Vocab at 0x7f319519f518>,
#  'doughnuts': <gensim.models.keyedvectors.Vocab at 0x7f31952514e0>,
#  'laurelandhardy': <gensim.models.keyedvectors.Vocab at 0x7f3195251588>,
#  'robecosta': <gensim.models.keyedvectors.Vocab at 0x7f31952515c0>,
#  'later': <gensim.models.keyedvectors.Vocab at 0x7f31952515f8>,
#  'prosperity': <gensim.models.keyedvectors.Vocab at 0x7f31951eca90>,
#  'ecz8woviki': <gensim.models.keyedvectors.Vocab at 0x7f31952516d8>,
#  'oreeee5hfq': <gensim.models.keyedvectors.Vocab at 0x7f3195251780>,
#  'studies': <gensim.models.keyedvectors.Vocab at 0x7f31952517b8>,
#  'taotaotasi': <gensim.models.keyedvectors.Vocab at 0x7f3195251860>,
#  'christie': <gensim.models.keyedvectors.Vocab at 0x7f31952518d0>,
#  'cyber': <gensim.models.keyedvectors.Vocab at 0x7f3195251978>,
#  '5sjrek8ofk': <gensim.models.keyedvectors.Vocab at 0x7f3195251a58>,
#  'tired': <gensim.models.keyedvectors.Vocab at 0x7f3195251a90>,
#  'forum': <gensim.models.keyedvectors.Vocab at 0x7f31951ecb70>,
#  'natashavianna': <gensim.models.keyedvectors.Vocab at 0x7f3195251d68>,
#  'sitdownrand': <gensim.models.keyedvectors.Vocab at 0x7f31951a6470>,
#  'educated': <gensim.models.keyedvectors.Vocab at 0x7f3195251dd8>,
#  'foxdebatedisaster': <gensim.models.keyedvectors.Vocab at 0x7f3195167a58>,
#  'c3f1n5c1pt': <gensim.models.keyedvectors.Vocab at 0x7f31951a69b0>,
#  'mslabuski': <gensim.models.keyedvectors.Vocab at 0x7f3195251f28>,
#  'dianneg': <gensim.models.keyedvectors.Vocab at 0x7f3195251f98>,
#  'bullshittery': <gensim.models.keyedvectors.Vocab at 0x7f3195251fd0>,
#  '2dw9wcytwi': <gensim.models.keyedvectors.Vocab at 0x7f319519b2e8>,
#  'michaelsnook': <gensim.models.keyedvectors.Vocab at 0x7f3195251208>,
#  'eza7pbyakh': <gensim.models.keyedvectors.Vocab at 0x7f31952512e8>,
#  'drewzc': <gensim.models.keyedvectors.Vocab at 0x7f3195251390>,
#  'efp81zsufp': <gensim.models.keyedvectors.Vocab at 0x7f3195251630>,
#  'offense': <gensim.models.keyedvectors.Vocab at 0x7f31952516a0>,
#  'welcomed': <gensim.models.keyedvectors.Vocab at 0x7f3195251710>,
#  'insider': <gensim.models.keyedvectors.Vocab at 0x7f3195251908>,
#  'coldpizzaparty': <gensim.models.keyedvectors.Vocab at 0x7f3195251a20>,
#  'wham': <gensim.models.keyedvectors.Vocab at 0x7f31952032b0>,
#  'kirahoffy': <gensim.models.keyedvectors.Vocab at 0x7f31951ecd30>,
#  'hvdnlwytc3': <gensim.models.keyedvectors.Vocab at 0x7f3195251c50>,
#  'foxfire': <gensim.models.keyedvectors.Vocab at 0x7f3195251d30>,
#  'able': <gensim.models.keyedvectors.Vocab at 0x7f3195251e10>,
#  'grneyedmandy': <gensim.models.keyedvectors.Vocab at 0x7f3195137f28>,
#  'fiercefemtivist': <gensim.models.keyedvectors.Vocab at 0x7f3195251e80>,
#  'ebwx3o9oeu': <gensim.models.keyedvectors.Vocab at 0x7f3195251f60>,
#  'leftist': <gensim.models.keyedvectors.Vocab at 0x7f31952510b8>,
#  'eeavzmrvb2': <gensim.models.keyedvectors.Vocab at 0x7f31952514a8>,
#  'destroy': <gensim.models.keyedvectors.Vocab at 0x7f3195251518>,
#  'brightly': <gensim.models.keyedvectors.Vocab at 0x7f31952519e8>,
#  'erupted': <gensim.models.keyedvectors.Vocab at 0x7f31951034e0>,
#  'critic': <gensim.models.keyedvectors.Vocab at 0x7f319519c8d0>,
#  'forks': <gensim.models.keyedvectors.Vocab at 0x7f3195251320>,
#  'podhoretz': <gensim.models.keyedvectors.Vocab at 0x7f31950f8588>,
#  'sober': <gensim.models.keyedvectors.Vocab at 0x7f3195251940>,
#  'futures': <gensim.models.keyedvectors.Vocab at 0x7f3195251b38>,
#  'cry': <gensim.models.keyedvectors.Vocab at 0x7f3195251ba8>,
#  'ijreview': <gensim.models.keyedvectors.Vocab at 0x7f3195251828>,
#  'rvpxm2ieyi': <gensim.models.keyedvectors.Vocab at 0x7f3195251898>,
#  'sexual': <gensim.models.keyedvectors.Vocab at 0x7f31952480b8>,
#  'trashy': <gensim.models.keyedvectors.Vocab at 0x7f31952480f0>,
#  'z0mee2wix0': <gensim.models.keyedvectors.Vocab at 0x7f3195248128>,
#  'fast': <gensim.models.keyedvectors.Vocab at 0x7f3195248198>,
#  'unaccountable': <gensim.models.keyedvectors.Vocab at 0x7f31952481d0>,
#  'moreau': <gensim.models.keyedvectors.Vocab at 0x7f31950de9b0>,
#  'snaps': <gensim.models.keyedvectors.Vocab at 0x7f3195249978>,
#  'bbhmm': <gensim.models.keyedvectors.Vocab at 0x7f31952482b0>,
#  'sweetie': <gensim.models.keyedvectors.Vocab at 0x7f31951782b0>,
#  'organizations': <gensim.models.keyedvectors.Vocab at 0x7f31952483c8>,
#  'ttp2x2grrc': <gensim.models.keyedvectors.Vocab at 0x7f3195248400>,
#  'hosting': <gensim.models.keyedvectors.Vocab at 0x7f3195248470>,
#  'kiddie': <gensim.models.keyedvectors.Vocab at 0x7f31952484e0>,
#  'kkawecki': <gensim.models.keyedvectors.Vocab at 0x7f3195248550>,
#  'stylemom': <gensim.models.keyedvectors.Vocab at 0x7f31952485f8>,
#  'themayaka': <gensim.models.keyedvectors.Vocab at 0x7f31951a9eb8>,
#  'walmawall': <gensim.models.keyedvectors.Vocab at 0x7f3195248780>,
#  'foanzk9qmv': <gensim.models.keyedvectors.Vocab at 0x7f3195248828>,
#  'drag': <gensim.models.keyedvectors.Vocab at 0x7f3195248860>,
#  'x5rmyn4rc6': <gensim.models.keyedvectors.Vocab at 0x7f31952488d0>,
#  'anjdelgado': <gensim.models.keyedvectors.Vocab at 0x7f31951783c8>,
#  'extraordinary': <gensim.models.keyedvectors.Vocab at 0x7f3195137ef0>,
#  'description': <gensim.models.keyedvectors.Vocab at 0x7f3195248ac8>,
#  'delicacy': <gensim.models.keyedvectors.Vocab at 0x7f3195248b70>,
#  'sprayed': <gensim.models.keyedvectors.Vocab at 0x7f3195157198>,
#  'promotes': <gensim.models.keyedvectors.Vocab at 0x7f3195248be0>,
#  'heathnola': <gensim.models.keyedvectors.Vocab at 0x7f3195248c50>,
#  'brainscape': <gensim.models.keyedvectors.Vocab at 0x7f3195248c88>,
#  'morepeople': <gensim.models.keyedvectors.Vocab at 0x7f3195248cf8>,
#  '0jx8yeb00f': <gensim.models.keyedvectors.Vocab at 0x7f3195248d68>,
#  'tl4vurohdt': <gensim.models.keyedvectors.Vocab at 0x7f3195248dd8>,
#  'clowncircus': <gensim.models.keyedvectors.Vocab at 0x7f3195248eb8>,
#  'worrying': <gensim.models.keyedvectors.Vocab at 0x7f3195248ef0>,
#  'lwpfgdcnas': <gensim.models.keyedvectors.Vocab at 0x7f31951ea860>,
#  'gentlemen': <gensim.models.keyedvectors.Vocab at 0x7f3195248208>,
#  'basically': <gensim.models.keyedvectors.Vocab at 0x7f3195248390>,
#  'makes': <gensim.models.keyedvectors.Vocab at 0x7f3195248438>,
#  'enthralled': <gensim.models.keyedvectors.Vocab at 0x7f3195248518>,
#  'husband': <gensim.models.keyedvectors.Vocab at 0x7f319510eb38>,
#  'wheaton': <gensim.models.keyedvectors.Vocab at 0x7f3195248588>,
#  'wildcards': <gensim.models.keyedvectors.Vocab at 0x7f31952485c0>,
#  'drugs': <gensim.models.keyedvectors.Vocab at 0x7f31952486d8>,
#  'bid': <gensim.models.keyedvectors.Vocab at 0x7f31952487f0>,
#  'stzw': <gensim.models.keyedvectors.Vocab at 0x7f319513bb38>,
#  'drawing': <gensim.models.keyedvectors.Vocab at 0x7f3195248908>,
#  'head': <gensim.models.keyedvectors.Vocab at 0x7f3195248978>,
#  'vn45hf6yem': <gensim.models.keyedvectors.Vocab at 0x7f3195248a20>,
#  'tarantino': <gensim.models.keyedvectors.Vocab at 0x7f3195248ba8>,
#  'tiwloaaoj8': <gensim.models.keyedvectors.Vocab at 0x7f31951785f8>,
#  'jamalraad': <gensim.models.keyedvectors.Vocab at 0x7f3195248d30>,
#  'bcr3nvr9bk': <gensim.models.keyedvectors.Vocab at 0x7f3195248f60>,
#  'disheartening': <gensim.models.keyedvectors.Vocab at 0x7f3195248f98>,
#  'vp': <gensim.models.keyedvectors.Vocab at 0x7f3195248fd0>,
#  'strategic': <gensim.models.keyedvectors.Vocab at 0x7f31950a4208>,
#  'storms': <gensim.models.keyedvectors.Vocab at 0x7f3195178668>,
#  'defending': <gensim.models.keyedvectors.Vocab at 0x7f31952484a8>,
#  'rages': <gensim.models.keyedvectors.Vocab at 0x7f31950e31d0>,
#  '1v4tvjla6c': <gensim.models.keyedvectors.Vocab at 0x7f3195248630>,
#  'unpredictability': <gensim.models.keyedvectors.Vocab at 0x7f31951a40b8>,
#  'ttcdktnmut': <gensim.models.keyedvectors.Vocab at 0x7f3195248748>,
#  'barf': <gensim.models.keyedvectors.Vocab at 0x7f3195248898>,
#  'carsonwins': <gensim.models.keyedvectors.Vocab at 0x7f3195248c18>,
#  'ug21fi5fc': <gensim.models.keyedvectors.Vocab at 0x7f3195248e10>,
#  'worth': <gensim.models.keyedvectors.Vocab at 0x7f3195248080>,
#  'gtl3eozkl3': <gensim.models.keyedvectors.Vocab at 0x7f3195248b00>,
#  'youre': <gensim.models.keyedvectors.Vocab at 0x7f31952482e8>,
#  'reviewjournal': <gensim.models.keyedvectors.Vocab at 0x7f3195248940>,
#  'seuss': <gensim.models.keyedvectors.Vocab at 0x7f31950fac50>,
#  'city': <gensim.models.keyedvectors.Vocab at 0x7f31952489b0>,
#  'asking': <gensim.models.keyedvectors.Vocab at 0x7f3195206240>,
#  'geophysicist': <gensim.models.keyedvectors.Vocab at 0x7f31951a7cf8>,
#  'insurance': <gensim.models.keyedvectors.Vocab at 0x7f319524c048>,
#  'extensions': <gensim.models.keyedvectors.Vocab at 0x7f319524c080>,
#  'domestic': <gensim.models.keyedvectors.Vocab at 0x7f319524c198>,
#  'bullriders1': <gensim.models.keyedvectors.Vocab at 0x7f319524c2e8>,
#  'buck': <gensim.models.keyedvectors.Vocab at 0x7f319524c390>,
#  'victimized': <gensim.models.keyedvectors.Vocab at 0x7f319524c3c8>,
#  'alcohol': <gensim.models.keyedvectors.Vocab at 0x7f319524c470>,
#  'aholes': <gensim.models.keyedvectors.Vocab at 0x7f319524c4a8>,
#  'xul0y2qxp6': <gensim.models.keyedvectors.Vocab at 0x7f319524c4e0>,
#  'done': <gensim.models.keyedvectors.Vocab at 0x7f319524c588>,
#  '2tv5m6onvo': <gensim.models.keyedvectors.Vocab at 0x7f319524c5f8>,
#  'ringling': <gensim.models.keyedvectors.Vocab at 0x7f31951de278>,
#  'rhmvgumuir': <gensim.models.keyedvectors.Vocab at 0x7f319524c668>,
#  'pmjhbxqfqk': <gensim.models.keyedvectors.Vocab at 0x7f319524c6a0>,
#  'voiceovers': <gensim.models.keyedvectors.Vocab at 0x7f319524c748>,
#  'ecstatic': <gensim.models.keyedvectors.Vocab at 0x7f31951b1128>,
#  'iacaucus': <gensim.models.keyedvectors.Vocab at 0x7f31951ec8d0>,
#  'tpfa': <gensim.models.keyedvectors.Vocab at 0x7f319524c8d0>,
#  'beanbag': <gensim.models.keyedvectors.Vocab at 0x7f319524c908>,
#  'chyt': <gensim.models.keyedvectors.Vocab at 0x7f319524c940>,
#  'vttzii0rq6': <gensim.models.keyedvectors.Vocab at 0x7f31950a6cc0>,
#  'backyard': <gensim.models.keyedvectors.Vocab at 0x7f319524c9e8>,
#  'transparency': <gensim.models.keyedvectors.Vocab at 0x7f319524ca20>,
#  'resident': <gensim.models.keyedvectors.Vocab at 0x7f319524ca58>,
#  'amen': <gensim.models.keyedvectors.Vocab at 0x7f319524ca90>,
#  'considered': <gensim.models.keyedvectors.Vocab at 0x7f319512b1d0>,
#  'polished': <gensim.models.keyedvectors.Vocab at 0x7f319524cb00>,
#  'blundered': <gensim.models.keyedvectors.Vocab at 0x7f319524cb70>,
#  'pseudo': <gensim.models.keyedvectors.Vocab at 0x7f319524cbe0>,
#  '9': <gensim.models.keyedvectors.Vocab at 0x7f319524cc88>,
#  'lzdebates': <gensim.models.keyedvectors.Vocab at 0x7f3195200898>,
#  'sartre': <gensim.models.keyedvectors.Vocab at 0x7f319524cd30>,
#  '7l6xapqamu': <gensim.models.keyedvectors.Vocab at 0x7f319524c6d8>,
#  'content': <gensim.models.keyedvectors.Vocab at 0x7f319524c710>,
#  'faced': <gensim.models.keyedvectors.Vocab at 0x7f319524c780>,
#  'petulant': <gensim.models.keyedvectors.Vocab at 0x7f319524c7f0>,
#  'xocs': <gensim.models.keyedvectors.Vocab at 0x7f319524cb38>,
#  'parental': <gensim.models.keyedvectors.Vocab at 0x7f319524ccc0>,
#  'nauseous': <gensim.models.keyedvectors.Vocab at 0x7f319524c0f0>,
#  'icon': <gensim.models.keyedvectors.Vocab at 0x7f319524c1d0>,
#  'morecowbells': <gensim.models.keyedvectors.Vocab at 0x7f319524c208>,
#  'lodmczbpe2': <gensim.models.keyedvectors.Vocab at 0x7f31951eca58>,
#  'purpochristian': <gensim.models.keyedvectors.Vocab at 0x7f319524c278>,
#  'megynkellydebatequestions': <gensim.models.keyedvectors.Vocab at 0x7f319524c2b0>,
#  'bimbos': <gensim.models.keyedvectors.Vocab at 0x7f319524c438>,
#  'yrjqlnoj2j': <gensim.models.keyedvectors.Vocab at 0x7f319524c550>,
#  '412v70': <gensim.models.keyedvectors.Vocab at 0x7f319524ce10>,
#  'shrill': <gensim.models.keyedvectors.Vocab at 0x7f3195203358>,
#  'ygmgbavqut': <gensim.models.keyedvectors.Vocab at 0x7f319524ce80>,
#  'fredbarnes': <gensim.models.keyedvectors.Vocab at 0x7f319524cef0>,
#  'unamerican': <gensim.models.keyedvectors.Vocab at 0x7f319524cf60>,
#  'fairtax': <gensim.models.keyedvectors.Vocab at 0x7f319524c978>,
#  'dangerfield': <gensim.models.keyedvectors.Vocab at 0x7f319524c9b0>,
#  'drain': <gensim.models.keyedvectors.Vocab at 0x7f319524cba8>,
#  'justified': <gensim.models.keyedvectors.Vocab at 0x7f319524c400>,
#  'radicalism': <gensim.models.keyedvectors.Vocab at 0x7f31951ecda0>,
#  'psychopath': <gensim.models.keyedvectors.Vocab at 0x7f319524cf98>,
#  'afriendindeed': <gensim.models.keyedvectors.Vocab at 0x7f31951ad438>,
#  'cic': <gensim.models.keyedvectors.Vocab at 0x7f319524cc50>,
#  'pahuckabee': <gensim.models.keyedvectors.Vocab at 0x7f319524c160>,
#  'cnnmoney': <gensim.models.keyedvectors.Vocab at 0x7f319524c358>,
#  'nt': <gensim.models.keyedvectors.Vocab at 0x7f319524c518>,
#  'o06uczxff8': <gensim.models.keyedvectors.Vocab at 0x7f319524c5c0>,
#  ...}

# %%
#Word embedding of the word "With"
model.wv["level"]
# Out:
# array([-0.01682623,  0.01904772,  0.09865578, -0.00305726,  0.01429111,
#         0.02463139,  0.02655845, -0.03346057, -0.02406447,  0.00259166,
#         0.01031249,  0.0039704 ,  0.02156182, -0.05577968, -0.02400477,
#         0.0123924 , -0.00462562,  0.03068833,  0.03928994,  0.05355615,
#         0.01525774,  0.06060887, -0.06233357,  0.00382755,  0.05642894,
#        -0.02394897, -0.07360403, -0.00662334,  0.00678974, -0.05055292,
#        -0.02043871,  0.00939632,  0.03730861,  0.02511507,  0.06233795,
#         0.06402127,  0.01263601, -0.02919376,  0.06216326,  0.04464545,
#         0.02089566,  0.02613247, -0.02415999,  0.03567228, -0.05724327,
#         0.00347368,  0.00499592, -0.03593763,  0.06694987, -0.04172412,
#         0.01733824,  0.00712488, -0.01386341, -0.03779038,  0.04002213,
#         0.0044485 ,  0.04796574,  0.02166961, -0.03609928,  0.03276599,
#        -0.02174158, -0.03666539,  0.01866267,  0.02628101,  0.02463651,
#         0.05440414,  0.0123358 ,  0.03987351,  0.00765493, -0.01417688,
#         0.04655512,  0.01502973,  0.00734067, -0.01003094, -0.01511931,
#        -0.03269944, -0.08121344, -0.00510571,  0.05493691, -0.00231009,
#         0.02791245, -0.02898232, -0.01693823, -0.02328412, -0.01857479,
#         0.0690812 , -0.03440637, -0.02574277,  0.0877782 , -0.03604346,
#        -0.00153384,  0.02826887,  0.02529532,  0.00758374, -0.02093388,
#         0.00582585, -0.03111637,  0.05195134, -0.0428643 ,  0.03447787],
#       dtype=float32)

# %%
#Simialr words of music in the corpus
model.wv.most_similar("level")
# Out:
# [('brain', 0.9965094327926636),
#  ('scott', 0.99632728099823),
#  ('brothers', 0.9959276914596558),
#  ('rather', 0.9958280324935913),
#  ('idiot', 0.9958206415176392),
#  ('willing', 0.9957659244537354),
#  ('b', 0.9957613945007324),
#  ('twist', 0.9957426190376282),
#  ('hates', 0.9957401156425476),
#  ('wanted', 0.9956766366958618)]

# %%
model.wv.most_similar(positive=['king','woman'], negative= ['man'], topn=5)
# Out:
# [('doubts', 0.9784618616104126),
#  ('one', 0.9778905510902405),
#  ('girls', 0.9778863191604614),
#  ('pants', 0.9751665592193604),
#  ('hits', 0.9745514988899231)]

# %%
model.wv.doesnt_match(['woman','man','queen','movie'])
# Out:
# /usr/local/lib/python3.5/dist-packages/gensim/models/keyedvectors.py:735: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   vectors = vstack(self.word_vec(word, use_norm=True) for word in used_words).astype(REAL)
# 'man'

# %%
#Creating the input data
X = np.zeros((len(corpus),100)) #Initializing the X matrix with zeros
for i in range(len(corpus)):
    emb = [model.wv[w] for w in corpus[i]] #Create a list of word embeddings of the words in each sentence
    X[i] = np.mean(emb, axis=0) #Take the mean of the word embeddings of the words in a sentence because length of the sentences varies and the dimension of the features will increase with the increase in the number of words in the sentence

# %%
le = preprocessing.LabelEncoder()
Y = le.fit_transform(sentiment)

# %%
print(X.shape,Y.shape)
# Out:
# (13871, 100) (13871,)

# %%
#Splitting the data into train data and test data
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size = 0.20, random_state = 42)
print(X_train.shape,Y_train.shape)
print(X_test.shape,Y_test.shape)
# Out:
# (11096, 100) (9709,)
# (2775, 100) (4162,)

# %%
#Printing the size of the train data, train label, test data and test label
print("Shape train data = ",np.shape(X_train))
print("Shape of train label = ",np.shape(y_train))
print("Shape of test data = ",np.shape(X_test))
print("Shape of test label = ",np.shape(y_test))
# Out:
# Shape train data =  (11096, 100)
# Shape of train label =  (11096,)
# Shape of test data =  (2775, 100)
# Shape of test label =  (2775,)

# %%
#Classification using SVM
clf = GaussianNB() #Initializing the classifier
clf.fit(X_train, y_train) #Train the classifier using X_train and y_train
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
#Predict the class label for the test data using the trained model
y_pred = clf.predict(X_test)

# %%
#Generating the confusion matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[ 414 1094  214]
#  [  55  475   82]
#  [  38  301  102]]

# %%
#Computation of the accuracy score
accuracy = accuracy_score(y_test, y_pred)
print('Accuracy = ','%.2f'%(accuracy*100))
# Out:
# Accuracy =  35.71

# %%
#K-fold cross-validation
score = cross_val_score(clf, X, y, cv = 5)

# %%
#Performance of the model evaluated using accuracy score. k-fold cross-validation gives k different accuracy score. 
#Hence the accuracy of prediction by the model is taken as the mean of the accuracy score +/- standard deviation of the score
print('Accuracy = ','%.2f'%(np.mean(score)*100),"+/-",'%.4f'%(np.std(score)))
# Out:
# Accuracy =  31.07 +/- 0.0651

# %% [markdown]
# ### Feature extraction using Doc2vec

# %%
#Creating sentence embedding with Doc2vec
documents = [TaggedDocument(doc, [i]) for i, doc in enumerate(corpus)]
model = Doc2Vec(documents, size = 100, window=5, min_count=1)

# %%
#Create the input matrix using doc2vec embeddings
X = []

for i in range(len(corpus)):
    X.append(model.infer_vector(corpus[i]))

# %%
#Splitting the data into train data and test data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
#Printing the size of the train data, train label, test data and test label
print("Shape train data = ",np.shape(X_train))
print("Shape of train label = ",np.shape(y_train))
print("Shape of test data = ",np.shape(X_test))
print("Shape of test label = ",np.shape(y_test))
# Out:
# Shape train data =  (11096, 100)
# Shape of train label =  (11096,)
# Shape of test data =  (2775, 100)
# Shape of test label =  (2775,)

# %%
#Classification using SVM
clf = GaussianNB() #Initializing the classifier
clf.fit(X_train, y_train) #Train the classifier using X_train and y_train
# Out:
# GaussianNB(priors=None, var_smoothing=1e-09)

# %%
#Predict the class label for the test data using the trained model
y_pred = clf.predict(X_test)

# %%
#Generating the confusion matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[689 473 542]
#  [172 255 206]
#  [119 113 206]]

# %%
#Computation of the accuracy score
accuracy = accuracy_score(y_test, y_pred)
print('Accuracy = ','%.2f'%(accuracy*100))
# Out:
# Accuracy =  41.44

# %%
#K-fold cross-validation
score = cross_val_score(clf, X, sentiment, cv = 5)

# %%
#Performance of the model evaluated using accuracy score. k-fold cross-validation gives k different accuracy score. 
#Hence the accuracy of prediction by the model is taken as the mean of the accuracy score +/- standard deviation of the score
print('Accuracy = ','%.2f'%(np.mean(score)*100),"+/-",'%.4f'%(np.std(score)))
# Out:
# Accuracy =  36.34 +/- 0.0328

# %% [markdown]
# ### Feature extraction using pretrained models

# %%
model = KeyedVectors.load_word2vec_format('GoogleNews-vectors-negative300.bin', binary=True)

# %%
model.wv.most_similar(positive=['king','woman'], negative= ['man'], topn=1)

# %% [markdown]
# ## Text classification using deep learning algorithms

# %%
data = pd.read_csv('sa_data.csv')

# %%
data.head()
# Out:
#                                                 text sentiment
# 0  RT @NancyLeeGrahn: How did everyone feel about...   Neutral
# 1  RT @ScottWalker: Didn't catch the full #GOPdeb...  Positive
# 2  RT @TJMShow: No mention of Tamir Rice and the ...   Neutral
# 3  RT @RobGeorge: That Carly Fiorina is trending ...  Positive
# 4  RT @DanScavino: #GOPDebate w/ @realDonaldTrump...  Positive

# %%
#Preprocessing - removing unwanted characters, tokenization, stop-word removal
def clean_data(tweet):
    x = re.sub("[^a-zA-Z0-9]", " ",tweet) 
    x = x.lower().split()                             
    stops = set(stopwords.words("english"))                  
    words = [w for w in x if not w in stops] 
    return( " ".join(words))

# %%
data['text'] = data['text'].apply(lambda x: clean_data(x))

# %%
for i in range(len(data)):
    data['text'][i] = data['text'][i].replace('rt ','')

# %%
#Converting the dataframe into list
reviews = data['text'].tolist()
sentiment = data['sentiment'].tolist()

corpus = []
for i in range(len(reviews)):
    corpus.append(word_tokenize(reviews[i]))

# %%
#Tokenization
max_features = 1200 #number of words to keep. 1200 is the number of unique words in the corpus.
tokenizer = Tokenizer(nb_words=max_fatures, split=' ')
tokenizer.fit_on_texts(data['text'].values)
# Out:
# /usr/local/lib/python3.5/dist-packages/keras/preprocessing/text.py:172: UserWarning: The `nb_words` argument in `Tokenizer` has been renamed `num_words`.
#   warnings.warn('The `nb_words` argument in `Tokenizer` '

# %%
#Unique words and and their count
tokenizer.word_counts
# Out:
# OrderedDict([('nancyleegrahn', 6),
#              ('everyone', 109),
#              ('feel', 62),
#              ('climate', 72),
#              ('change', 84),
#              ('question', 351),
#              ('last', 879),
#              ('night', 903),
#              ('exactly', 22),
#              ('gopdebate', 9048),
#              ('scottwalker', 94),
#              ('catch', 9),
#              ('full', 45),
#              ('scott', 101),
#              ('best', 185),
#              ('lines', 14),
#              ('90', 12),
#              ('seconds', 16),
#              ('walker16', 29),
#              ('http', 3018),
#              ('co', 3633),
#              ('zsff', 1),
#              ('tjmshow', 1),
#              ('mention', 57),
#              ('tamir', 2),
#              ('rice', 2),
#              ('held', 10),
#              ('cleveland', 37),
#              ('wow', 55),
#              ('robgeorge', 1),
#              ('carly', 120),
#              ('fiorina', 144),
#              ('trending', 2),
#              ('hours', 34),
#              ('debate', 1063),
#              ('men', 194),
#              ('completed', 1),
#              ('says', 161),
#              ('danscavino', 18),
#              ('w', 161),
#              ('realdonaldtrump', 1079),
#              ('delivered', 8),
#              ('highest', 12),
#              ('ratings', 142),
#              ('history', 40),
#              ('presidential', 184),
#              ('debates', 174),
#              ('trump2016', 77),
#              ('gregabbott', 3),
#              ('tx', 7),
#              ('tedcruz', 282),
#              ('first', 164),
#              ('day', 96),
#              ('rescind', 3),
#              ('every', 120),
#              ('illegal', 73),
#              ('executive', 15),
#              ('action', 9),
#              ('taken', 18),
#              ('barack', 9),
#              ('obama', 185),
#              ('foxnews', 605),
#              ('warriorwoman91', 4),
#              ('liked', 17),
#              ('happy', 15),
#              ('heard', 44),
#              ('going', 194),
#              ('moderator', 45),
#              ('anymore', 23),
#              ('megynkelly', 667),
#              ('https', 907),
#              ('msnbc', 35),
#              ('live', 92),
#              ('thomasaroberts', 1),
#              ('around', 42),
#              ('2', 201),
#              ('pm', 4),
#              ('et', 12),
#              ('deer', 1),
#              ('headlights', 1),
#              ('lizzwinstead', 6),
#              ('ben', 194),
#              ('carson', 357),
#              ('may', 51),
#              ('brain', 47),
#              ('surgeon', 8),
#              ('performed', 10),
#              ('lobotomy', 2),
#              ('nancyosborne180', 5),
#              ('proved', 27),
#              ('batsask', 26),
#              ('badassteachersa', 6),
#              ('tbats', 5),
#              ('g2ggjy1bjd', 1),
#              ('jgreendc', 1),
#              ('fairness', 1),
#              ('billclinton', 4),
#              ('owns', 4),
#              ('phrase', 3),
#              ('waynedupreeshow', 10),
#              ('woke', 9),
#              ('tweet', 49),
#              ('line', 45),
#              ('via', 195),
#              ('govmikehuckabee', 97),
#              ('6ov5hxhicv', 1),
#              ('reading', 21),
#              ('family', 27),
#              ('comments', 65),
#              ('great', 208),
#              ('giagjpygxz', 1),
#              ('arcticfox2016', 2),
#              ('allenwestrepub', 19),
#              ('dear', 89),
#              ('jebbush', 115),
#              ('notamistake', 9),
#              ('ttfg7kycd9', 1),
#              ('pattonoswalt', 43),
#              ('loved', 45),
#              ('walker', 208),
#              ('mark', 9),
#              ('harmon', 1),
#              ('romantic', 1),
#              ('rival', 1),
#              ('summer', 6),
#              ('school', 13),
#              ('look', 177),
#              ('hey', 91),
#              ('chrischristie', 82),
#              ('exploiting', 1),
#              ('tragedy', 2),
#              ('9', 47),
#              ('11', 33),
#              ('political', 116),
#              ('gain', 6),
#              ('rudygiulianigop', 1),
#              ('thing', 127),
#              ('carolcnn', 5),
#              ('donaldtrump', 135),
#              ('fire', 26),
#              ('women', 348),
#              ('peterbeinasl', 1),
#              ('schaeffer', 1),
#              ('iwf', 1),
#              ('myrkiger', 1),
#              ('weigh', 5),
#              ('johncardillo', 4),
#              ('guess', 40),
#              ('speaking', 162),
#              ('time', 345),
#              ('moderators', 117),
#              ('31', 10),
#              ('7', 33),
#              ('2wsut0c0lx', 1),
#              ('reason', 25),
#              ('comment', 24),
#              ('funny', 44),
#              ('case', 16),
#              ('ignorant', 19),
#              ('gop', 740),
#              ('tcot', 232),
#              ('government', 42),
#              ('working', 29),
#              ('people', 627),
#              ('pamelageller', 12),
#              ('huckabee', 311),
#              ('paying', 13),
#              ('transgender', 10),
#              ('surgery', 4),
#              ('soldiers', 10),
#              ('sailors', 1),
#              ('airmen', 1),
#              ('make', 172),
#              ('country', 144),
#              ('safer', 1),
#              ('ha', 27),
#              ('chucknellis', 13),
#              ('cruz', 450),
#              ('class', 51),
#              ('amp', 1059),
#              ('truth', 127),
#              ('gets', 173),
#              ('vote', 159),
#              ('mchamric', 1),
#              ('teatraitors', 5),
#              ('still', 134),
#              ('clown', 29),
#              ('show', 143),
#              ('glad', 26),
#              ('head', 47),
#              ('trump', 1894),
#              ('helping', 7),
#              ('destroy', 31),
#              ('nwgx8g8jwr', 2),
#              ('erinmallorylong', 3),
#              ('hate', 67),
#              ('planned', 55),
#              ('parenthood', 52),
#              ('thekevinryder', 1),
#              ('vine', 18),
#              ('dabulldawg88', 6),
#              ('xkxvdradce', 1),
#              ('mrpooni', 1),
#              ('fox', 1335),
#              ('news', 909),
#              ('trying', 240),
#              ('convince', 6),
#              ('us', 217),
#              ('young', 16),
#              ('black', 97),
#              ('americans', 75),
#              ('worried', 15),
#              ('isis', 56),
#              ('police', 46),
#              ('terrorism', 56),
#              ('rankings', 3),
#              ('worst', 29),
#              ('performance', 61),
#              ('rubio', 400),
#              ('kasich', 202),
#              ('christie', 179),
#              ('bush', 588),
#              ('paul', 218),
#              ('thebaxterbean', 37),
#              ('abortion', 107),
#              ('ban', 7),
#              ('allows', 2),
#              ('rapist', 4),
#              ('father', 29),
#              ('sue', 4),
#              ('emotional', 4),
#              ('distress', 2),
#              ('rhmvgumuir', 2),
#              ('badger', 2),
#              ('feministabulous', 16),
#              ('competition', 5),
#              ('moved', 4),
#              ('far', 60),
#              ('gay', 64),
#              ('rights', 139),
#              ('worse', 22),
#              ('ever', 105),
#              ('g', 202),
#              ('mch7576', 2),
#              ('pry2qpcwfu', 2),
#              ('hillaryclinton', 147),
#              ('watch', 213),
#              ('bet', 19),
#              ('like', 731),
#              ('donating', 2),
#              ('democrat', 64),
#              ('right', 284),
#              ('pglqcqqgop', 1),
#              ('qp1e', 1),
#              ('fbhw', 1),
#              ('need', 406),
#              ('borrow', 4),
#              ('train', 6),
#              ('horn', 1),
#              ('next', 330),
#              ('little', 74),
#              ('bell', 15),
#              ('wimpy', 1),
#              ('hornmeansyouredone', 1),
#              ('lisavikingstad', 1),
#              ('ted', 169),
#              ('bed', 15),
#              ('keep', 78),
#              ('confusingly', 1),
#              ('sad', 27),
#              ('face', 239),
#              ('refuse', 29),
#              ('social', 131),
#              ('media', 99),
#              ('reaction', 22),
#              ('x6kuvskltf', 1),
#              ('socialmedia', 10),
#              ('ogoyfnyikj', 1),
#              ('winesdaypodcast', 1),
#              ('update', 5),
#              ('tech', 7),
#              ('failures', 2),
#              ('fgglf2j5hu', 1),
#              ('zw35dkuozi', 1),
#              ('amymek', 24),
#              ('torched', 1),
#              ('passed', 7),
#              ('gt', 70),
#              ('candycrowley', 8),
#              ('longer', 16),
#              ('famous', 6),
#              ('assassin', 1),
#              ('congratulations', 6),
#              ('u', 143),
#              ('wi', 12),
#              ('stockwizards3', 1),
#              ('ticket', 12),
#              ('would', 493),
#              ('win', 67),
#              ('landslide', 8),
#              ('seanhannity', 21),
#              ('anncoulter', 10),
#              ('republican', 445),
#              ('potus', 74),
#              ('kvxrdashian', 5),
#              ('jeb', 592),
#              ('fault', 8),
#              ('brother', 25),
#              ('clean', 6),
#              ('mess', 29),
#              ('made', 132),
#              ('ali', 5),
#              ('primary', 49),
#              ('voters', 61),
#              ('none', 36),
#              ('wiser', 2),
#              ('policy', 37),
#              ('plans', 12),
#              ('folks', 30),
#              ('putting', 16),
#              ('forth', 5),
#              ('journalism', 2),
#              ('itsashlyperez', 2),
#              ('listening', 27),
#              ('fetty', 1),
#              ('wap', 1),
#              ('packing', 2),
#              ('true', 78),
#              ('american', 236),
#              ('doesthishashtagexpire', 1),
#              ('mgell', 1),
#              ('cross', 4),
#              ('shrug', 1),
#              ('emoji', 3),
#              ('president', 447),
#              ('business', 31),
#              ('lego', 2),
#              ('movie', 24),
#              ('jamellemybelle', 1),
#              ('meanwhile', 11),
#              ('white', 103),
#              ('house', 25),
#              ('nouuut5hkq', 1),
#              ('rowdygentleman', 1),
#              ('planning', 9),
#              ('drinking', 29),
#              ('game', 57),
#              ('rowdy', 6),
#              ('gentleman', 5),
#              ('brownblaze', 3),
#              ('please', 80),
#              ('kkkorgop', 102),
#              ('yaqyac3uv3', 1),
#              ('thinks', 89),
#              ('criticism', 2),
#              ('misogynistic', 10),
#              ('remarks', 11),
#              ('correctness', 32),
#              ('problem', 77),
#              ('nope', 8),
#              ('pervasive', 1),
#              ('sexism', 27),
#              ('lekarmasucre', 1),
#              ('handled', 9),
#              ('blacklivesmatter', 92),
#              ('8zgdy6lpct', 1),
#              ('palmaceiahome1', 7),
#              ('goal', 8),
#              ('take', 210),
#              ('pave', 2),
#              ('way', 119),
#              ('rino', 14),
#              ('philstockworld', 2),
#              ('chat', 6),
#              ('room', 23),
#              ('futures', 3),
#              ('spy', 7),
#              ('nonfarmpayrolls', 3),
#              ('jobs', 42),
#              ('netflix', 3),
#              ('0k06sf81rq', 2),
#              ('say', 239),
#              ('thanks', 166),
#              ('gov', 61),
#              ('tweeted', 20),
#              ('moment', 48),
#              ('saying', 90),
#              ('purpose', 85),
#              ('military', 167),
#              ('kill', 121),
#              ('break', 148),
#              ('things', 171),
#              ('trans', 19),
#              ('servicemembers', 1),
#              ('ariannahuff', 1),
#              ('yki30j7hho', 2),
#              ('chrisstirewalt', 5),
#              ('big', 140),
#              ('moments', 38),
#              ('randpaul', 143),
#              ('vs', 47),
#              ('kellyfil', 1),
#              ('stylemom', 1),
#              ('hell', 70),
#              ('body', 18),
#              ('parts', 10),
#              ('even', 173),
#              ('foh', 1),
#              ('stop', 77),
#              ('1965', 2),
#              ('wtf', 16),
#              ('rushlimbaugh', 19),
#              ('getting', 70),
#              ('beheaded', 3),
#              ('overseas', 4),
#              ('whether', 14),
#              ('calls', 34),
#              ('rosie', 55),
#              ('donnell', 30),
#              ('fat', 44),
#              ('defend', 19),
#              ('fair', 263),
#              ('balanced', 228),
#              ('name', 50),
#              ('calling', 67),
#              ('juvenile', 2),
#              ('theskysgoneout', 1),
#              ('non', 16),
#              ('christians', 10),
#              ('god', 445),
#              ('questions', 376),
#              ('underline', 1),
#              ('anyone', 270),
#              ('really', 371),
#              ('cares', 12),
#              ('religious', 12),
#              ('minorities', 3),
#              ('chri', 2),
#              ('bipartisanism', 15),
#              ('response', 34),
#              ('pathetic', 15),
#              ('ismxbrrm0h', 1),
#              ('factcheckdotorg', 2),
#              ('said', 346),
#              ('cut', 36),
#              ('fl', 7),
#              ('taxes', 24),
#              ('19b', 1),
#              ('includes', 1),
#              ('cuts', 13),
#              ('estate', 1),
#              ('mandated', 1),
#              ('federal', 10),
#              ('law', 25),
#              ('ht', 35),
#              ('mydaughtersarmy', 8),
#              ('want', 373),
#              ('abortions', 21),
#              ('rbl1t4ipx6', 1),
#              ('karrattipaul', 1),
#              ('join', 24),
#              ('sign', 8),
#              ('death', 21),
#              ('warrant', 10),
#              ('signed', 3),
#              ('wakeupamerica', 30),
#              ('cruzcrew', 39),
#              ('htt', 34),
#              ('p0tus', 5),
#              ('closing', 86),
#              ('statements', 54),
#              ('s15nlillso', 1),
#              ('status', 31),
#              ('single', 54),
#              ('broke', 10),
#              ('goodbye', 9),
#              ('bretbaier', 63),
#              ('chris', 426),
#              ('wallace', 370),
#              ('frankluntz', 65),
#              ('14', 14),
#              ('focus', 50),
#              ('groupers', 3),
#              ('favorable', 4),
#              ('view', 25),
#              ('3', 94),
#              ('saw', 46),
#              ('positively', 1),
#              ('holly', 4),
#              ('renee', 3),
#              ('donation', 7),
#              ('carlyfiorina', 205),
#              ('impressed', 27),
#              ('jlfhfvz7st', 1),
#              ('thejimhughes', 3),
#              ('sending', 8),
#              ('foreign', 23),
#              ('aid', 3),
#              ('places', 6),
#              ('burn', 5),
#              ('flag', 7),
#              ('staberkeley', 2),
#              ('frankthorpnbc', 2),
#              ('rand', 172),
#              ('eye', 10),
#              ('roll', 14),
#              ('hf318qsowd', 2),
#              ('johnkasich', 90),
#              ('scrap', 1),
#              ('iran', 73),
#              ('deal', 52),
#              ('get', 462),
#              ('nuke', 2),
#              ('kasich4us', 18),
#              ('9trzxonlzf', 1),
#              ('decide', 13),
#              ('early', 28),
#              ('come', 65),
#              ('back', 136),
#              ('twitter', 131),
#              ('fulltime', 1),
#              ('gonna', 42),
#              ('wait', 69),
#              ('closer', 3),
#              ('election', 47),
#              ('hooked', 1),
#              ('mspackyetti', 1),
#              ('donald', 426),
#              ('campaign', 58),
#              ('reveals', 8),
#              ('1', 143),
#              ('important', 56),
#              ('trolls', 1),
#              ('real', 185),
#              ('scare', 4),
#              ('eve', 3),
#              ('worry', 14),
#              ('never', 215),
#              ('elected', 28),
#              ('remember', 36),
#              ('george', 16),
#              ('twice', 15),
#              ('agenda', 13),
#              ('promote', 2),
#              ('fired', 15),
#              ('hp', 8),
#              ('run', 83),
#              ('race', 69),
#              ('9k1eujdfo7', 1),
#              ('hlllary', 1),
#              ('oh', 141),
#              ('one', 540),
#              ('hear', 237),
#              ('anything', 61),
#              ('affordable', 12),
#              ('child', 14),
#              ('care', 79),
#              ('families', 28),
#              ('naughtybeyotch', 3),
#              ('wqnsupspkc', 2),
#              ('marthamaccallum', 16),
#              ('billhemmer', 19),
#              ('bill', 29),
#              ('martha', 5),
#              ('team', 20),
#              ('2nd', 30),
#              ('ambush', 6),
#              ('megyn', 248),
#              ('kelly', 190),
#              ('attacking', 20),
#              ('war', 85),
#              ('franklin', 5),
#              ('graham', 19),
#              ('1st', 41),
#              ('encouraging', 3),
#              ('see', 266),
#              ('several', 13),
#              ('candidates', 852),
#              ('express', 6),
#              ('faith', 14),
#              ('son', 15),
#              ('jesus', 50),
#              ('christ', 11),
#              ('c', 92),
#              ('snarkydemo', 2),
#              ('politically', 37),
#              ('correct', 44),
#              ('course', 27),
#              ('trumpspeak', 1),
#              ('let', 159),
#              ('huge', 29),
#              ('asshole', 15),
#              ('message', 20),
#              ('wfk5cmvgin', 1),
#              ('davidcicilline', 1),
#              ('episode', 13),
#              ('apprentice', 10),
#              ('seen', 80),
#              ('luntz', 16),
#              ('go', 238),
#              ('almost', 25),
#              ('reach', 6),
#              ('100', 20),
#              ('happens', 8),
#              ('dial', 6),
#              ('research', 7),
#              ('lolhayley', 1),
#              ('something', 68),
#              ('actual', 22),
#              ('man', 147),
#              ('running', 72),
#              ('wondering', 37),
#              ('could', 119),
#              ('party', 220),
#              ('pay', 37),
#              ('liver', 1),
#              ('transplant', 1),
#              ('playing', 32),
#              ('mtaibbi', 5),
#              ('brandondhowell', 1),
#              ('stafriday', 1),
#              ('1ai9cuz8by', 1),
#              ('unconstitutional', 4),
#              ('order', 86),
#              ('enacted', 1),
#              ('pres', 24),
#              ('oba', 2),
#              ('ronnie2k', 1),
#              ('jcuirk1i1u', 1),
#              ('bruneski', 1),
#              ('upstairs', 1),
#              ('kids', 47),
#              ('many', 156),
#              ('miss', 44),
#              ('gopclowncar', 30),
#              ('todd', 6),
#              ('akin', 2),
#              ('sting', 2),
#              ('backfired', 5),
#              ('republicans', 123),
#              ('standwithpp', 8),
#              ('ekxpfkthqn', 1),
#              ('learjetter', 8),
#              ('digest', 2),
#              ('allowing', 5),
#              ('crazy', 35),
#              ('dwstweets', 39),
#              ('trash', 8),
#              ('ladysandersfarm', 12),
#              ('receive', 6),
#              ('enormous', 2),
#              ('applause', 15),
#              ('horribly', 2),
#              ('answer', 114),
#              ('r4e8tpotd5', 1),
#              ('favorite', 65),
#              ('responses', 10),
#              ('2iqcdrcdlm', 1),
#              ('7tdma3vlm8', 1),
#              ('though', 27),
#              ('super', 24),
#              ('conservative', 63),
#              ('reporter', 6),
#              ('actually', 98),
#              ('interview', 15),
#              ('style', 10),
#              ('kingsthings', 2),
#              ('series', 2),
#              ('minute', 17),
#              ('opportunities', 3),
#              ('avoid', 8),
#              ('answering', 16),
#              ('candidate', 312),
#              ('melissagracey', 1),
#              ('credit', 16),
#              ('joke', 33),
#              ('goes', 24),
#              ('someone', 136),
#              ('else', 191),
#              ('icredssplr', 1),
#              ('reince', 14),
#              ('simply', 14),
#              ('incredible', 5),
#              ('apxm8ao8jf', 2),
#              ('doubled', 2),
#              ('previous', 6),
#              ('record', 52),
#              ('watched', 103),
#              ('katethomas', 1),
#              ('literally', 20),
#              ('got', 227),
#              ('lousy', 3),
#              ('hangover', 37),
#              ('cxch7x', 1),
#              ('dreamer', 1),
#              ('haha', 5),
#              ('saas', 1),
#              ('voxdotcom', 10),
#              ('morning', 57),
#              ('towards', 11),
#              ('factchecked', 1),
#              ('daectmllaj', 1),
#              ('texascruzn', 2),
#              ('1z3vufjzlw', 2),
#              ('zellieimani', 11),
#              ('person', 96),
#              ('tv', 107),
#              ('qlgsxrh5hw', 1),
#              ('marco', 97),
#              ('told', 47),
#              ('yesterday', 30),
#              ('anti', 32),
#              ('bigotry', 6),
#              ('a4eiuettlf', 2),
#              ('cariisie', 1),
#              ('place', 40),
#              ('foolish', 3),
#              ('yet', 44),
#              ('think', 479),
#              ('done', 52),
#              ('crying', 8),
#              ('agai', 1),
#              ('akbarjenkins', 1),
#              ('maybe', 56),
#              ('piven', 2),
#              ('cloward', 2),
#              ('confused', 12),
#              ('pinkard', 2),
#              ('bowden', 2),
#              ('steal', 6),
#              ('cars', 3),
#              ('kevinbaker', 2),
#              ('kevinmkr', 1),
#              ('watching', 334),
#              ('qcmxmu8mlp', 1),
#              ('jrehling', 5),
#              ('pigs', 20),
#              ('save', 13),
#              ('theonlyadult', 1),
#              ('might', 41),
#              ('rip', 11),
#              ('everything', 49),
#              ('caught', 12),
#              ('surprise', 28),
#              ('able', 15),
#              ('recover', 2),
#              ('equilibrium', 1),
#              ('kirahoffy', 1),
#              ('web', 4),
#              ('stream', 11),
#              ('mobile', 3),
#              ('app', 6),
#              ('fail', 20),
#              ('surprised', 24),
#              ('tkpesooezt', 2),
#              ('john', 73),
#              ('helped', 9),
#              ('ohioans', 1),
#              ('create', 11),
#              ('350', 1),
#              ('000', 26),
#              ('new', 117),
#              ('america', 245),
#              ('kbzfbjyp2c', 1),
#              ('help', 67),
#              ('maryknoll', 1),
#              ('sisters', 1),
#              ('replace', 25),
#              ('windows', 1),
#              ('convent', 1),
#              ('fdgxg3vv13', 1),
#              ('catholic', 2),
#              ('gofundme', 1),
#              ('trcot', 1),
#              ('largest', 9),
#              ('audience', 73),
#              ('chip', 9),
#              ('nzync1jrxs', 2),
#              ('started', 14),
#              ('violently', 2),
#              ('69ing', 1),
#              ('cameronesposito', 2),
#              ('ugh', 16),
#              ('guys', 88),
#              ('shut', 29),
#              ('much', 164),
#              ('respect', 43),
#              ('teach', 10),
#              ('future', 66),
#              ('probably', 34),
#              ('safe', 6),
#              ('except', 29),
#              ('attacked', 8),
#              ('congoboy', 1),
#              ('long', 142),
#              ('tiring', 2),
#              ('season', 13),
#              ('shockingly', 3),
#              ('ill', 2),
#              ('informed', 11),
#              ('vtk1k0txi', 1),
#              ('blessed', 18),
#              ('thedemocrats', 16),
#              ('find', 47),
#              ('marcorubio', 119),
#              ('miracle', 2),
#              ('happen', 16),
#              ('grow', 11),
#              ('opportunity', 10),
#              ('lnqhdgtudk', 1),
#              ('mattyiceaz', 13),
#              ('carry', 9),
#              ('state', 78),
#              ('xlnb', 2),
#              ('indication', 1),
#              ('peep', 2),
#              ('bh0chsy5eh', 1),
#              ('smethanie', 4),
#              ('sure', 106),
#              ('tooth', 4),
#              ('fairy', 3),
#              ('agreed', 13),
#              ('teletubbies', 3),
#              ('voted', 10),
#              ('yes', 77),
#              ('caller', 3),
#              ('rush', 30),
#              ('limbaugh', 13),
#              ('lost', 49),
#              ('stinger', 3),
#              ('inc', 4),
#              ('behaviour', 2),
#              ('astonishingly', 1),
#              ('biased', 24),
#              ('economics', 3),
#              ('wins', 51),
#              ('falters', 2),
#              ('exaggerates', 2),
#              ('molloaqhwq', 1),
#              ('knowmorenotless', 1),
#              ('gpnaplang', 1),
#              ('jamesviser', 2),
#              ('huh', 11),
#              ('half', 45),
#              ('clinton', 110),
#              ('charity', 1),
#              ('went', 50),
#              ('clintons', 3),
#              ('bvwrosgwal', 1),
#              ('copolitics', 3),
#              ('hillary2016', 21),
#              ('stophillary', 2),
#              ('uniteb', 1),
#              ('kraig4u', 1),
#              ('wonder', 40),
#              ('took', 49),
#              ('seriously', 73),
#              ('heidil', 2),
#              ('rn', 3),
#              ('diegouk', 1),
#              ('democrats', 101),
#              ('7v4wjok3vm', 1),
#              ('p2', 56),
#              ('ctl', 4),
#              ('topprog', 9),
#              ('tlot', 27),
#              ('owe', 3),
#              ('thank', 57),
#              ('4', 69),
#              ('exposing', 3),
#              ('world', 90),
#              ('rhinos', 3),
#              ('lies', 29),
#              ('budget', 27),
#              ('535m', 1),
#              ('surplus', 4),
#              ('76b', 1),
#              ('deficit', 3),
#              ('vvmxzkxlkr', 1),
#              ('sensanders', 11),
#              ('give', 88),
#              ('birth', 21),
#              ('changed', 30),
#              ('5hkcefp1hf', 1),
#              ('received', 40),
#              ('word', 106),
#              ('soup', 1),
#              ('sandwich', 2),
#              ('frankconniff', 5),
#              ('interviewer', 3),
#              ('talking', 166),
#              ('points', 39),
#              ('feeding', 1),
#              ('lesliemac', 1),
#              ('murder', 5),
#              ('ppl', 30),
#              ('fine', 12),
#              ('unborn', 17),
#              ('babies', 23),
#              ('goplogic', 1),
#              ('missing', 19),
#              ('jon', 32),
#              ('stewaalready', 2),
#              ('jonvoyage', 34),
#              ('h', 36),
#              ('charlottelaws', 1),
#              ('standing', 16),
#              ('libertyjibbet', 1),
#              ('know', 341),
#              ('whine', 7),
#              ('unfair', 14),
#              ('set', 194),
#              ('ya', 20),
#              ('gopde', 37),
#              ('pro', 72),
#              ('life', 141),
#              ('hour', 21),
#              ('forkedtongue', 1),
#              ('iseeorangepeople', 1),
#              ('failed', 35),
#              ('tonight', 327),
#              ('tried', 30),
#              ('destroying', 4),
#              ('kellyfai', 1),
#              ('edstetzer', 3),
#              ('btw', 9),
#              ('mix', 3),
#              ('politics', 93),
#              ('religion', 19),
#              ('teammarco', 5),
#              ('nailed', 10),
#              ('must', 55),
#              ('protect', 14),
#              ('nn6s7do22j', 1),
#              ('bankruptcy', 30),
#              ('giving', 41),
#              ('softball', 124),
#              ('obviously', 169),
#              ('memo', 2),
#              ('seersuckerthursday', 1),
#              ('lzagrrtzfl', 1),
#              ('vh1', 1),
#              ('honestly', 24),
#              ('types', 3),
#              ('petty', 5),
#              ('qxdoemfuqo', 1),
#              ('mcr6lrjh2h', 1),
#              ('tuxcedocat', 1),
#              ('dopefuls', 1),
#              ('2009', 3),
#              ('gloating', 1),
#              ('abt', 19),
#              ('buying', 9),
#              ('dem', 15),
#              ('pols', 1),
#              ('bidding', 1),
#              ('2000s', 1),
#              ('billionaire', 12),
#              ('caricature', 1),
#              ('myacash', 1),
#              ('5spmu3csic', 1),
#              ('peddoc63', 15),
#              ('carly2016', 31),
#              ('flyoverculture', 2),
#              ('leahr77', 3),
#              ('steph93065', 5),
#              ('maydnusa', 6),
#              ('daenerys', 2),
#              ('3jrcuqdafu', 1),
#              ('scorpionspriest', 1),
#              ('telling', 24),
#              ('another', 75),
#              ('hug', 19),
#              ('johnfugelsang', 15),
#              ('missed', 47),
#              ('either', 29),
#              ('struggling', 5),
#              ('unlimited', 2),
#              ('pfikac', 1),
#              ('verge', 1),
#              ('greatest', 15),
#              ('alive', 13),
#              ('washington', 26),
#              ('holding', 14),
#              ('mysa', 1),
#              ('txlege', 3),
#              ('drmartyfox', 3),
#              ('drudge', 34),
#              ('poll', 43),
#              ('pjnet', 38),
#              ('yuh6j7qqha', 1),
#              ('siteroi', 2),
#              ('governorperry', 23),
#              ('fights', 5),
#              ('immigration', 133),
#              ('q', 26),
#              ('border', 20),
#              ('porous', 1),
#              ('fixed', 7),
#              ('summary', 17),
#              ...])

# %%
#Dictionary index of a word
tokenizer.word_index["moderators"]
# Out:
# 185

# %%
X = tokenizer.texts_to_sequences(data['text'].values)
X = pad_sequences(X, padding = 'post') #Zero padding at the end of the sequence

# %%
Y = to_categorical(Y)
print(Y)
# Out:
# [[0. 1. 0.]
#  [0. 0. 1.]
#  [0. 1. 0.]
#  ...
#  [0. 0. 1.]
#  [1. 0. 0.]
#  [0. 0. 1.]]

# %%
#Splitting the data into train data and test data
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)

# %% [markdown]
# ### RNN, LSTM, Stacked-RNN, Stacked-LSTM, Bidirectional-RNN, Bidirectional-LSTM

# %%
embed_dim = 500
hidden_layer = 100

model = Sequential()
model.add(Embedding(max_features, embed_dim,input_length = X.shape[1], dropout=0.2))
model.add(SimpleRNN(hidden_layer))
model.add(Dense(3,activation='softmax'))
model.compile(loss = 'categorical_crossentropy', optimizer='adam',metrics = ['accuracy'])
print(model.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_7 (Embedding)      (None, 24, 500)           600000
# _________________________________________________________________
# simple_rnn_6 (SimpleRNN)     (None, 100)               60100
# _________________________________________________________________
# dense_7 (Dense)              (None, 3)                 303
# =================================================================
# Total params: 660,403
# Trainable params: 660,403
# Non-trainable params: 0
# _________________________________________________________________
# None
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:5: UserWarning: The `dropout` argument is no longer support in `Embedding`. You can apply a `keras.layers.SpatialDropout1D` layer right after the `Embedding` layer to get the same behavior.
#   """

# %%
batch_size = 32
model.fit(X_train, y_train, epochs = 10, batch_size=batch_size)
# Out:
# Epoch 1/10
# 11096/11096 [==============================] - 5s 450us/step - loss: 0.8403 - acc: 0.6333
# Epoch 2/10
# 11096/11096 [==============================] - 5s 414us/step - loss: 0.7148 - acc: 0.6978
# Epoch 3/10
# 11096/11096 [==============================] - 5s 417us/step - loss: 0.6347 - acc: 0.7364
# Epoch 4/10
# 11096/11096 [==============================] - 5s 416us/step - loss: 0.5678 - acc: 0.7669
# Epoch 5/10
# 11096/11096 [==============================] - 5s 414us/step - loss: 0.5164 - acc: 0.7924
# Epoch 6/10
# 11096/11096 [==============================] - 5s 413us/step - loss: 0.4712 - acc: 0.8121
# Epoch 7/10
# 11096/11096 [==============================] - 5s 416us/step - loss: 0.4239 - acc: 0.8326
# Epoch 8/10
# 11096/11096 [==============================] - 5s 415us/step - loss: 0.3921 - acc: 0.8464
# Epoch 9/10
# 11096/11096 [==============================] - 5s 415us/step - loss: 0.3626 - acc: 0.8612
# Epoch 10/10
# 11096/11096 [==============================] - 5s 417us/step - loss: 0.3406 - acc: 0.8672

# %%
score = model.evaluate(X_test, y_test, verbose = 1, batch_size = batch_size)
print("Accuracy: %.2f" % (score[1]*100))
# Out:
# Accuracy: 62.81

# %%
test = data['text'][0]
test = clean_data(test)
test = test.replace('rt ','')
test = [test]
test = tokenizer.texts_to_sequences(test)
test = pad_sequences(test, maxlen=24, padding = 'post')

# %%
class_label = model.predict_classes(test)
print(le.inverse_transform(class_label))
# Out:
# ['Negative']

# %% [markdown]
# ### CNN-RNN and CNN-LSTM

# %%
# Convolution
kernel_size = 5
filters = 64
pool_size = 4

# %%
model = Sequential()
model.add(Embedding(max_features, embed_dim,input_length = X.shape[1], dropout=0.2))
model.add(Conv1D(filters,
                 kernel_size,
                 padding='valid',
                 activation='relu',
                 strides=1))
model.add(MaxPooling1D(pool_size=pool_size))
model.add(LSTM(hidden_layer))
model.add(Dense(3))
model.add(Activation('sigmoid'))
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:2: UserWarning: The `dropout` argument is no longer support in `Embedding`. You can apply a `keras.layers.SpatialDropout1D` layer right after the `Embedding` layer to get the same behavior.

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['accuracy'])

# %%
batch_size = 32
model.fit(X_train, y_train, epochs = 10, batch_size=batch_size)
# Out:
# Epoch 1/10
# 11096/11096 [==============================] - 8s 697us/step - loss: 0.8193 - acc: 0.6501
# Epoch 2/10
# 11096/11096 [==============================] - 6s 583us/step - loss: 0.6894 - acc: 0.7051
# Epoch 3/10
# 11096/11096 [==============================] - 7s 614us/step - loss: 0.5988 - acc: 0.7504
# Epoch 4/10
# 11096/11096 [==============================] - 7s 611us/step - loss: 0.5043 - acc: 0.7959
# Epoch 5/10
# 11096/11096 [==============================] - 7s 611us/step - loss: 0.3999 - acc: 0.8389
# Epoch 6/10
# 11096/11096 [==============================] - 7s 606us/step - loss: 0.3333 - acc: 0.8693
# Epoch 7/10
# 11096/11096 [==============================] - 7s 608us/step - loss: 0.2987 - acc: 0.8809
# Epoch 8/10
# 11096/11096 [==============================] - 7s 610us/step - loss: 0.2726 - acc: 0.8920
# Epoch 9/10
# 11096/11096 [==============================] - 7s 629us/step - loss: 0.2426 - acc: 0.9019
# Epoch 10/10
# 11096/11096 [==============================] - 7s 642us/step - loss: 0.2262 - acc: 0.9065

# %%
score = model.evaluate(X_test, y_test, verbose = 1, batch_size = batch_size)
print("Accuracy: %.2f" % (score[1]*100))
# Out:
# 2775/2775 [==============================] - 0s 46us/step
# Accuracy: 60.76

# %% [markdown]
# ### Using word2vec in Keras

# %%
#Reading the data
data = pd.read_csv('sa_data.csv')

# %%
def clean_data(tweet):
    x = re.sub("[^a-zA-Z0-9]", " ",tweet) 
    x = x.lower().split()                             
    stops = set(stopwords.words("english"))                  
    words = [w for w in x if not w in stops] 
    return( " ".join(words))

# %%
data['text'] = data['text'].apply(lambda x: clean_data(x))

for i in range(len(data)):
    data['text'][i] = data['text'][i].replace('rt ','')

# %%
reviews = data['text'].tolist()
sentiment = data['sentiment'].tolist()

corpus = []
for i in range(len(reviews)):
    corpus.append(word_tokenize(reviews[i]))

# %%
wv_model = Word2Vec(corpus, size=100, window=5, min_count=1)
w2v_model_wv = wv_model.wv

# %%
#Tokenization
max_features = 1200 #number of words to keep. 1200 is the number of unique words in the corpus.
tokenizer = Tokenizer(nb_words=max_fatures, split=' ')
tokenizer.fit_on_texts(data['text'].values)
X = tokenizer.texts_to_sequences(data['text'].values)
X = pad_sequences(X, padding = 'post') #Zero padding at the end of the sequence
word_index = tokenizer.word_index
# Out:
# /usr/local/lib/python3.5/dist-packages/keras/preprocessing/text.py:172: UserWarning: The `nb_words` argument in `Tokenizer` has been renamed `num_words`.
#   warnings.warn('The `nb_words` argument in `Tokenizer` '

# %%
maxlen = len(X[0])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)
print('Shape of X_train and X_test data:', X_train.shape,X_test.shape)
print('Shape of y_train and y_test:', y_train.shape,y_test.shape)
# Out:
# Shape of X_train and X_test data: (11096, 24) (2775, 24)
# Shape of y_train and y_test: (11096, 3) (2775, 3)

# %%
nb_words = len(wv_model.wv.vocab)
embedding_dimension = 100

embedding_matrix = np.zeros((nb_words, embedding_dimension))
for word, i in word_index.items():
    if word in wv_model.wv.vocab:
        embedding_matrix[i] = wv_model.wv[word]

# %%
wv_layer = Embedding(nb_words,embedding_dimension,weights=[embedding_matrix], input_length=maxlen,
                     trainable=True)
input_tweet = Input(shape=(maxlen,))
embedded_sequences = wv_layer(input_tweet)
x = SimpleRNN(64, return_sequences=False)(embedded_sequences)
preds = Dense(3, activation='sigmoid')(x)

# %%
model = Model(inputs=[input_tweet], outputs=preds)

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam',metrics=['accuracy'])

# %%
model.fit([X_train], y_train, validation_split=0.1,epochs=10, batch_size=256, shuffle=True)
# Out:
# Train on 9986 samples, validate on 1110 samples
# Epoch 1/10
# 9986/9986 [==============================] - 2s 214us/step - loss: 0.9353 - acc: 0.6095 - val_loss: 0.9511 - val_acc: 0.6000
# Epoch 2/10
# 9986/9986 [==============================] - 1s 126us/step - loss: 0.9129 - acc: 0.6180 - val_loss: 0.9195 - val_acc: 0.6117
# Epoch 3/10
# 9986/9986 [==============================] - 1s 133us/step - loss: 0.8917 - acc: 0.6156 - val_loss: 0.9018 - val_acc: 0.6036
# Epoch 4/10
# 9986/9986 [==============================] - 1s 126us/step - loss: 0.8803 - acc: 0.6151 - val_loss: 0.9095 - val_acc: 0.5964
# Epoch 5/10
# 9986/9986 [==============================] - 1s 124us/step - loss: 0.8771 - acc: 0.6050 - val_loss: 0.9335 - val_acc: 0.5505
# Epoch 6/10
# 9986/9986 [==============================] - 1s 123us/step - loss: 0.9073 - acc: 0.6062 - val_loss: 0.9083 - val_acc: 0.6090
# Epoch 7/10
# 9986/9986 [==============================] - 1s 126us/step - loss: 0.8331 - acc: 0.6346 - val_loss: 0.8828 - val_acc: 0.6081
# Epoch 8/10
# 9986/9986 [==============================] - 1s 124us/step - loss: 0.7825 - acc: 0.6513 - val_loss: 0.8862 - val_acc: 0.6027
# Epoch 9/10
# 9986/9986 [==============================] - 1s 132us/step - loss: 0.7895 - acc: 0.6477 - val_loss: 0.8748 - val_acc: 0.6054
# Epoch 10/10
# 9986/9986 [==============================] - 1s 127us/step - loss: 0.7172 - acc: 0.6767 - val_loss: 0.8786 - val_acc: 0.6036

# %%
score = model.evaluate(X_test, y_test, verbose = 2, batch_size = batch_size)
print("Accuracy: %.2f" % (score[1]*100))
# Out:
# Accuracy: 61.05
